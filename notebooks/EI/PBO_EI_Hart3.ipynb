# %% [markdown]
# # Preferential Bayesian Optimization: EI
# This notebook demonstrates the use of the Expected Improvement (EI) acquisition function on ordinal (preference) data.
#
# Formulation by Nguyen Quoc Phong.

# %%
import numpy as np
import gpflow
import tensorflow as tf
import matplotlib.pyplot as plt
import sys
import os
import pickle

from gpflow.utilities import set_trainable, print_summary
gpflow.config.set_default_summary_fmt("notebook")

sys.path.append(os.path.split(os.path.split(os.path.split(os.getcwd())[0])[0])[0]) # Move 3 levels up directory to import PBO
import PBO

# %%
objective = PBO.objectives.hartmann3d
objective_low = 0
objective_high = 1.
objective_name = "Hart3"
acquisition_name = "EI"
experiment_name = "PBO" + "_" + acquisition_name + "_" + objective_name

# %%
num_runs = 20
num_evals = 20
num_samples = 1000
num_choices = 2
input_dims = 3
num_maximizers = 20
num_init_points = 3
num_inducing_init = 3
num_discrete_per_dim = 100 # Discretization of continuous input space

# %%
results_dir = os.getcwd() + '/results/' + experiment_name + '/'

try:
    # Create target Directory
    os.makedirs(results_dir)
    print("Directory " , results_dir ,  " created ") 
except FileExistsError:
    print("Directory " , results_dir ,  " already exists")
# Out:
# Directory  /home/sebtsh/PBO/notebooks/EI/results/PBO_EI_Hart3/  already exists

# %%
def get_noisy_observation(X, objective):
    f = PBO.objectives.objective_get_f_neg(X, objective)
    return PBO.observation_model.gen_observation_from_f(X, f, 1)

# %%
def train_and_visualize(X, y, num_inducing, title):
    
    # Train model with data
    q_mu, q_sqrt, u, inputs, k, indifference_threshold = PBO.models.learning_stochastic.train_model_fullcov(X, y, 
                                                                         num_inducing=num_inducing,
                                                                         obj_low=objective_low,
                                                                         obj_high=objective_high,
                                                                         num_steps=3000)
    likelihood = gpflow.likelihoods.Gaussian()
    model = PBO.models.learning.init_SVGP_fullcov(q_mu, q_sqrt, u, k, likelihood)
    u_mean = q_mu.numpy()
    inducing_vars = u.numpy()
    
    return model, inputs, u_mean, inducing_vars

# %%
def uniform_grid(input_dims, num_discrete_per_dim, low=0., high=1.):
    """
    Returns an array with all possible permutations of discrete values in input_dims number of dimensions.
    :param input_dims: int
    :param num_discrete_per_dim: int
    :param low: int
    :param high: int
    :return: tensor of shape (num_discrete_per_dim ** input_dims, input_dims)
    """
    num_points = num_discrete_per_dim ** input_dims
    out = np.zeros([num_points, input_dims])
    discrete_points = np.linspace(low, high, num_discrete_per_dim)
    for i in range(num_points):
        for dim in range(input_dims):
            val = num_discrete_per_dim ** (dim)
            out[i, dim] = discrete_points[int((i // val) % num_discrete_per_dim)]
    return out

# %% [markdown]
# This function is our main metric for the performance of the acquisition function: The closer the model's best guess to the global minimum, the better.

# %%
def best_guess(model):
    """
    Returns a GP model's best guess of the global maximum of f.
    """
    xx = uniform_grid(input_dims, num_discrete_per_dim, low=objective_low, high=objective_high)
    res = model.predict_f(xx)[0].numpy()
    return xx[np.argmax(res)]

# %% [markdown]
# Store the results in these arrays:

# %%
num_data_at_end = int((num_init_points-1) * num_init_points / 2 + num_evals)
X_results = np.zeros([num_runs, num_data_at_end, num_choices, input_dims])
y_results = np.zeros([num_runs, num_data_at_end, 1, input_dims])
best_guess_results = np.zeros([num_runs, num_evals, input_dims])

# %% [markdown]
# Create the initial values for each run:

# %%
np.random.seed(0)
init_points = np.random.uniform(low=objective_low, high=objective_high, size=[num_runs, num_init_points, input_dims])
num_combs = int((num_init_points-1) * num_init_points / 2)
init_vals = np.zeros([num_runs, num_combs, num_choices, input_dims])
for run in range(num_runs):
    cur_idx = 0
    for init_point in range(num_init_points-1):
        for next_point in range(init_point+1, num_init_points):
            init_vals[run, cur_idx, 0] = init_points[run, init_point]
            init_vals[run, cur_idx, 1] = init_points[run, next_point]
            cur_idx += 1

# %% [markdown]
# The following loops carry out the Bayesian optimization algorithm over a number of runs, with a fixed number of evaluations per run.

# %%
for run in range(num_runs):
    print("Beginning run %s" % (run))
    
    X = init_vals[run]
    y = get_noisy_observation(X, objective)
    
    model, inputs, u_mean, inducing_vars = train_and_visualize(X, y, num_inducing_init, "Run_{}:_Initial_model".format(run))

    for evaluation in range(num_evals):
        print("Beginning evaluation %s" % (evaluation)) 

        # Get incumbent maximizer
        maximizer = np.expand_dims(best_guess(model), axis=0)  # (1, input_dims)
        
        print("Maximizer:")
        print(maximizer)
        
        # Sample possible next input points. In EI, all queries are a pair with the incumbent maximizer as the 
        # first point and a next input point as the second point
        
        samples = np.random.uniform(low=objective_low,
                                    high=objective_high,
                                    size=(num_samples, input_dims))
        
        # Calculate EI vals
        ei_vals = PBO.acquisitions.ei.EI(model, maximizer, samples)
        
        # Select query that maximizes EI
        next_idx = np.argmax(ei_vals)
        next_query = np.zeros((num_choices, input_dims))
        next_query[0, :] = maximizer  # EI only works in binary choices
        next_query[1, :] = samples[next_idx]
        print("Evaluation %s: Next query is %s with EI value of %s" % (evaluation, next_query, ei_vals[next_idx]))

        X = np.concatenate([X, [next_query]])
        # Evaluate objective function
        y = np.concatenate([y, get_noisy_observation(np.expand_dims(next_query, axis=0), objective)], axis=0)
        
        print("Evaluation %s: Training model" % (evaluation))
        model, inputs, u_mean, inducing_vars = train_and_visualize(X, y, 
                                                                   num_inducing_init + evaluation + 1, 
                                                                   "Run_{}_Evaluation_{}".format(run, evaluation))

        best_guess_results[run, evaluation, :] = best_guess(model)
        
        pickle.dump((model.kernel.variance.numpy(), 
                     model.kernel.lengthscale.numpy(),
                     model.inducing_variable.Z.numpy(), 
                     model.q_mu.numpy(), 
                     model.q_sqrt.numpy()), 
                    open(results_dir + "Run_{}_Evaluation_{}_model.p".format(run, evaluation), "wb"))

    X_results[run] = X
    y_results[run] = y
# Out:
# Beginning run 0
# Indifference_threshold is trainable.
# WARNING:tensorflow:From /home/sebtsh/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/ops/array_grad.py:563: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity instead.
# Negative ELBO at step 0: 7.269339792522033 in 0.2291s
# Negative ELBO at step 500: 2.2747047046285003 in 53.2784s
# Negative ELBO at step 1000: 2.061834863461045 in 52.1164s
# Negative ELBO at step 1500: 2.1425262940705623 in 51.5013s
# Negative ELBO at step 2000: 2.0919999830423746 in 60.9488s
# Negative ELBO at step 2500: 2.138971449508106 in 60.1255s
# Beginning evaluation 0
# Maximizer:
# [[0.64646465 0.17171717 0.        ]]
# Evaluation 0: Next query is [[0.64646465 0.17171717 0.        ]
#  [0.6090939  0.18511639 0.00620341]] with EI value of [0.37960182]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 206.06655683262238 in 0.2569s
# Negative ELBO at step 500: 10.548103926089214 in 71.9289s
# Negative ELBO at step 1000: 5.105079274545194 in 79.4841s
# Negative ELBO at step 1500: 3.661707759438784 in 79.9528s
# Negative ELBO at step 2000: 3.2896125189383056 in 72.7576s
# Negative ELBO at step 2500: 3.2865185568403006 in 76.9187s
# Beginning evaluation 1
# Maximizer:
# [[0.7979798  0.21212121 0.        ]]
# Evaluation 1: Next query is [[0.7979798  0.21212121 0.        ]
#  [0.29865743 0.00657328 0.06052102]] with EI value of [0.36371925]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 64.5982530910107 in 0.5275s
# Negative ELBO at step 500: 5.869473773956607 in 96.6632s
# Negative ELBO at step 1000: 3.9610932335996507 in 87.9620s
# Negative ELBO at step 1500: 3.6857168132292273 in 85.8938s
# Negative ELBO at step 2000: 3.7603660934502074 in 91.1783s
# Negative ELBO at step 2500: 3.6022182089714434 in 88.6574s
# Beginning evaluation 2
# Maximizer:
# [[1.         0.70707071 0.        ]]
# Evaluation 2: Next query is [[1.         0.70707071 0.        ]
#  [0.9809524  0.63842233 0.00192003]] with EI value of [0.36775174]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 223.42025647707 in 0.2392s
# Negative ELBO at step 500: 8.9253859992392 in 97.8299s
# Negative ELBO at step 1000: 5.406236445348295 in 103.2886s
# Negative ELBO at step 1500: 4.775691218550166 in 102.0729s
# Negative ELBO at step 2000: 4.481935956818047 in 98.9064s
# Negative ELBO at step 2500: 4.450970101338329 in 98.8748s
# Beginning evaluation 3
# Maximizer:
# [[1.         0.34343434 0.1010101 ]]
# Evaluation 3: Next query is [[1.         0.34343434 0.1010101 ]
#  [0.95161358 0.18793987 0.12814614]] with EI value of [0.3745085]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 164.0821818880941 in 0.3007s
# Negative ELBO at step 500: 8.015322506421416 in 109.9650s
# Negative ELBO at step 1000: 5.670127033855304 in 117.1436s
# Negative ELBO at step 1500: 5.436253936243769 in 109.3908s
# Negative ELBO at step 2000: 5.181290179897721 in 115.7513s
# Negative ELBO at step 2500: 5.074488165636543 in 100.9864s
# Beginning evaluation 4
# Maximizer:
# [[0.92929293 0.31313131 0.        ]]
# Evaluation 4: Next query is [[0.92929293 0.31313131 0.        ]
#  [0.96110878 0.08091772 0.00923588]] with EI value of [0.37334245]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1062.0645372978465 in 0.3941s
# Negative ELBO at step 500: 29.01170279289657 in 110.9506s
# Negative ELBO at step 1000: 12.895430019248234 in 139.0635s
# Negative ELBO at step 1500: 8.463842715266848 in 110.8996s
# Negative ELBO at step 2000: 7.533388220262081 in 139.8479s
# Negative ELBO at step 2500: 6.586043421556521 in 117.6598s
# Beginning evaluation 5
# Maximizer:
# [[1.         0.23232323 0.15151515]]
# Evaluation 5: Next query is [[1.         0.23232323 0.15151515]
#  [0.9966761  0.01060222 0.39942649]] with EI value of [0.34320764]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 318.67906219516146 in 0.3781s
# Negative ELBO at step 500: 16.350281951087858 in 121.3728s
# Negative ELBO at step 1000: 8.338714569621377 in 156.6325s
# Negative ELBO at step 1500: 6.8813958287595405 in 120.8599s
# Negative ELBO at step 2000: 6.568520950015214 in 143.2487s
# Negative ELBO at step 2500: 6.314058860194993 in 134.6502s
# Beginning evaluation 6
# Maximizer:
# [[1.         0.28282828 0.        ]]
# Evaluation 6: Next query is [[1.         0.28282828 0.        ]
#  [0.96126746 0.33014246 0.02748104]] with EI value of [0.34961818]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 3010.751153758888 in 0.3355s
# Negative ELBO at step 500: 65.74216427481088 in 151.2329s
# Negative ELBO at step 1000: 30.438687877327098 in 152.7723s
# Negative ELBO at step 1500: 19.485083892151717 in 157.8507s
# Negative ELBO at step 2000: 13.38827224028363 in 152.7532s
# Negative ELBO at step 2500: 9.9879360786665 in 157.0804s
# Beginning evaluation 7
# Maximizer:
# [[1.         0.25252525 0.        ]]
# Evaluation 7: Next query is [[1.         0.25252525 0.        ]
#  [0.99239492 0.12677467 0.07258742]] with EI value of [0.40393439]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 4513.38032999144 in 0.5963s
# Negative ELBO at step 500: 93.12230887427006 in 174.2025s
# Negative ELBO at step 1000: 32.94191202376978 in 173.4900s
# Negative ELBO at step 1500: 19.388001041288746 in 170.5681s
# Negative ELBO at step 2000: 14.673859456843717 in 172.6436s
# Negative ELBO at step 2500: 10.74063849274342 in 170.0901s
# Beginning evaluation 8
# Maximizer:
# [[1.         0.29292929 0.01010101]]
# Evaluation 8: Next query is [[1.         0.29292929 0.01010101]
#  [0.9939008  0.07119443 0.03478882]] with EI value of [0.3708805]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2718.4478556640875 in 0.5058s
# Negative ELBO at step 500: 69.24067806169377 in 179.8628s
# Negative ELBO at step 1000: 29.371675084400707 in 185.5541s
# Negative ELBO at step 1500: 18.082132307532667 in 185.5219s
# Negative ELBO at step 2000: 12.720345072128758 in 179.7929s
# Negative ELBO at step 2500: 10.939183380155534 in 186.1088s
# Beginning evaluation 9
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 9: Next query is [[1.         0.         0.        ]
#  [0.93187675 0.02017622 0.04876027]] with EI value of [0.3572112]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7340.613432246142 in 0.4800s
# Negative ELBO at step 500: 186.25321564755876 in 205.2390s
# Negative ELBO at step 1000: 70.86593258924992 in 189.0381s
# Negative ELBO at step 1500: 41.407531347116645 in 195.9180s
# Negative ELBO at step 2000: 25.421453331165175 in 199.4356s
# Negative ELBO at step 2500: 22.66200685073967 in 193.6533s
# Beginning evaluation 10
# Maximizer:
# [[1.         0.07070707 0.        ]]
# Evaluation 10: Next query is [[1.         0.07070707 0.        ]
#  [0.05560529 0.06000847 0.92188098]] with EI value of [0.3410304]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 13016.885813068815 in 0.4853s
# Negative ELBO at step 500: 225.25717715152166 in 214.1354s
# Negative ELBO at step 1000: 104.68568039082889 in 208.4059s
# Negative ELBO at step 1500: 48.60035237764727 in 204.9663s
# Negative ELBO at step 2000: 33.71113632764703 in 208.5001s
# Negative ELBO at step 2500: 26.80417676227394 in 208.0649s
# Beginning evaluation 11
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 11: Next query is [[1.         0.         0.        ]
#  [0.09096376 0.04199186 0.10138417]] with EI value of [0.41760938]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 40677.10312695379 in 0.5263s
# Negative ELBO at step 500: 742.7487974173432 in 218.4718s
# Negative ELBO at step 1000: 295.0551501280632 in 227.8889s
# Negative ELBO at step 1500: 172.2312944013078 in 230.2722s
# Negative ELBO at step 2000: 86.48277436460039 in 224.7348s
# Negative ELBO at step 2500: 69.50857805861123 in 231.0721s
# Beginning evaluation 12
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 12: Next query is [[1.         0.         0.        ]
#  [0.88152939 0.04547404 0.01269527]] with EI value of [0.46738817]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 37544.67349619091 in 0.5672s
# Negative ELBO at step 500: 664.3567069109073 in 232.1328s
# Negative ELBO at step 1000: 301.39863010834205 in 230.2457s
# Negative ELBO at step 1500: 145.28763189990826 in 228.6570s
# Negative ELBO at step 2000: 74.62249578707097 in 233.7544s
# Negative ELBO at step 2500: 68.78685486041611 in 232.9551s
# Beginning evaluation 13
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 13: Next query is [[1.         0.         0.        ]
#  [0.9976618  0.22095679 0.13858573]] with EI value of [0.7007696]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 27294.071802858638 in 0.5683s
# Negative ELBO at step 500: 502.50854910375364 in 239.9422s
# Negative ELBO at step 1000: 163.2015872098046 in 238.2877s
# Negative ELBO at step 1500: 84.85222388609695 in 241.6681s
# Negative ELBO at step 2000: 59.30275255032723 in 242.3696s
# Negative ELBO at step 2500: 36.490532600778444 in 244.4570s
# Beginning evaluation 14
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 14: Next query is [[1.         0.         0.        ]
#  [0.94875957 0.94501841 0.96451909]] with EI value of [0.40121016]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 45081.57363781841 in 1.9348s
# Negative ELBO at step 500: 706.0025319325745 in 235.9195s
# Negative ELBO at step 1000: 267.14965713554864 in 243.7605s
# Negative ELBO at step 1500: 142.50679630541765 in 252.3258s
# Negative ELBO at step 2000: 85.00478197702796 in 254.6759s
# Negative ELBO at step 2500: 67.06253966358706 in 260.8458s
# Beginning evaluation 15
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 15: Next query is [[1.         0.         0.        ]
#  [0.9919055  0.9598744  0.13595882]] with EI value of [0.60011734]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 152119.83920036352 in 1.0280s
# Negative ELBO at step 500: 2471.668335469771 in 269.7136s
# Negative ELBO at step 1000: 828.1242064098652 in 276.2140s
# Negative ELBO at step 1500: 542.6486726954207 in 276.7231s
# Negative ELBO at step 2000: 318.4714467918052 in 283.5570s
# Negative ELBO at step 2500: 228.8862903864616 in 280.3806s
# Beginning evaluation 16
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 16: Next query is [[1.         0.         0.        ]
#  [0.9450778  0.87645654 0.03055841]] with EI value of [0.61247489]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 672004.2499209371 in 0.7060s
# Negative ELBO at step 500: 4628.068719848272 in 305.3147s
# Negative ELBO at step 1000: 2171.7700889785897 in 282.6247s
# Negative ELBO at step 1500: 1286.6065130347422 in 291.6128s
# Negative ELBO at step 2000: 724.4924439699867 in 288.7479s
# Negative ELBO at step 2500: 500.75819579639614 in 297.0988s
# Beginning evaluation 17
# Maximizer:
# [[1.         0.76767677 0.90909091]]
# Evaluation 17: Next query is [[1.         0.76767677 0.90909091]
#  [0.03499704 0.14569321 0.93756273]] with EI value of [1.43264325]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 150271.21265320768 in 0.6656s
# Negative ELBO at step 500: 2196.838941221458 in 296.6795s
# Negative ELBO at step 1000: 816.2559381105077 in 292.7460s
# Negative ELBO at step 1500: 408.63903179807085 in 299.0872s
# Negative ELBO at step 2000: 215.81219526315718 in 305.1497s
# Negative ELBO at step 2500: 151.97214476148676 in 300.3063s
# Beginning evaluation 18
# Maximizer:
# [[0.         0.94949495 0.26262626]]
# Evaluation 18: Next query is [[0.00000000e+00 9.49494949e-01 2.62626263e-01]
#  [6.43499460e-04 6.11946957e-02 3.55324220e-02]] with EI value of [0.69086364]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 102456.35488842557 in 0.7502s
# Negative ELBO at step 500: 1457.3198405830333 in 313.7165s
# Negative ELBO at step 1000: 564.0081113634672 in 316.8944s
# Negative ELBO at step 1500: 275.34930761626896 in 319.3940s
# Negative ELBO at step 2000: 181.1450689034084 in 311.1018s
# Negative ELBO at step 2500: 118.0546805299124 in 319.3742s
# Beginning evaluation 19
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 19: Next query is [[1.         0.         0.        ]
#  [0.99904486 0.98320911 0.86865004]] with EI value of [0.39673216]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 751382.5726379724 in 0.7355s
# Negative ELBO at step 500: 8544.852576123112 in 319.4071s
# Negative ELBO at step 1000: 3122.965015950187 in 327.9921s
# Negative ELBO at step 1500: 1688.800333144712 in 325.8200s
# Negative ELBO at step 2000: 1033.8608761528496 in 315.2453s
# Negative ELBO at step 2500: 765.0732640028513 in 325.9768s
# Beginning run 1
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 19.665197053781974 in 0.1607s
# Negative ELBO at step 500: 2.5233458251797494 in 64.8354s
# Negative ELBO at step 1000: 2.326731215707296 in 64.9663s
# Negative ELBO at step 1500: 2.159268011299629 in 61.9113s
# Negative ELBO at step 2000: 2.002056060282025 in 67.0426s
# Negative ELBO at step 2500: 2.0610705235493825 in 64.5520s
# Beginning evaluation 0
# Maximizer:
# [[0.55555556 1.         0.38383838]]
# Evaluation 0: Next query is [[0.55555556 1.         0.38383838]
#  [0.50918509 0.9826912  0.40495312]] with EI value of [0.37278329]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 18.00840278253737 in 0.1985s
# Negative ELBO at step 500: 3.1611298902299483 in 76.5755s
# Negative ELBO at step 1000: 2.7230323600490536 in 77.2521s
# Negative ELBO at step 1500: 2.7697301131417458 in 73.3325s
# Negative ELBO at step 2000: 2.782124686182481 in 76.9213s
# Negative ELBO at step 2500: 2.796732703998711 in 85.2178s
# Beginning evaluation 1
# Maximizer:
# [[0.39393939 1.         0.46464646]]
# Evaluation 1: Next query is [[0.39393939 1.         0.46464646]
#  [0.28735006 0.98433413 0.41100527]] with EI value of [0.37687309]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 31.240073382089903 in 0.2248s
# Negative ELBO at step 500: 4.028527952457354 in 91.8131s
# Negative ELBO at step 1000: 3.9498977067422727 in 96.3322s
# Negative ELBO at step 1500: 3.5596560664933357 in 78.0885s
# Negative ELBO at step 2000: 3.469552076995753 in 89.0450s
# Negative ELBO at step 2500: 3.509102495018154 in 87.1318s
# Beginning evaluation 2
# Maximizer:
# [[0.73737374 1.         0.54545455]]
# Evaluation 2: Next query is [[0.73737374 1.         0.54545455]
#  [0.7619591  0.98721036 0.51205373]] with EI value of [0.37518868]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 144.44787074425548 in 0.2730s
# Negative ELBO at step 500: 8.124134500167223 in 103.3619s
# Negative ELBO at step 1000: 5.062648721106333 in 99.5062s
# Negative ELBO at step 1500: 4.738642577821881 in 102.3482s
# Negative ELBO at step 2000: 4.835484927534447 in 103.8966s
# Negative ELBO at step 2500: 4.645501655763204 in 101.5272s
# Beginning evaluation 3
# Maximizer:
# [[0.85858586 1.         0.36363636]]
# Evaluation 3: Next query is [[0.85858586 1.         0.36363636]
#  [0.97118474 0.97598171 0.13147592]] with EI value of [0.31705465]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 274.25313059482954 in 0.3085s
# Negative ELBO at step 500: 12.003802870650985 in 121.5176s
# Negative ELBO at step 1000: 6.300404771629783 in 118.1293s
# Negative ELBO at step 1500: 5.836266984743377 in 118.1063s
# Negative ELBO at step 2000: 5.18296676415315 in 112.6083s
# Negative ELBO at step 2500: 5.434226213785237 in 117.2692s
# Beginning evaluation 4
# Maximizer:
# [[0.65656566 1.         0.        ]]
# Evaluation 4: Next query is [[0.65656566 1.         0.        ]
#  [0.83777765 0.97077005 0.04876954]] with EI value of [0.30619566]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 264.2220262961024 in 0.3080s
# Negative ELBO at step 500: 11.421548782187607 in 127.4182s
# Negative ELBO at step 1000: 8.185672106001547 in 137.3737s
# Negative ELBO at step 1500: 6.233981640368786 in 131.3671s
# Negative ELBO at step 2000: 5.958858029544578 in 124.3341s
# Negative ELBO at step 2500: 6.05947564001854 in 137.6087s
# Beginning evaluation 5
# Maximizer:
# [[0.83838384 1.         0.23232323]]
# Evaluation 5: Next query is [[0.83838384 1.         0.23232323]
#  [0.99627301 0.91265433 0.00992792]] with EI value of [0.33558088]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 514.4598049245024 in 0.8897s
# Negative ELBO at step 500: 22.592444895413372 in 145.8517s
# Negative ELBO at step 1000: 10.974557413974674 in 142.5990s
# Negative ELBO at step 1500: 8.602127261543192 in 141.7456s
# Negative ELBO at step 2000: 7.551942980243785 in 145.0837s
# Negative ELBO at step 2500: 6.706481983487654 in 145.4247s
# Beginning evaluation 6
# Maximizer:
# [[0.8989899  1.         0.02020202]]
# Evaluation 6: Next query is [[0.8989899  1.         0.02020202]
#  [0.84705056 0.96634746 0.06667913]] with EI value of [0.33015444]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 623.3364552600303 in 0.3633s
# Negative ELBO at step 500: 37.060107837549594 in 155.3933s
# Negative ELBO at step 1000: 14.756222549280466 in 153.7916s
# Negative ELBO at step 1500: 10.489809765388427 in 153.9261s
# Negative ELBO at step 2000: 8.388772664340275 in 155.4069s
# Negative ELBO at step 2500: 8.120668114440287 in 153.3284s
# Beginning evaluation 7
# Maximizer:
# [[1.         0.67676768 0.        ]]
# Evaluation 7: Next query is [[1.         0.67676768 0.        ]
#  [0.97407992 0.03171899 0.03505893]] with EI value of [0.30104247]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2331.033742048971 in 0.4172s
# Negative ELBO at step 500: 61.62783577733786 in 168.0286s
# Negative ELBO at step 1000: 28.116401455941663 in 171.0153s
# Negative ELBO at step 1500: 16.954819146984477 in 168.6649s
# Negative ELBO at step 2000: 12.097102264614314 in 176.3681s
# Negative ELBO at step 2500: 10.461520185860037 in 170.8314s
# Beginning evaluation 8
# Maximizer:
# [[1.         0.13131313 0.        ]]
# Evaluation 8: Next query is [[1.         0.13131313 0.        ]
#  [0.98773827 0.09453728 0.0103552 ]] with EI value of [0.35330009]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 6597.73065430359 in 0.4132s
# Negative ELBO at step 500: 174.03247451811131 in 181.3269s
# Negative ELBO at step 1000: 67.57801466958962 in 178.3522s
# Negative ELBO at step 1500: 34.4297979480369 in 186.5406s
# Negative ELBO at step 2000: 20.922468606792467 in 183.1815s
# Negative ELBO at step 2500: 18.628237803116868 in 186.0724s
# Beginning evaluation 9
# Maximizer:
# [[1.        0.1010101 0.       ]]
# Evaluation 9: Next query is [[1.         0.1010101  0.        ]
#  [0.06032924 0.05525525 0.13934219]] with EI value of [0.45070463]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 6613.390835946962 in 0.4488s
# Negative ELBO at step 500: 130.83056576164378 in 204.7235s
# Negative ELBO at step 1000: 57.14237636415854 in 204.2381s
# Negative ELBO at step 1500: 32.02646072082114 in 186.1608s
# Negative ELBO at step 2000: 27.18467919523344 in 194.4590s
# Negative ELBO at step 2500: 19.76322797819938 in 195.4937s
# Beginning evaluation 10
# Maximizer:
# [[1.         0.27272727 0.        ]]
# Evaluation 10: Next query is [[1.         0.27272727 0.        ]
#  [0.98876555 0.95462712 0.18836087]] with EI value of [0.38894801]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 14849.356766788886 in 0.5074s
# Negative ELBO at step 500: 256.48927347538273 in 205.8268s
# Negative ELBO at step 1000: 107.52675055653262 in 210.2054s
# Negative ELBO at step 1500: 45.34457839613007 in 210.2336s
# Negative ELBO at step 2000: 34.57656237462362 in 202.8373s
# Negative ELBO at step 2500: 25.37548171557558 in 209.8603s
# Beginning evaluation 11
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 11: Next query is [[1.         0.         0.        ]
#  [0.98439381 0.037001   0.04454101]] with EI value of [0.50422371]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 4179.5008138148005 in 0.5622s
# Negative ELBO at step 500: 126.10184494025535 in 227.2839s
# Negative ELBO at step 1000: 47.581287089869974 in 228.6781s
# Negative ELBO at step 1500: 30.163876887033727 in 230.0968s
# Negative ELBO at step 2000: 25.54840234684663 in 224.8419s
# Negative ELBO at step 2500: 16.05103082211925 in 224.5470s
# Beginning evaluation 12
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 12: Next query is [[1.         0.         0.        ]
#  [0.10065231 0.98560624 0.91286342]] with EI value of [0.33205217]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 8481.13001609139 in 0.6158s
# Negative ELBO at step 500: 238.75964997703747 in 225.4098s
# Negative ELBO at step 1000: 101.79541282760803 in 231.3310s
# Negative ELBO at step 1500: 52.862764286730766 in 231.4761s
# Negative ELBO at step 2000: 40.52999943679582 in 233.3319s
# Negative ELBO at step 2500: 22.3553139198757 in 235.2417s
# Beginning evaluation 13
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 13: Next query is [[1.         0.         0.        ]
#  [0.99632519 0.05448062 0.95658966]] with EI value of [0.40241416]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 706093.6042142033 in 0.5757s
# Negative ELBO at step 500: 7427.898793685422 in 242.2927s
# Negative ELBO at step 1000: 2914.799904644491 in 237.6424s
# Negative ELBO at step 1500: 1897.3793899056325 in 247.2630s
# Negative ELBO at step 2000: 1053.7351548881547 in 244.5926s
# Negative ELBO at step 2500: 759.9373377643885 in 243.5047s
# Beginning evaluation 14
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 14: Next query is [[1.         0.         0.        ]
#  [0.84960956 0.99160966 0.05493101]] with EI value of [2.1738121]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 61418.84826679758 in 0.6413s
# Negative ELBO at step 500: 1194.1077709428448 in 260.5981s
# Negative ELBO at step 1000: 388.35040323740975 in 254.2833s
# Negative ELBO at step 1500: 216.88713155671 in 242.9072s
# Negative ELBO at step 2000: 104.92742421378048 in 261.2884s
# Negative ELBO at step 2500: 79.52434460799164 in 262.6295s
# Beginning evaluation 15
# Maximizer:
# [[0. 1. 1.]]
# Evaluation 15: Next query is [[0.         1.         1.        ]
#  [0.96186572 0.19624857 0.05069741]] with EI value of [0.61294479]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 30983.677009844254 in 0.6565s
# Negative ELBO at step 500: 675.1967409508208 in 272.8790s
# Negative ELBO at step 1000: 268.3822561814793 in 275.4740s
# Negative ELBO at step 1500: 177.50659779864574 in 278.7364s
# Negative ELBO at step 2000: 89.95359049069856 in 268.0992s
# Negative ELBO at step 2500: 61.214021489892325 in 286.5180s
# Beginning evaluation 16
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 16: Next query is [[1.         0.         0.        ]
#  [0.03644394 0.00342549 0.04468548]] with EI value of [0.48200779]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 30579.01812051418 in 0.8864s
# Negative ELBO at step 500: 728.7473491660666 in 293.3045s
# Negative ELBO at step 1000: 262.663603557338 in 298.4967s
# Negative ELBO at step 1500: 142.11510125057907 in 285.0187s
# Negative ELBO at step 2000: 78.73387581715386 in 291.8262s
# Negative ELBO at step 2500: 64.1623658604521 in 283.3866s
# Beginning evaluation 17
# Maximizer:
# [[1.         0.16161616 0.        ]]
# Evaluation 17: Next query is [[1.         0.16161616 0.        ]
#  [0.01287952 0.89495156 0.93042167]] with EI value of [0.39044863]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 118646.84315834672 in 0.6735s
# Negative ELBO at step 500: 1789.5588934638697 in 304.2643s
# Negative ELBO at step 1000: 605.2882639425385 in 302.7497s
# Negative ELBO at step 1500: 349.62278211867635 in 304.1870s
# Negative ELBO at step 2000: 240.0698283868831 in 310.3069s
# Negative ELBO at step 2500: 136.00198160682962 in 301.4310s
# Beginning evaluation 18
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 18: Next query is [[1.         0.         0.        ]
#  [0.02221596 0.98278609 0.51843123]] with EI value of [0.68244554]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 158905.65396640846 in 0.8021s
# Negative ELBO at step 500: 2694.306939489874 in 319.5738s
# Negative ELBO at step 1000: 1223.751073791093 in 322.2315s
# Negative ELBO at step 1500: 608.1052255222709 in 319.0631s
# Negative ELBO at step 2000: 359.19983519920737 in 304.8705s
# Negative ELBO at step 2500: 236.86044120815023 in 318.3908s
# Beginning evaluation 19
# Maximizer:
# [[1.         0.01010101 0.        ]]
# Evaluation 19: Next query is [[1.00000000e+00 1.01010101e-02 0.00000000e+00]
#  [1.56952430e-01 9.98176846e-01 4.71618399e-04]] with EI value of [0.65566994]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 473126.89661543205 in 1.1258s
# Negative ELBO at step 500: 3829.566599337756 in 328.0213s
# Negative ELBO at step 1000: 1527.4836654325825 in 332.0931s
# Negative ELBO at step 1500: 826.4970399907639 in 330.1468s
# Negative ELBO at step 2000: 439.699295572972 in 327.9863s
# Negative ELBO at step 2500: 300.68434102601964 in 327.6205s
# Beginning run 2
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 5.638178347464526 in 0.1631s
# Negative ELBO at step 500: 2.461086073088487 in 52.8679s
# Negative ELBO at step 1000: 2.149235663841378 in 54.6032s
# Negative ELBO at step 1500: 2.211927512030171 in 66.9355s
# Negative ELBO at step 2000: 2.1685546866507415 in 75.1759s
# Negative ELBO at step 2500: 2.0977825223930595 in 52.9522s
# Beginning evaluation 0
# Maximizer:
# [[0.71717172 0.         0.68686869]]
# Evaluation 0: Next query is [[0.71717172 0.         0.68686869]
#  [0.73369835 0.0186812  0.69611264]] with EI value of [0.36019734]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7.6879873968521775 in 0.4712s
# Negative ELBO at step 500: 3.0191812694278077 in 81.2719s
# Negative ELBO at step 1000: 2.9520017344788743 in 83.9219s
# Negative ELBO at step 1500: 2.9544147991198315 in 63.5015s
# Negative ELBO at step 2000: 2.9302612781585733 in 68.2333s
# Negative ELBO at step 2500: 2.8096248361556735 in 78.1778s
# Beginning evaluation 1
# Maximizer:
# [[0.86868687 0.07070707 0.67676768]]
# Evaluation 1: Next query is [[0.86868687 0.07070707 0.67676768]
#  [0.80067241 0.05306949 0.75952094]] with EI value of [0.35470449]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 259.0917545654516 in 0.2410s
# Negative ELBO at step 500: 9.804153962094416 in 93.6791s
# Negative ELBO at step 1000: 5.14235201341671 in 85.3803s
# Negative ELBO at step 1500: 3.973563745879877 in 92.5737s
# Negative ELBO at step 2000: 4.082083536647387 in 93.2574s
# Negative ELBO at step 2500: 3.872882852465633 in 85.7641s
# Beginning evaluation 2
# Maximizer:
# [[0.82828283 0.         0.3030303 ]]
# Evaluation 2: Next query is [[0.82828283 0.         0.3030303 ]
#  [0.88342382 0.03323632 0.0946884 ]] with EI value of [0.35513445]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1174.9866926982606 in 0.3412s
# Negative ELBO at step 500: 20.10387917224585 in 99.5467s
# Negative ELBO at step 1000: 7.8748623161510425 in 100.9598s
# Negative ELBO at step 1500: 7.5196934634995705 in 108.6944s
# Negative ELBO at step 2000: 6.192278876939536 in 98.5608s
# Negative ELBO at step 2500: 5.759270102289311 in 100.6544s
# Beginning evaluation 3
# Maximizer:
# [[1.         0.11111111 0.14141414]]
# Evaluation 3: Next query is [[1.         0.11111111 0.14141414]
#  [0.03382078 0.18681958 0.12443592]] with EI value of [0.37658539]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 483.2186284943023 in 0.2634s
# Negative ELBO at step 500: 12.415488257473907 in 111.9959s
# Negative ELBO at step 1000: 7.395885312326494 in 112.4606s
# Negative ELBO at step 1500: 6.269854135446233 in 123.0107s
# Negative ELBO at step 2000: 5.789708469072427 in 101.6246s
# Negative ELBO at step 2500: 5.35869612028726 in 124.1915s
# Beginning evaluation 4
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 4: Next query is [[0.         0.         0.        ]
#  [0.06876434 0.02147061 0.07410452]] with EI value of [0.33146425]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 644.2202979676679 in 0.4405s
# Negative ELBO at step 500: 17.455353017461817 in 129.6919s
# Negative ELBO at step 1000: 9.720727218227932 in 129.8444s
# Negative ELBO at step 1500: 7.8544258468974215 in 133.5196s
# Negative ELBO at step 2000: 7.246218159735703 in 121.2714s
# Negative ELBO at step 2500: 6.619747197975681 in 137.9888s
# Beginning evaluation 5
# Maximizer:
# [[0.         0.01010101 0.09090909]]
# Evaluation 5: Next query is [[0.         0.01010101 0.09090909]
#  [0.00058394 0.01766234 0.03808144]] with EI value of [0.36064762]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 568.0822263061107 in 0.3103s
# Negative ELBO at step 500: 21.695811227513484 in 141.3030s
# Negative ELBO at step 1000: 9.715932293500101 in 153.4257s
# Negative ELBO at step 1500: 7.781049414711513 in 141.2524s
# Negative ELBO at step 2000: 7.167345471237764 in 141.7790s
# Negative ELBO at step 2500: 7.085471211465185 in 137.1015s
# Beginning evaluation 6
# Maximizer:
# [[0.         0.04040404 0.2020202 ]]
# Evaluation 6: Next query is [[0.00000000e+00 4.04040404e-02 2.02020202e-01]
#  [1.13898532e-02 2.82572460e-04 2.89672828e-01]] with EI value of [0.34664587]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 3450.5921728205435 in 0.3745s
# Negative ELBO at step 500: 61.44294513578111 in 152.2602s
# Negative ELBO at step 1000: 25.99365965034299 in 154.7763s
# Negative ELBO at step 1500: 17.126481729178032 in 157.1947s
# Negative ELBO at step 2000: 12.035748104554774 in 153.2243s
# Negative ELBO at step 2500: 11.66506549588355 in 155.7780s
# Beginning evaluation 7
# Maximizer:
# [[0.         0.29292929 0.        ]]
# Evaluation 7: Next query is [[0.         0.29292929 0.        ]
#  [0.05781157 0.98221278 0.00385026]] with EI value of [0.39698299]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2248.0372058297835 in 0.6798s
# Negative ELBO at step 500: 68.83439153625692 in 168.7632s
# Negative ELBO at step 1000: 29.717118217019618 in 170.6105s
# Negative ELBO at step 1500: 18.912879464560092 in 174.3415s
# Negative ELBO at step 2000: 13.069484331266533 in 172.5214s
# Negative ELBO at step 2500: 11.31419674329297 in 177.4266s
# Beginning evaluation 8
# Maximizer:
# [[0.         0.07070707 0.        ]]
# Evaluation 8: Next query is [[0.         0.07070707 0.        ]
#  [0.02366702 0.11999901 0.01064001]] with EI value of [0.32249577]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 23558.848552572243 in 0.5314s
# Negative ELBO at step 500: 323.8395382051005 in 178.4023s
# Negative ELBO at step 1000: 100.31859273829605 in 180.5025s
# Negative ELBO at step 1500: 62.09316702640858 in 182.5898s
# Negative ELBO at step 2000: 32.96759194495752 in 188.1569s
# Negative ELBO at step 2500: 26.55586026910199 in 180.2717s
# Beginning evaluation 9
# Maximizer:
# [[0.         0.02020202 0.        ]]
# Evaluation 9: Next query is [[0.         0.02020202 0.        ]
#  [0.15493605 0.93965042 0.98803393]] with EI value of [0.57806228]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2965.6864086968667 in 0.4609s
# Negative ELBO at step 500: 73.07936547837458 in 181.3050s
# Negative ELBO at step 1000: 29.737626431325268 in 193.2864s
# Negative ELBO at step 1500: 19.86509251298459 in 191.1518s
# Negative ELBO at step 2000: 13.469542007192473 in 193.7729s
# Negative ELBO at step 2500: 12.874887572344825 in 201.4632s
# Beginning evaluation 10
# Maximizer:
# [[0.         0.14141414 0.        ]]
# Evaluation 10: Next query is [[0.         0.14141414 0.        ]
#  [0.04011742 0.06941244 0.04898104]] with EI value of [0.35643587]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 14246.66994277283 in 0.7307s
# Negative ELBO at step 500: 333.6619607886384 in 209.2461s
# Negative ELBO at step 1000: 114.53332384676199 in 214.5535s
# Negative ELBO at step 1500: 66.76657017670198 in 204.9076s
# Negative ELBO at step 2000: 46.994407516124134 in 210.5096s
# Negative ELBO at step 2500: 36.39903261752664 in 206.2658s
# Beginning evaluation 11
# Maximizer:
# [[0.         0.07070707 0.        ]]
# Evaluation 11: Next query is [[0.         0.07070707 0.        ]
#  [0.98631642 0.75170607 0.01099973]] with EI value of [0.41836477]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 9735.05084439756 in 1.0009s
# Negative ELBO at step 500: 188.9889943267404 in 232.0620s
# Negative ELBO at step 1000: 73.25618257882611 in 223.3266s
# Negative ELBO at step 1500: 49.157415809221185 in 227.2464s
# Negative ELBO at step 2000: 27.020032514690747 in 223.3588s
# Negative ELBO at step 2500: 22.438544216488403 in 227.3468s
# Beginning evaluation 12
# Maximizer:
# [[0.         0.14141414 0.        ]]
# Evaluation 12: Next query is [[0.         0.14141414 0.        ]
#  [0.99091681 0.02937577 0.86832147]] with EI value of [0.46112962]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 21382.294975237684 in 0.8664s
# Negative ELBO at step 500: 293.54867427990524 in 233.8367s
# Negative ELBO at step 1000: 141.0880535167569 in 232.0635s
# Negative ELBO at step 1500: 74.72486459414064 in 237.3929s
# Negative ELBO at step 2000: 47.79529408068335 in 234.3175s
# Negative ELBO at step 2500: 34.27626707711556 in 238.1157s
# Beginning evaluation 13
# Maximizer:
# [[0.         0.02020202 0.        ]]
# Evaluation 13: Next query is [[0.         0.02020202 0.        ]
#  [0.99681938 0.66567044 0.00240647]] with EI value of [0.44667033]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 15930.15568947123 in 0.6043s
# Negative ELBO at step 500: 327.4251820381907 in 252.8128s
# Negative ELBO at step 1000: 132.04954425550017 in 259.5369s
# Negative ELBO at step 1500: 64.12342729606434 in 246.6809s
# Negative ELBO at step 2000: 41.00309559449567 in 253.9851s
# Negative ELBO at step 2500: 34.56153482095671 in 251.6397s
# Beginning evaluation 14
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 14: Next query is [[0.         0.         0.        ]
#  [0.01749025 0.04989342 0.91128284]] with EI value of [0.30812276]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 35469.666688835474 in 0.7474s
# Negative ELBO at step 500: 764.44483490507 in 262.9876s
# Negative ELBO at step 1000: 263.9723323521997 in 257.6165s
# Negative ELBO at step 1500: 161.02069953760272 in 255.7978s
# Negative ELBO at step 2000: 92.95615616688697 in 263.7997s
# Negative ELBO at step 2500: 62.18014669663712 in 264.8074s
# Beginning evaluation 15
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 15: Next query is [[0.         0.         0.        ]
#  [0.01883947 0.9559347  0.05164429]] with EI value of [0.43083308]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 15531.20563680676 in 0.7144s
# Negative ELBO at step 500: 411.6921373928075 in 274.9644s
# Negative ELBO at step 1000: 152.95134514609947 in 267.2965s
# Negative ELBO at step 1500: 76.06541749883826 in 272.8700s
# Negative ELBO at step 2000: 51.025860333621964 in 275.9513s
# Negative ELBO at step 2500: 34.83775171882467 in 278.5497s
# Beginning evaluation 16
# Maximizer:
# [[0.         0.19191919 0.        ]]
# Evaluation 16: Next query is [[0.         0.19191919 0.        ]
#  [0.59518096 0.00496469 0.95380454]] with EI value of [0.31585513]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 66025.85307618535 in 0.6634s
# Negative ELBO at step 500: 1519.0334275244325 in 295.9041s
# Negative ELBO at step 1000: 608.5900210117974 in 277.5323s
# Negative ELBO at step 1500: 294.97839238230006 in 287.1514s
# Negative ELBO at step 2000: 166.3396626726009 in 290.1641s
# Negative ELBO at step 2500: 103.18109750166647 in 287.0138s
# Beginning evaluation 17
# Maximizer:
# [[0.         0.09090909 0.        ]]
# Evaluation 17: Next query is [[0.         0.09090909 0.        ]
#  [0.24930005 0.02457625 0.95270822]] with EI value of [0.63230486]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 239123.46303985926 in 0.7736s
# Negative ELBO at step 500: 2804.250335246763 in 307.9726s
# Negative ELBO at step 1000: 1063.196172707786 in 299.0882s
# Negative ELBO at step 1500: 500.92360712199167 in 307.2991s
# Negative ELBO at step 2000: 295.6401310755938 in 305.0913s
# Negative ELBO at step 2500: 211.93050754193717 in 312.0240s
# Beginning evaluation 18
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 18: Next query is [[0.         0.         0.        ]
#  [0.94893351 0.04547139 0.07080836]] with EI value of [0.61198167]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 634008.2297801807 in 1.5320s
# Negative ELBO at step 500: 7866.472322788544 in 302.3989s
# Negative ELBO at step 1000: 2991.8078456354706 in 261.8013s
# Negative ELBO at step 1500: 1703.4559694389518 in 262.7605s
# Negative ELBO at step 2000: 1127.7050179001521 in 262.8748s
# Negative ELBO at step 2500: 670.173928977728 in 262.7476s
# Beginning evaluation 19
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 19: Next query is [[0.         0.         0.        ]
#  [0.94650979 0.91137236 0.98827787]] with EI value of [0.95079067]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 610109.6817048352 in 0.7591s
# Negative ELBO at step 500: 5407.05905573665 in 273.0116s
# Negative ELBO at step 1000: 2342.0539001054954 in 270.6628s
# Negative ELBO at step 1500: 1386.6296161108964 in 270.7310s
# Negative ELBO at step 2000: 747.4046713407125 in 271.4161s
# Negative ELBO at step 2500: 703.4841895495138 in 270.3079s
# Beginning run 3
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 26.548499017810634 in 0.1701s
# Negative ELBO at step 500: 2.612227628299484 in 53.2112s
# Negative ELBO at step 1000: 2.220309310093998 in 52.1877s
# Negative ELBO at step 1500: 2.2139507330808934 in 50.8440s
# Negative ELBO at step 2000: 1.9770887560585348 in 53.0243s
# Negative ELBO at step 2500: 2.08045015652539 in 52.7586s
# Beginning evaluation 0
# Maximizer:
# [[0.         0.46464646 0.31313131]]
# Evaluation 0: Next query is [[0.         0.46464646 0.31313131]
#  [0.00242963 0.44174118 0.34716203]] with EI value of [0.3641592]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 14.544794152956772 in 0.1656s
# Negative ELBO at step 500: 2.9203723793446246 in 64.0518s
# Negative ELBO at step 1000: 2.7278531278776352 in 63.0635s
# Negative ELBO at step 1500: 2.736445046226428 in 62.5132s
# Negative ELBO at step 2000: 2.6809773943804354 in 64.0457s
# Negative ELBO at step 2500: 2.6350197834519116 in 62.3781s
# Beginning evaluation 1
# Maximizer:
# [[0.08080808 0.98989899 0.50505051]]
# Evaluation 1: Next query is [[0.08080808 0.98989899 0.50505051]
#  [0.10726632 0.93341384 0.55991446]] with EI value of [0.38508717]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 87.15851856664865 in 0.2292s
# Negative ELBO at step 500: 5.871900764522847 in 73.3612s
# Negative ELBO at step 1000: 4.062916110533084 in 75.2244s
# Negative ELBO at step 1500: 3.6337658865667897 in 73.7522s
# Negative ELBO at step 2000: 3.6191917143468757 in 76.0975s
# Negative ELBO at step 2500: 3.4303481799693234 in 74.5556s
# Beginning evaluation 2
# Maximizer:
# [[0.         0.7979798  0.54545455]]
# Evaluation 2: Next query is [[0.         0.7979798  0.54545455]
#  [0.02986495 0.96285702 0.76383184]] with EI value of [0.35813305]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 285.50825548162373 in 0.2459s
# Negative ELBO at step 500: 9.579962581220212 in 83.6923s
# Negative ELBO at step 1000: 6.38592464555591 in 84.4548s
# Negative ELBO at step 1500: 5.07530789082115 in 82.4810s
# Negative ELBO at step 2000: 4.7006702015703645 in 87.1822s
# Negative ELBO at step 2500: 4.519621674655553 in 85.4427s
# Beginning evaluation 3
# Maximizer:
# [[0.        1.        0.2020202]]
# Evaluation 3: Next query is [[0.         1.         0.2020202 ]
#  [0.02448004 0.97717456 0.14140362]] with EI value of [0.35412661]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 170.8420109132159 in 0.2522s
# Negative ELBO at step 500: 9.76605176386646 in 94.0343s
# Negative ELBO at step 1000: 6.028798529373517 in 96.8887s
# Negative ELBO at step 1500: 5.436718113640515 in 94.4345s
# Negative ELBO at step 2000: 5.17229974147342 in 94.5639s
# Negative ELBO at step 2500: 4.945724522959947 in 97.0083s
# Beginning evaluation 4
# Maximizer:
# [[0.         0.77777778 0.22222222]]
# Evaluation 4: Next query is [[0.         0.77777778 0.22222222]
#  [0.04364037 0.98241958 0.0370155 ]] with EI value of [0.34028224]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1022.3662501038154 in 0.3256s
# Negative ELBO at step 500: 28.39058844766633 in 108.0804s
# Negative ELBO at step 1000: 11.805579939726456 in 108.9912s
# Negative ELBO at step 1500: 9.378225262732556 in 107.2947s
# Negative ELBO at step 2000: 7.1696732132570125 in 107.7509s
# Negative ELBO at step 2500: 6.713343782388246 in 108.9588s
# Beginning evaluation 5
# Maximizer:
# [[0.         1.         0.14141414]]
# Evaluation 5: Next query is [[0.         1.         0.14141414]
#  [0.02784481 0.99651345 0.92535954]] with EI value of [0.32060636]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 251.66429859190495 in 0.3423s
# Negative ELBO at step 500: 15.004004887849508 in 118.0179s
# Negative ELBO at step 1000: 8.956733805810737 in 120.5694s
# Negative ELBO at step 1500: 7.405955762017938 in 119.4722s
# Negative ELBO at step 2000: 6.90785134593078 in 118.7116s
# Negative ELBO at step 2500: 6.625726077437704 in 119.0716s
# Beginning evaluation 6
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 6: Next query is [[0.         1.         0.        ]
#  [0.03969918 0.89786565 0.0644204 ]] with EI value of [0.31644726]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 5164.966978236487 in 0.3227s
# Negative ELBO at step 500: 106.38184620744936 in 127.4558s
# Negative ELBO at step 1000: 46.8706674425439 in 130.7317s
# Negative ELBO at step 1500: 23.060543896835796 in 128.6810s
# Negative ELBO at step 2000: 18.874369860916424 in 129.0413s
# Negative ELBO at step 2500: 12.639469293501579 in 129.5172s
# Beginning evaluation 7
# Maximizer:
# [[0.         0.74747475 0.04040404]]
# Evaluation 7: Next query is [[0.         0.74747475 0.04040404]
#  [0.05958625 0.94604947 0.02858703]] with EI value of [0.3601663]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1719.4021538667675 in 0.4752s
# Negative ELBO at step 500: 49.847842409172465 in 142.0086s
# Negative ELBO at step 1000: 21.087966886785537 in 143.4500s
# Negative ELBO at step 1500: 13.068834505529075 in 142.0241s
# Negative ELBO at step 2000: 10.134267894469147 in 142.9416s
# Negative ELBO at step 2500: 9.086879537290894 in 140.4627s
# Beginning evaluation 8
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 8: Next query is [[0.         1.         0.        ]
#  [0.04459185 0.9499171  0.04998077]] with EI value of [0.28541113]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 6339.851658234821 in 0.4223s
# Negative ELBO at step 500: 125.78916844138325 in 152.9161s
# Negative ELBO at step 1000: 46.260934041699606 in 152.6904s
# Negative ELBO at step 1500: 24.823363969323417 in 151.9496s
# Negative ELBO at step 2000: 19.66253185461406 in 152.1037s
# Negative ELBO at step 2500: 14.502359244919152 in 153.2450s
# Beginning evaluation 9
# Maximizer:
# [[0.06060606 1.         0.        ]]
# Evaluation 9: Next query is [[0.06060606 1.         0.        ]
#  [0.00818707 0.03222656 0.03183269]] with EI value of [0.32225196]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 4434.064136850597 in 0.4028s
# Negative ELBO at step 500: 99.3181385492571 in 161.7413s
# Negative ELBO at step 1000: 53.69892496533254 in 165.1803s
# Negative ELBO at step 1500: 30.437786086317967 in 164.4075s
# Negative ELBO at step 2000: 18.714477497041877 in 164.6890s
# Negative ELBO at step 2500: 14.45101140660594 in 163.2949s
# Beginning evaluation 10
# Maximizer:
# [[0.05050505 1.         0.        ]]
# Evaluation 10: Next query is [[0.05050505 1.         0.        ]
#  [0.03198988 0.98199966 0.04201114]] with EI value of [0.3513454]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2698.611534300152 in 0.4778s
# Negative ELBO at step 500: 84.66547565902296 in 175.3330s
# Negative ELBO at step 1000: 35.7266696810928 in 171.9912s
# Negative ELBO at step 1500: 20.38570999176796 in 171.4015s
# Negative ELBO at step 2000: 17.307620314815324 in 169.8707s
# Negative ELBO at step 2500: 13.286393542682202 in 174.4560s
# Beginning evaluation 11
# Maximizer:
# [[0.04040404 1.         0.        ]]
# Evaluation 11: Next query is [[0.04040404 1.         0.        ]
#  [0.01728536 0.93991811 0.0246421 ]] with EI value of [0.28169195]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7618.722244745961 in 0.5105s
# Negative ELBO at step 500: 167.27299748196975 in 184.8692s
# Negative ELBO at step 1000: 79.30984586658157 in 183.9455s
# Negative ELBO at step 1500: 41.680903173090805 in 186.8712s
# Negative ELBO at step 2000: 30.45926401276089 in 188.5057s
# Negative ELBO at step 2500: 22.12532290254177 in 187.1297s
# Beginning evaluation 12
# Maximizer:
# [[0.01010101 1.         0.        ]]
# Evaluation 12: Next query is [[0.01010101 1.         0.        ]
#  [0.99905976 0.96905504 0.01466823]] with EI value of [0.2899149]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 26872.7496637552 in 0.5877s
# Negative ELBO at step 500: 483.21215031619977 in 195.7503s
# Negative ELBO at step 1000: 217.18962534748954 in 196.3344s
# Negative ELBO at step 1500: 115.37292065060942 in 197.4867s
# Negative ELBO at step 2000: 64.51027532978097 in 195.5400s
# Negative ELBO at step 2500: 44.39015218469079 in 196.6389s
# Beginning evaluation 13
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 13: Next query is [[0.         1.         0.        ]
#  [0.0317121  0.11769334 0.97499435]] with EI value of [0.54760188]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7697.816088221642 in 0.6314s
# Negative ELBO at step 500: 206.94052752413245 in 209.4772s
# Negative ELBO at step 1000: 73.49063831513942 in 209.4525s
# Negative ELBO at step 1500: 43.88562375922291 in 207.3893s
# Negative ELBO at step 2000: 25.461920572223143 in 209.8961s
# Negative ELBO at step 2500: 21.789937928619743 in 208.6991s
# Beginning evaluation 14
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 14: Next query is [[0.         1.         0.        ]
#  [0.01595469 0.97589503 0.0244791 ]] with EI value of [0.31954931]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 48562.74134048547 in 0.7031s
# Negative ELBO at step 500: 1244.0899221604252 in 218.3504s
# Negative ELBO at step 1000: 418.2607223580145 in 217.9428s
# Negative ELBO at step 1500: 220.44763714024924 in 216.7410s
# Negative ELBO at step 2000: 141.046840092894 in 219.8053s
# Negative ELBO at step 2500: 97.73968082180149 in 220.3115s
# Beginning evaluation 15
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 15: Next query is [[0.         1.         0.        ]
#  [0.13819959 0.91002998 0.00155207]] with EI value of [0.51031524]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 39533.47184929651 in 0.6769s
# Negative ELBO at step 500: 723.1908648474224 in 231.3345s
# Negative ELBO at step 1000: 292.46635766169413 in 230.8040s
# Negative ELBO at step 1500: 170.91633604501396 in 230.7726s
# Negative ELBO at step 2000: 87.25892024058136 in 233.7761s
# Negative ELBO at step 2500: 59.44937317591131 in 228.6819s
# Beginning evaluation 16
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 16: Next query is [[0.         1.         0.        ]
#  [0.05351025 0.98304384 0.01206908]] with EI value of [0.44243669]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 38945.58987828904 in 0.6556s
# Negative ELBO at step 500: 866.617671094197 in 237.6121s
# Negative ELBO at step 1000: 327.1585617269562 in 244.0346s
# Negative ELBO at step 1500: 149.02090659701335 in 242.4493s
# Negative ELBO at step 2000: 101.39053898883157 in 239.9332s
# Negative ELBO at step 2500: 61.13250133900584 in 240.5612s
# Beginning evaluation 17
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 17: Next query is [[0.         1.         0.        ]
#  [0.00170967 0.98464194 0.68205043]] with EI value of [0.50518201]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 45462.4755537007 in 0.7231s
# Negative ELBO at step 500: 1117.273236140956 in 252.8363s
# Negative ELBO at step 1000: 432.23308830776983 in 252.6224s
# Negative ELBO at step 1500: 202.20047473943998 in 255.5837s
# Negative ELBO at step 2000: 144.45967523541236 in 252.9584s
# Negative ELBO at step 2500: 77.98137808673344 in 253.5420s
# Beginning evaluation 18
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 18: Next query is [[0.         1.         0.        ]
#  [0.01869681 0.97685445 0.21695474]] with EI value of [0.41194973]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 155202.03540824982 in 0.8146s
# Negative ELBO at step 500: 2247.265277189916 in 263.0494s
# Negative ELBO at step 1000: 885.4022511167387 in 265.0090s
# Negative ELBO at step 1500: 489.05967921013774 in 263.8044s
# Negative ELBO at step 2000: 278.0996039837689 in 265.7401s
# Negative ELBO at step 2500: 175.87791628479047 in 264.6759s
# Beginning evaluation 19
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 19: Next query is [[0.         1.         0.        ]
#  [0.0929386  0.98976848 0.13551056]] with EI value of [0.7381459]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 232711.64534844932 in 0.8444s
# Negative ELBO at step 500: 2704.577751673334 in 277.3472s
# Negative ELBO at step 1000: 1290.60668378407 in 272.5955s
# Negative ELBO at step 1500: 754.9311260759282 in 273.8239s
# Negative ELBO at step 2000: 465.8596186291504 in 276.2896s
# Negative ELBO at step 2500: 336.47114925338695 in 275.3090s
# Beginning run 4
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 5.7199457508195355 in 0.1582s
# Negative ELBO at step 500: 2.1212048735235567 in 53.3443s
# Negative ELBO at step 1000: 2.0928576046521057 in 51.5681s
# Negative ELBO at step 1500: 2.0179761240920993 in 54.5153s
# Negative ELBO at step 2000: 1.923525441792074 in 52.3304s
# Negative ELBO at step 2500: 1.854618954901354 in 51.2114s
# Beginning evaluation 0
# Maximizer:
# [[0.58585859 0.71717172 1.        ]]
# Evaluation 0: Next query is [[0.58585859 0.71717172 1.        ]
#  [0.62203407 0.75249521 0.99622499]] with EI value of [0.42228434]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 15.174588735451376 in 0.1667s
# Negative ELBO at step 500: 3.065517747032819 in 64.3471s
# Negative ELBO at step 1000: 2.8260149814351445 in 62.4611s
# Negative ELBO at step 1500: 2.7908194738021916 in 65.1014s
# Negative ELBO at step 2000: 2.6713702462867683 in 62.6466s
# Negative ELBO at step 2500: 2.720017346524208 in 63.9820s
# Beginning evaluation 1
# Maximizer:
# [[0.25252525 0.96969697 1.        ]]
# Evaluation 1: Next query is [[0.25252525 0.96969697 1.        ]
#  [0.3038371  0.94413318 0.98306246]] with EI value of [0.38820984]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 55.045790121095926 in 0.2333s
# Negative ELBO at step 500: 4.821844022166548 in 72.6627s
# Negative ELBO at step 1000: 3.7186904544273847 in 76.1999s
# Negative ELBO at step 1500: 3.5256304321023126 in 73.8226s
# Negative ELBO at step 2000: 3.6500398045066844 in 74.3571s
# Negative ELBO at step 2500: 3.4894811275040905 in 72.0954s
# Beginning evaluation 2
# Maximizer:
# [[0.15151515 0.96969697 1.        ]]
# Evaluation 2: Next query is [[0.15151515 0.96969697 1.        ]
#  [0.07144296 0.98132193 0.92791029]] with EI value of [0.3715083]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 251.54049063996945 in 0.2235s
# Negative ELBO at step 500: 9.941548912703915 in 84.4241s
# Negative ELBO at step 1000: 6.490224422427383 in 86.3038s
# Negative ELBO at step 1500: 4.886931475564449 in 83.8239s
# Negative ELBO at step 2000: 4.69320990173538 in 87.1831s
# Negative ELBO at step 2500: 4.31317757624711 in 86.4238s
# Beginning evaluation 3
# Maximizer:
# [[0.56565657 0.7979798  1.        ]]
# Evaluation 3: Next query is [[0.56565657 0.7979798  1.        ]
#  [0.79277451 0.90516287 0.9916984 ]] with EI value of [0.37665789]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 134.3412701604947 in 0.3005s
# Negative ELBO at step 500: 8.503125801089997 in 96.0021s
# Negative ELBO at step 1000: 5.760132665274278 in 96.1631s
# Negative ELBO at step 1500: 5.183713116718758 in 96.8934s
# Negative ELBO at step 2000: 5.187619448846057 in 96.2826s
# Negative ELBO at step 2500: 4.9641502233252535 in 97.5693s
# Beginning evaluation 4
# Maximizer:
# [[0.72727273 1.         1.        ]]
# Evaluation 4: Next query is [[0.72727273 1.         1.        ]
#  [0.78308748 0.96303207 0.99710617]] with EI value of [0.33282954]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 339.6917434994527 in 0.3624s
# Negative ELBO at step 500: 13.71436075944304 in 106.3153s
# Negative ELBO at step 1000: 7.909770697686168 in 109.4647s
# Negative ELBO at step 1500: 6.805452882228772 in 107.9718s
# Negative ELBO at step 2000: 6.08750896617754 in 106.4656s
# Negative ELBO at step 2500: 5.908942808325009 in 107.3138s
# Beginning evaluation 5
# Maximizer:
# [[1. 1. 1.]]
# Evaluation 5: Next query is [[1.         1.         1.        ]
#  [0.99118047 0.89970487 0.94364595]] with EI value of [0.28527195]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 656.0576659504065 in 0.3440s
# Negative ELBO at step 500: 22.584570432622222 in 118.6039s
# Negative ELBO at step 1000: 9.93315452364699 in 119.2047s
# Negative ELBO at step 1500: 7.79829534463604 in 121.2022s
# Negative ELBO at step 2000: 6.797208802873397 in 116.2159s
# Negative ELBO at step 2500: 6.794240739641392 in 117.2755s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-67e1c7356eb9> in <module>
#      40         model, inputs, u_mean, inducing_vars = train_and_visualize(X, y,
#      41                                                                    num_inducing_init + evaluation + 1,
# ---> 42                                                                    "Run_{}_Evaluation_{}".format(run, evaluation))
#      43
#      44         best_guess_results[run, evaluation, :] = best_guess(model)
#
# <ipython-input-6-4e02aba53f99> in train_and_visualize(X, y, num_inducing, title)
#       6                                                                          obj_low=objective_low,
#       7                                                                          obj_high=objective_high,
# ----> 8                                                                          num_steps=3000)
#       9     likelihood = gpflow.likelihoods.Gaussian()
#      10     model = PBO.models.learning.init_SVGP_fullcov(q_mu, q_sqrt, u, k, likelihood)
#
# ~/PBO/models/learning_stochastic.py in train_model_fullcov(X, y, num_inducing, obj_low, obj_high, lengthscale, num_steps, indifference_threshold)
#     371     try:
#     372         for i in range(num_steps):
# --> 373             optimizer.minimize(neg_elbo, var_list=trainable_vars)
#     374
#     375             if i % 500 == 0:
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/keras/optimizer_v2/optimizer_v2.py in minimize(self, loss, var_list, grad_loss, name)
#     314     """
#     315     grads_and_vars = self._compute_gradients(
# --> 316         loss, var_list=var_list, grad_loss=grad_loss)
#     317
#     318     return self.apply_gradients(grads_and_vars, name=name)
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/keras/optimizer_v2/optimizer_v2.py in _compute_gradients(self, loss, var_list, grad_loss)
#     353     var_list = nest.flatten(var_list)
#     354     with backend.name_scope(self._name + "/gradients"):
# --> 355       grads = tape.gradient(loss_value, var_list, grad_loss)
#     356
#     357       if hasattr(self, "clipnorm"):
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1027         output_gradients=output_gradients,
#    1028         sources_raw=flat_sources_raw,
# -> 1029         unconnected_gradients=unconnected_gradients)
#    1030
#    1031     if not self._persistent:
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      75       output_gradients,
#      76       sources_raw,
# ---> 77       compat.as_str(unconnected_gradients.value))
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices)
#     139     return [None] * num_inputs
#     140
# --> 141   return grad_fn(mock_op, *out_grads)
#     142
#     143
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/ops/array_grad.py in _GatherV2Grad(op, grad)
#     600
#     601     params_grad = _BatchGatherGrad(params_shape, values_transpose, indices,
# --> 602                                    batch_dims, params_shape[axis])
#     603
#     604     # Inverts the above transpose by moving dimension batch_dims back to its
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/ops/array_grad.py in _BatchGatherGrad(params_shape, values, indices, batch_dims, gather_dim_size)
#     506
#     507   # Axis is the first non-batch dimension.
# --> 508   indices_size = array_ops.expand_dims(array_ops.size(indices), 0)
#     509   if batch_dims:
#     510     values_shape = array_ops.shape(values)
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/util/dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/ops/array_ops.py in size(input, name, out_type)
#     629   @end_compatibility
#     630   """
# --> 631   return size_internal(input, name, optimize=True, out_type=out_type)
#     632
#     633
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/ops/array_ops.py in size_internal(input, name, optimize, out_type)
#     650           input,
#     651           (sparse_tensor.SparseTensor, sparse_tensor.SparseTensorValue))):
# --> 652     input = ops.convert_to_tensor(input)
#     653     np_out_type = out_type.as_numpy_dtype
#     654     num_elements = np.prod(input._shape_tuple(), dtype=np_out_type)  # pylint: disable=protected-access
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1261
#    1262
# -> 1263 def convert_to_tensor(value,
#    1264                       dtype=None,
#    1265                       name=None,
#
# KeyboardInterrupt:

# %%
pickle.dump((X_results, y_results, best_guess_results), open(results_dir + "Xybestguess.p", "wb"))

# %%
def dist(x, y):
    """
    x and y have shape (..., input_dims)
    """
    return np.sqrt(np.sum((x - y) * (x - y), axis=-1))

xx = uniform_grid(input_dims, num_discrete_per_dim, low=objective_low, high=objective_high)
global_min = xx[np.argmin(objective(xx))][0]

for i in range(best_guess_results.shape[0]):
    diff_from_min = dist(best_guess_results[i], global_min)
    
    x_axis = list(range(num_combs+1, num_combs+1+num_evals))
    plt.figure(figsize=(12, 6))
    plt.plot(x_axis, diff_from_min, 'kx', mew=2)
    plt.xticks(x_axis)
    plt.xlabel('Evaluations', fontsize=18)
    plt.ylabel('Best guess distance', fontsize=16)
    plt.title("Run %s" % i)
    plt.show()
