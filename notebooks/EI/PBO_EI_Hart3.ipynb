# %% [markdown]
# # Preferential Bayesian Optimization: EI
# This notebook demonstrates the use of the Expected Improvement (EI) acquisition function on ordinal (preference) data.
#
# Formulation by Nguyen Quoc Phong.

# %%
import numpy as np
import gpflow
import tensorflow as tf
import matplotlib.pyplot as plt
import sys
import os
import pickle

from gpflow.utilities import set_trainable, print_summary
gpflow.config.set_default_summary_fmt("notebook")

sys.path.append(os.path.split(os.path.split(os.path.split(os.getcwd())[0])[0])[0]) # Move 3 levels up directory to import PBO
import PBO

# %%
objective = PBO.objectives.hartmann3d
objective_low = 0
objective_high = 1.
objective_name = "Hart3"
acquisition_name = "EI"
experiment_name = "PBO" + "_" + acquisition_name + "_" + objective_name

# %%
num_runs = 20
num_evals = 20
num_samples = 1000
num_choices = 2
input_dims = 3
num_maximizers = 20
num_init_points = 3
num_inducing_init = 3
num_discrete_per_dim = 100 # Discretization of continuous input space

# %%
results_dir = os.getcwd() + '/results/' + experiment_name + '/'

try:
    # Create target Directory
    os.makedirs(results_dir)
    print("Directory " , results_dir ,  " created ") 
except FileExistsError:
    print("Directory " , results_dir ,  " already exists")
# Out:
# Directory  /home/sebtsh/PBO/notebooks/EI/results/PBO_EI_Hart3/  created

# %%
def get_noisy_observation(X, objective):
    f = PBO.objectives.objective_get_f_neg(X, objective)
    return PBO.observation_model.gen_observation_from_f(X, f, 1)

# %%
def train_and_visualize(X, y, num_inducing, title):
    
    # Train model with data
    q_mu, q_sqrt, u, inputs, k, indifference_threshold = PBO.models.learning_stochastic.train_model_fullcov(X, y, 
                                                                         num_inducing=num_inducing,
                                                                         obj_low=objective_low,
                                                                         obj_high=objective_high,
                                                                         num_steps=3000)
    likelihood = gpflow.likelihoods.Gaussian()
    model = PBO.models.learning.init_SVGP_fullcov(q_mu, q_sqrt, u, k, likelihood)
    u_mean = q_mu.numpy()
    inducing_vars = u.numpy()
    
    return model, inputs, u_mean, inducing_vars

# %%
def uniform_grid(input_dims, num_discrete_per_dim, low=0., high=1.):
    """
    Returns an array with all possible permutations of discrete values in input_dims number of dimensions.
    :param input_dims: int
    :param num_discrete_per_dim: int
    :param low: int
    :param high: int
    :return: tensor of shape (num_discrete_per_dim ** input_dims, input_dims)
    """
    num_points = num_discrete_per_dim ** input_dims
    out = np.zeros([num_points, input_dims])
    discrete_points = np.linspace(low, high, num_discrete_per_dim)
    for i in range(num_points):
        for dim in range(input_dims):
            val = num_discrete_per_dim ** (dim)
            out[i, dim] = discrete_points[int((i // val) % num_discrete_per_dim)]
    return out

# %% [markdown]
# This function is our main metric for the performance of the acquisition function: The closer the model's best guess to the global minimum, the better.

# %%
def best_guess(model):
    """
    Returns a GP model's best guess of the global maximum of f.
    """
    xx = uniform_grid(input_dims, num_discrete_per_dim, low=objective_low, high=objective_high)
    res = model.predict_f(xx)[0].numpy()
    return xx[np.argmax(res)]

# %% [markdown]
# Store the results in these arrays:

# %%
num_data_at_end = int((num_init_points-1) * num_init_points / 2 + num_evals)
X_results = np.zeros([num_runs, num_data_at_end, num_choices, input_dims])
y_results = np.zeros([num_runs, num_data_at_end, 1, input_dims])
best_guess_results = np.zeros([num_runs, num_evals, input_dims])

# %%
y_results = np.zeros([num_runs, num_data_at_end, 1, input_dims])  # REMOVE LATER

# %%
X_results[0] = X
y_results[0] = y

# %% [markdown]
# Create the initial values for each run:

# %%
np.random.seed(0)
init_points = np.random.uniform(low=objective_low, high=objective_high, size=[num_runs, num_init_points, input_dims])
num_combs = int((num_init_points-1) * num_init_points / 2)
init_vals = np.zeros([num_runs, num_combs, num_choices, input_dims])
for run in range(num_runs):
    cur_idx = 0
    for init_point in range(num_init_points-1):
        for next_point in range(init_point+1, num_init_points):
            init_vals[run, cur_idx, 0] = init_points[run, init_point]
            init_vals[run, cur_idx, 1] = init_points[run, next_point]
            cur_idx += 1

# %% [markdown]
# The following loops carry out the Bayesian optimization algorithm over a number of runs, with a fixed number of evaluations per run.

# %%
for run in range(1, num_runs):
    print("Beginning run %s" % (run))
    
    X = init_vals[run]
    y = get_noisy_observation(X, objective)
    
    model, inputs, u_mean, inducing_vars = train_and_visualize(X, y, num_inducing_init, "Run_{}:_Initial_model".format(run))

    for evaluation in range(num_evals):
        print("Beginning evaluation %s" % (evaluation)) 

        # Get incumbent maximizer
        maximizer = np.expand_dims(best_guess(model), axis=0)  # (1, input_dims)
        
        print("Maximizer:")
        print(maximizer)
        
        # Sample possible next input points. In EI, all queries are a pair with the incumbent maximizer as the 
        # first point and a next input point as the second point
        
        samples = np.random.uniform(low=objective_low,
                                    high=objective_high,
                                    size=(num_samples, input_dims))
        
        # Calculate EI vals
        ei_vals = PBO.acquisitions.ei.EI(model, maximizer, samples)
        
        # Select query that maximizes EI
        next_idx = np.argmax(ei_vals)
        next_query = np.zeros((num_choices, input_dims))
        next_query[0, :] = maximizer  # EI only works in binary choices
        next_query[1, :] = samples[next_idx]
        print("Evaluation %s: Next query is %s with EI value of %s" % (evaluation, next_query, ei_vals[next_idx]))

        X = np.concatenate([X, [next_query]])
        # Evaluate objective function
        y = np.concatenate([y, get_noisy_observation(np.expand_dims(next_query, axis=0), objective)], axis=0)
        
        print("Evaluation %s: Training model" % (evaluation))
        model, inputs, u_mean, inducing_vars = train_and_visualize(X, y, 
                                                                   num_inducing_init + evaluation + 1, 
                                                                   "Run_{}_Evaluation_{}".format(run, evaluation))

        best_guess_results[run, evaluation, :] = best_guess(model)
        
        pickle.dump((model.kernel.variance.numpy(), 
                     model.kernel.lengthscale.numpy(),
                     model.inducing_variable.Z.numpy(), 
                     model.q_mu.numpy(), 
                     model.q_sqrt.numpy()), 
                    open(results_dir + "Run_{}_Evaluation_{}_model.p".format(run, evaluation), "wb"))

    X_results[run] = X
    y_results[run] = y
# Out:
# Beginning run 1
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 17.61162698744452 in 0.1617s
# Negative ELBO at step 500: 2.691590149473259 in 49.1487s
# Negative ELBO at step 1000: 2.256588760208899 in 50.6158s
# Negative ELBO at step 1500: 2.207094527697997 in 52.1038s
# Negative ELBO at step 2000: 2.0786714979930876 in 50.7919s
# Negative ELBO at step 2500: 2.0539095958825944 in 52.0857s
# Beginning evaluation 0
# Maximizer:
# [[0.56565657 1.         0.38383838]]
# Evaluation 0: Next query is [[0.56565657 1.         0.38383838]
#  [0.50918509 0.9826912  0.40495312]] with EI value of [0.37292236]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 12.558429402954927 in 0.1720s
# Negative ELBO at step 500: 3.0835059611427194 in 61.6494s
# Negative ELBO at step 1000: 2.834242296873967 in 62.8874s
# Negative ELBO at step 1500: 2.71171377963912 in 62.4205s
# Negative ELBO at step 2000: 2.7383506787215213 in 62.6384s
# Negative ELBO at step 2500: 2.7656101972225753 in 63.9077s
# Beginning evaluation 1
# Maximizer:
# [[0.38383838 1.         0.44444444]]
# Evaluation 1: Next query is [[0.38383838 1.         0.44444444]
#  [0.28735006 0.98433413 0.41100527]] with EI value of [0.37770574]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 35.96285373417169 in 0.1827s
# Negative ELBO at step 500: 4.153618763388794 in 73.4345s
# Negative ELBO at step 1000: 3.8134411388327325 in 74.0490s
# Negative ELBO at step 1500: 3.6418683797219233 in 72.4148s
# Negative ELBO at step 2000: 3.4790727391042755 in 73.8317s
# Negative ELBO at step 2500: 3.4569122774736494 in 75.0361s
# Beginning evaluation 2
# Maximizer:
# [[0.6969697  1.         0.52525253]]
# Evaluation 2: Next query is [[0.6969697  1.         0.52525253]
#  [0.7619591  0.98721036 0.51205373]] with EI value of [0.37561629]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 129.2781616401923 in 0.2181s
# Negative ELBO at step 500: 6.706704185374109 in 84.1089s
# Negative ELBO at step 1000: 5.18543098825516 in 85.8609s
# Negative ELBO at step 1500: 4.751893782242142 in 83.7741s
# Negative ELBO at step 2000: 4.468609212247119 in 83.6266s
# Negative ELBO at step 2500: 4.515210417522607 in 83.2786s
# Beginning evaluation 3
# Maximizer:
# [[0.88888889 1.         0.34343434]]
# Evaluation 3: Next query is [[0.88888889 1.         0.34343434]
#  [0.97118474 0.97598171 0.13147592]] with EI value of [0.31796808]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 301.88693013900087 in 0.2427s
# Negative ELBO at step 500: 13.216716879530985 in 95.0397s
# Negative ELBO at step 1000: 7.224982258975995 in 96.6521s
# Negative ELBO at step 1500: 5.691672312352656 in 94.4072s
# Negative ELBO at step 2000: 5.488608533615335 in 95.4040s
# Negative ELBO at step 2500: 5.1338548918370925 in 95.6319s
# Beginning evaluation 4
# Maximizer:
# [[0.66666667 1.         0.05050505]]
# Evaluation 4: Next query is [[0.66666667 1.         0.05050505]
#  [0.99618768 0.98004754 0.65574418]] with EI value of [0.30461963]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 226.76176501196048 in 0.3089s
# Negative ELBO at step 500: 13.399156432579389 in 108.5432s
# Negative ELBO at step 1000: 7.522669455474628 in 105.9790s
# Negative ELBO at step 1500: 6.355753951535681 in 104.8277s
# Negative ELBO at step 2000: 6.266036350319526 in 107.0441s
# Negative ELBO at step 2500: 5.951038862839598 in 105.9561s
# Beginning evaluation 5
# Maximizer:
# [[1.         1.         0.80808081]]
# Evaluation 5: Next query is [[1.         1.         0.80808081]
#  [0.97766303 0.98318665 0.84030162]] with EI value of [0.33221197]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 574.8131551716413 in 0.3379s
# Negative ELBO at step 500: 17.990988313861255 in 122.8700s
# Negative ELBO at step 1000: 10.65509693594091 in 117.5581s
# Negative ELBO at step 1500: 8.4744004846093 in 117.3161s
# Negative ELBO at step 2000: 7.521154837007268 in 116.5263s
# Negative ELBO at step 2500: 6.961858092769445 in 118.0044s
# Beginning evaluation 6
# Maximizer:
# [[0.84848485 1.         0.73737374]]
# Evaluation 6: Next query is [[0.84848485 1.         0.73737374]
#  [0.95077161 0.99122024 0.82922513]] with EI value of [0.29718652]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 804.6121136462634 in 0.3460s
# Negative ELBO at step 500: 28.440133119505823 in 132.0009s
# Negative ELBO at step 1000: 16.966888801780513 in 128.5379s
# Negative ELBO at step 1500: 11.13083086497685 in 128.2129s
# Negative ELBO at step 2000: 8.645089545963685 in 128.6578s
# Negative ELBO at step 2500: 8.100805717637702 in 126.9768s
# Beginning evaluation 7
# Maximizer:
# [[1.         1.         0.91919192]]
# Evaluation 7: Next query is [[1.         1.         0.91919192]
#  [0.94402617 0.97454205 0.90754638]] with EI value of [0.33603968]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2838.899996460137 in 0.3686s
# Negative ELBO at step 500: 53.45570255772009 in 143.1770s
# Negative ELBO at step 1000: 28.79984461678624 in 142.7988s
# Negative ELBO at step 1500: 14.893307870307478 in 140.1428s
# Negative ELBO at step 2000: 12.023680993068956 in 141.3140s
# Negative ELBO at step 2500: 9.51767223286533 in 140.9979s
# Beginning evaluation 8
# Maximizer:
# [[1.         0.91919192 0.92929293]]
# Evaluation 8: Next query is [[1.         0.91919192 0.92929293]
#  [0.98587516 0.9336223  0.90526992]] with EI value of [0.3664927]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7862.177745133446 in 0.4424s
# Negative ELBO at step 500: 135.62135817676156 in 150.7688s
# Negative ELBO at step 1000: 67.46188136949627 in 152.6066s
# Negative ELBO at step 1500: 30.031349500661754 in 151.6876s
# Negative ELBO at step 2000: 24.306737879376787 in 149.6572s
# Negative ELBO at step 2500: 17.007464899373822 in 150.7647s
# Beginning evaluation 9
# Maximizer:
# [[1.         0.94949495 1.        ]]
# Evaluation 9: Next query is [[1.         0.94949495 1.        ]
#  [0.90876224 0.84539788 0.01236294]] with EI value of [0.42118949]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 6137.700511825065 in 0.5351s
# Negative ELBO at step 500: 169.04523072194425 in 162.6275s
# Negative ELBO at step 1000: 53.81884127113434 in 168.0285s
# Negative ELBO at step 1500: 35.27514210499023 in 164.5996s
# Negative ELBO at step 2000: 23.718414797136955 in 163.1939s
# Negative ELBO at step 2500: 16.24108099455489 in 164.3490s
# Beginning evaluation 10
# Maximizer:
# [[0.76767677 1.         1.        ]]
# Evaluation 10: Next query is [[0.76767677 1.         1.        ]
#  [0.01084312 0.04958827 0.03750542]] with EI value of [0.37471681]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 11334.592846922753 in 0.4099s
# Negative ELBO at step 500: 248.59315415145036 in 171.1228s
# Negative ELBO at step 1000: 97.76378580915713 in 175.8937s
# Negative ELBO at step 1500: 51.80930999081525 in 172.5358s
# Negative ELBO at step 2000: 36.80792483414463 in 172.2716s
# Negative ELBO at step 2500: 26.76806025020148 in 174.3326s
# Beginning evaluation 11
# Maximizer:
# [[1. 1. 1.]]
# Evaluation 11: Next query is [[1.         1.         1.        ]
#  [0.98439381 0.037001   0.04454101]] with EI value of [0.40623883]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 4353.834269646485 in 0.5577s
# Negative ELBO at step 500: 124.78481154940451 in 184.0361s
# Negative ELBO at step 1000: 53.00761101340523 in 186.7505s
# Negative ELBO at step 1500: 32.07056145775639 in 185.4969s
# Negative ELBO at step 2000: 20.281922400260015 in 184.4331s
# Negative ELBO at step 2500: 19.143546719209176 in 186.3567s
# Beginning evaluation 12
# Maximizer:
# [[0.4040404 1.        1.       ]]
# Evaluation 12: Next query is [[0.4040404  1.         1.        ]
#  [0.10065231 0.98560624 0.91286342]] with EI value of [0.41024987]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 9996.332850799527 in 0.5459s
# Negative ELBO at step 500: 271.4002586222443 in 195.1838s
# Negative ELBO at step 1000: 100.8856484061619 in 195.3925s
# Negative ELBO at step 1500: 55.498303603528704 in 194.8208s
# Negative ELBO at step 2000: 31.36739828197857 in 192.5573s
# Negative ELBO at step 2500: 25.895956012738566 in 194.1972s
# Beginning evaluation 13
# Maximizer:
# [[1.         0.         0.17171717]]
# Evaluation 13: Next query is [[1.         0.         0.17171717]
#  [0.99632519 0.05448062 0.95658966]] with EI value of [0.43405732]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 829360.4983643367 in 0.5432s
# Negative ELBO at step 500: 8076.440096182777 in 204.1441s
# Negative ELBO at step 1000: 3095.008116798073 in 206.0096s
# Negative ELBO at step 1500: 1726.1018536209988 in 209.8674s
# Negative ELBO at step 2000: 936.4581822847244 in 205.1465s
# Negative ELBO at step 2500: 624.0143531384342 in 205.5991s
# Beginning evaluation 14
# Maximizer:
# [[1. 0. 0.]]
# Evaluation 14: Next query is [[1.         0.         0.        ]
#  [0.84960956 0.99160966 0.05493101]] with EI value of [2.04474917]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 51958.7428352869 in 0.5493s
# Negative ELBO at step 500: 904.4457527927708 in 216.1318s
# Negative ELBO at step 1000: 360.3303110019482 in 215.6646s
# Negative ELBO at step 1500: 178.3935139413908 in 216.3104s
# Negative ELBO at step 2000: 105.06938427871235 in 216.5745s
# Negative ELBO at step 2500: 54.64687211979768 in 217.0985s
# Beginning evaluation 15
# Maximizer:
# [[0.         1.         0.60606061]]
# Evaluation 15: Next query is [[0.         1.         0.60606061]
#  [0.49016787 0.02453868 0.01253913]] with EI value of [0.63206418]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 36137.09920573489 in 0.7412s
# Negative ELBO at step 500: 792.5204707828093 in 224.7825s
# Negative ELBO at step 1000: 287.2954235990844 in 227.0697s
# Negative ELBO at step 1500: 141.77151735950162 in 226.7264s
# Negative ELBO at step 2000: 83.95408578677673 in 229.5779s
# Negative ELBO at step 2500: 60.923499691143654 in 225.6052s
# Beginning evaluation 16
# Maximizer:
# [[0.         1.         0.53535354]]
# Evaluation 16: Next query is [[0.         1.         0.53535354]
#  [0.03644394 0.00342549 0.04468548]] with EI value of [0.46025533]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 30789.505539673937 in 0.6958s
# Negative ELBO at step 500: 626.6688042742182 in 239.0267s
# Negative ELBO at step 1000: 266.7127107148809 in 238.2554s
# Negative ELBO at step 1500: 145.8257128412514 in 239.8300s
# Negative ELBO at step 2000: 86.0542043510905 in 238.9147s
# Negative ELBO at step 2500: 70.93747956323678 in 238.3892s
# Beginning evaluation 17
# Maximizer:
# [[0.         1.         0.88888889]]
# Evaluation 17: Next query is [[0.         1.         0.88888889]
#  [0.01287952 0.89495156 0.93042167]] with EI value of [0.42790103]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 101421.27151280365 in 0.8686s
# Negative ELBO at step 500: 1761.6562621170206 in 249.3120s
# Negative ELBO at step 1000: 678.7208517047995 in 247.1476s
# Negative ELBO at step 1500: 308.7607103642097 in 252.7055s
# Negative ELBO at step 2000: 222.28331008363 in 248.6476s
# Negative ELBO at step 2500: 138.48809459327893 in 248.9376s
# Beginning evaluation 18
# Maximizer:
# [[0.         1.         0.53535354]]
# Evaluation 18: Next query is [[0.         1.         0.53535354]
#  [0.02221596 0.98278609 0.51843123]] with EI value of [0.68165377]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 228413.30140080428 in 0.7099s
# Negative ELBO at step 500: 2734.169761362302 in 260.9592s
# Negative ELBO at step 1000: 1221.3087117155656 in 261.3815s
# Negative ELBO at step 1500: 656.4170725816734 in 264.9551s
# Negative ELBO at step 2000: 414.0181264000181 in 263.5795s
# Negative ELBO at step 2500: 231.6769915713259 in 259.8401s
# Beginning evaluation 19
# Maximizer:
# [[0.         1.         0.42424242]]
# Evaluation 19: Next query is [[0.         1.         0.42424242]
#  [0.87035988 0.98491321 0.02476225]] with EI value of [0.62525917]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 396228.6263696427 in 0.7455s
# Negative ELBO at step 500: 4231.955415340375 in 270.0677s
# Negative ELBO at step 1000: 1332.8988345445857 in 271.2920s
# Negative ELBO at step 1500: 787.7009401903191 in 272.3560s
# Negative ELBO at step 2000: 494.7126894885117 in 268.8326s
# Negative ELBO at step 2500: 301.4986881277368 in 273.8407s
# Beginning run 2
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 6.901403611919593 in 0.1375s
# Negative ELBO at step 500: 2.353654510014082 in 52.2451s
# Negative ELBO at step 1000: 2.2896804919195444 in 51.0029s
# Negative ELBO at step 1500: 2.1709870543645122 in 50.8200s
# Negative ELBO at step 2000: 2.119837906196145 in 50.9687s
# Negative ELBO at step 2500: 2.0800788055670214 in 51.4982s
# Beginning evaluation 0
# Maximizer:
# [[0.66666667 0.         0.75757576]]
# Evaluation 0: Next query is [[0.66666667 0.         0.75757576]
#  [0.61778866 0.00558897 0.66870779]] with EI value of [0.36098374]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 6.698782786725697 in 0.1615s
# Negative ELBO at step 500: 3.058166687685782 in 63.8947s
# Negative ELBO at step 1000: 2.8419112290107225 in 61.8859s
# Negative ELBO at step 1500: 2.9152466411033378 in 62.2512s
# Negative ELBO at step 2000: 2.867528771382219 in 62.7874s
# Negative ELBO at step 2500: 2.8524996313083957 in 61.8277s
# Beginning evaluation 1
# Maximizer:
# [[0.7979798  0.05050505 0.45454545]]
# Evaluation 1: Next query is [[0.7979798  0.05050505 0.45454545]
#  [0.74224373 0.04350915 0.42385947]] with EI value of [0.35581461]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 288.02354427526257 in 0.2299s
# Negative ELBO at step 500: 9.313149260483549 in 73.3830s
# Negative ELBO at step 1000: 4.9177287085728345 in 74.9558s
# Negative ELBO at step 1500: 4.252752941858285 in 71.9781s
# Negative ELBO at step 2000: 3.768737198157296 in 73.4259s
# Negative ELBO at step 2500: 3.6881036816170476 in 73.3034s
# Beginning evaluation 2
# Maximizer:
# [[0.6969697  0.         0.29292929]]
# Evaluation 2: Next query is [[0.6969697  0.         0.29292929]
#  [0.88342382 0.03323632 0.0946884 ]] with EI value of [0.35358723]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 846.54293893369 in 0.2707s
# Negative ELBO at step 500: 18.80706171042928 in 84.4788s
# Negative ELBO at step 1000: 9.022309919176209 in 84.4237s
# Negative ELBO at step 1500: 7.793091357339576 in 83.8354s
# Negative ELBO at step 2000: 6.121155190429908 in 85.1088s
# Negative ELBO at step 2500: 5.275865609678473 in 85.6737s
# Beginning evaluation 3
# Maximizer:
# [[1.         0.13131313 0.22222222]]
# Evaluation 3: Next query is [[1.         0.13131313 0.22222222]
#  [0.03382078 0.18681958 0.12443592]] with EI value of [0.35517837]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 443.84623499817667 in 0.2936s
# Negative ELBO at step 500: 12.826695167700112 in 95.1828s
# Negative ELBO at step 1000: 8.099346076393958 in 97.3924s
# Negative ELBO at step 1500: 6.24586008089868 in 93.7596s
# Negative ELBO at step 2000: 5.690920833464588 in 97.9520s
# Negative ELBO at step 2500: 5.6440653592599626 in 95.7929s
# Beginning evaluation 4
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 4: Next query is [[0.         0.         0.        ]
#  [0.06876434 0.02147061 0.07410452]] with EI value of [0.33152209]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 725.3462214339712 in 0.3200s
# Negative ELBO at step 500: 17.854191474853792 in 106.9134s
# Negative ELBO at step 1000: 10.88847513088471 in 106.6777s
# Negative ELBO at step 1500: 7.398678895068024 in 106.2844s
# Negative ELBO at step 2000: 6.905797426389199 in 106.9408s
# Negative ELBO at step 2500: 6.602413454308113 in 106.6369s
# Beginning evaluation 5
# Maximizer:
# [[0.02020202 0.         0.08080808]]
# Evaluation 5: Next query is [[0.02020202 0.         0.08080808]
#  [0.00058394 0.01766234 0.03808144]] with EI value of [0.35911357]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 449.3282653481387 in 0.6061s
# Negative ELBO at step 500: 22.542818907109556 in 118.8758s
# Negative ELBO at step 1000: 9.68080837401631 in 120.2051s
# Negative ELBO at step 1500: 7.672679195372485 in 118.3243s
# Negative ELBO at step 2000: 7.32386326018321 in 117.4764s
# Negative ELBO at step 2500: 7.198002656419273 in 117.8514s
# Beginning evaluation 6
# Maximizer:
# [[0.         0.         0.17171717]]
# Evaluation 6: Next query is [[0.00000000e+00 0.00000000e+00 1.71717172e-01]
#  [1.13898532e-02 2.82572460e-04 2.89672828e-01]] with EI value of [0.3441612]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2995.922542761678 in 0.3745s
# Negative ELBO at step 500: 90.92521982434562 in 130.5748s
# Negative ELBO at step 1000: 29.197640000223082 in 127.4217s
# Negative ELBO at step 1500: 19.637795058537847 in 131.0978s
# Negative ELBO at step 2000: 12.93609824661661 in 130.0365s
# Negative ELBO at step 2500: 11.95327325443612 in 127.5708s
# Beginning evaluation 7
# Maximizer:
# [[0.         0.31313131 0.        ]]
# Evaluation 7: Next query is [[0.         0.31313131 0.        ]
#  [0.05781157 0.98221278 0.00385026]] with EI value of [0.40157568]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2873.1538963940857 in 0.3865s
# Negative ELBO at step 500: 76.42358087310804 in 141.5642s
# Negative ELBO at step 1000: 32.83963719750791 in 141.7211s
# Negative ELBO at step 1500: 19.953135624769104 in 139.9552s
# Negative ELBO at step 2000: 13.857089618296996 in 140.6317s
# Negative ELBO at step 2500: 11.299224047957175 in 143.4631s
# Beginning evaluation 8
# Maximizer:
# [[0.         0.17171717 0.        ]]
# Evaluation 8: Next query is [[0.         0.17171717 0.        ]
#  [0.02366702 0.11999901 0.01064001]] with EI value of [0.35493186]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 22951.987759550928 in 0.4827s
# Negative ELBO at step 500: 315.54539486416223 in 151.9330s
# Negative ELBO at step 1000: 123.64465914858818 in 153.4897s
# Negative ELBO at step 1500: 67.97030994886174 in 149.3993s
# Negative ELBO at step 2000: 49.08913717282405 in 149.8257s
# Negative ELBO at step 2500: 33.84979455471013 in 151.6409s
# Beginning evaluation 9
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 9: Next query is [[0.         0.         0.        ]
#  [0.15493605 0.93965042 0.98803393]] with EI value of [0.61362433]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2370.211945601278 in 0.4571s
# Negative ELBO at step 500: 74.9052807327034 in 162.4960s
# Negative ELBO at step 1000: 38.225720248513774 in 165.3311s
# Negative ELBO at step 1500: 21.474062628088493 in 164.0919s
# Negative ELBO at step 2000: 13.840265311733923 in 163.4469s
# Negative ELBO at step 2500: 14.155317255339707 in 165.5171s
# Beginning evaluation 10
# Maximizer:
# [[0.        0.1010101 0.       ]]
# Evaluation 10: Next query is [[0.         0.1010101  0.        ]
#  [0.04011742 0.06941244 0.04898104]] with EI value of [0.35890886]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 16795.51536599142 in 0.4317s
# Negative ELBO at step 500: 332.32678036517757 in 171.3948s
# Negative ELBO at step 1000: 131.47371853134115 in 172.2209s
# Negative ELBO at step 1500: 73.16682401036783 in 171.7380s
# Negative ELBO at step 2000: 45.15653334421917 in 170.6981s
# Negative ELBO at step 2500: 29.58752890859129 in 173.0915s
# Beginning evaluation 11
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 11: Next query is [[0.         0.         0.        ]
#  [0.98631642 0.75170607 0.01099973]] with EI value of [0.41849713]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 8333.259175479147 in 0.5122s
# Negative ELBO at step 500: 170.25651325521406 in 185.5459s
# Negative ELBO at step 1000: 84.49963624676697 in 182.3974s
# Negative ELBO at step 1500: 42.87726891397692 in 182.3790s
# Negative ELBO at step 2000: 28.526412630174075 in 185.5420s
# Negative ELBO at step 2500: 26.639721912870474 in 182.8465s
# Beginning evaluation 12
# Maximizer:
# [[0.         0.11111111 0.        ]]
# Evaluation 12: Next query is [[0.         0.11111111 0.        ]
#  [0.99091681 0.02937577 0.86832147]] with EI value of [0.46263411]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 19197.934412420214 in 0.5273s
# Negative ELBO at step 500: 296.74588891348577 in 197.0844s
# Negative ELBO at step 1000: 118.30468695208793 in 193.7096s
# Negative ELBO at step 1500: 80.04040080467863 in 192.9788s
# Negative ELBO at step 2000: 48.781167053759276 in 193.9100s
# Negative ELBO at step 2500: 34.55203118340262 in 193.7918s
# Beginning evaluation 13
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 13: Next query is [[0.         0.         0.        ]
#  [0.01657781 0.24457769 0.00510679]] with EI value of [0.42500295]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 15074.811512281556 in 0.6634s
# Negative ELBO at step 500: 303.41656796637216 in 203.7555s
# Negative ELBO at step 1000: 97.62262345266285 in 202.9580s
# Negative ELBO at step 1500: 63.66974728853304 in 202.1285s
# Negative ELBO at step 2000: 43.90281618207547 in 206.7339s
# Negative ELBO at step 2500: 30.399336685925363 in 204.1211s
# Beginning evaluation 14
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 14: Next query is [[0.         0.         0.        ]
#  [0.01749025 0.04989342 0.91128284]] with EI value of [0.33412716]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 33861.75921624675 in 0.6087s
# Negative ELBO at step 500: 691.9492397436375 in 216.8168s
# Negative ELBO at step 1000: 259.5938023283673 in 216.1596s
# Negative ELBO at step 1500: 135.66193934804522 in 216.4278s
# Negative ELBO at step 2000: 101.9500469097141 in 216.6585s
# Negative ELBO at step 2500: 71.55052053909138 in 214.9276s
# Beginning evaluation 15
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 15: Next query is [[0.         0.         0.        ]
#  [0.01883947 0.9559347  0.05164429]] with EI value of [0.46532433]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 18491.438534879784 in 0.6177s
# Negative ELBO at step 500: 379.38070985081515 in 225.5711s
# Negative ELBO at step 1000: 147.4951503895324 in 227.3873s
# Negative ELBO at step 1500: 70.38312446053506 in 225.4549s
# Negative ELBO at step 2000: 51.915207442815564 in 226.3225s
# Negative ELBO at step 2500: 39.382639793122486 in 227.4427s
# Beginning evaluation 16
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 16: Next query is [[0.         0.         0.        ]
#  [0.59518096 0.00496469 0.95380454]] with EI value of [0.31687381]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 51382.62708259879 in 0.6306s
# Negative ELBO at step 500: 1221.0118536490938 in 239.5690s
# Negative ELBO at step 1000: 403.905079043249 in 239.5924s
# Negative ELBO at step 1500: 295.33857808817584 in 237.2011s
# Negative ELBO at step 2000: 140.98686453804368 in 242.2973s
# Negative ELBO at step 2500: 114.73272223144863 in 238.5383s
# Beginning evaluation 17
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 17: Next query is [[0.         0.         0.        ]
#  [0.98614242 0.22280134 0.01937925]] with EI value of [0.52692409]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 261243.22457542206 in 0.6556s
# Negative ELBO at step 500: 2725.732694762355 in 248.6639s
# Negative ELBO at step 1000: 1062.7101652734268 in 248.9990s
# Negative ELBO at step 1500: 524.7745306272525 in 247.9993s
# Negative ELBO at step 2000: 340.35865430866215 in 251.1263s
# Negative ELBO at step 2500: 224.65312098202267 in 250.5145s
# Beginning evaluation 18
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 18: Next query is [[0.         0.         0.        ]
#  [0.0709732  0.0033779  0.27475762]] with EI value of [0.60317686]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 684494.5795976259 in 0.8345s
# Negative ELBO at step 500: 9360.263468445506 in 263.4186s
# Negative ELBO at step 1000: 3969.995825310292 in 262.4069s
# Negative ELBO at step 1500: 2007.8506410019922 in 259.0471s
# Negative ELBO at step 2000: 1001.8025176993966 in 266.3747s
# Negative ELBO at step 2500: 737.8697274438551 in 260.1584s
# Beginning evaluation 19
# Maximizer:
# [[0. 0. 0.]]
# Evaluation 19: Next query is [[0.         0.         0.        ]
#  [0.94650979 0.91137236 0.98827787]] with EI value of [1.04625545]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 464584.3476314632 in 0.6850s
# Negative ELBO at step 500: 6368.611380100547 in 271.4192s
# Negative ELBO at step 1000: 2440.7331431648545 in 272.0162s
# Negative ELBO at step 1500: 1689.8697971180343 in 331.9129s
# Negative ELBO at step 2000: 874.2390735919276 in 336.5660s
# Negative ELBO at step 2500: 555.1502217610322 in 329.6064s
# Beginning run 3
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 26.77291117389093 in 0.1440s
# Negative ELBO at step 500: 2.748689558758493 in 59.0626s
# Negative ELBO at step 1000: 2.387556752959749 in 73.0517s
# Negative ELBO at step 1500: 2.1172489073279364 in 66.1184s
# Negative ELBO at step 2000: 2.182423786118708 in 67.6899s
# Negative ELBO at step 2500: 2.0309959205793557 in 66.8035s
# Beginning evaluation 0
# Maximizer:
# [[0.         0.44444444 0.32323232]]
# Evaluation 0: Next query is [[0.         0.44444444 0.32323232]
#  [0.00242963 0.44174118 0.34716203]] with EI value of [0.36079101]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 11.575698745819329 in 0.1862s
# Negative ELBO at step 500: 3.0000549107750647 in 79.6641s
# Negative ELBO at step 1000: 2.822300048988304 in 82.3014s
# Negative ELBO at step 1500: 2.7449874366594065 in 78.1942s
# Negative ELBO at step 2000: 2.6506978173595312 in 85.6839s
# Negative ELBO at step 2500: 2.638435776719275 in 66.2685s
# Beginning evaluation 1
# Maximizer:
# [[0.09090909 1.         0.49494949]]
# Evaluation 1: Next query is [[0.09090909 1.         0.49494949]
#  [0.10726632 0.93341384 0.55991446]] with EI value of [0.384787]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 98.13076575797903 in 0.3354s
# Negative ELBO at step 500: 5.213145604261618 in 88.8550s
# Negative ELBO at step 1000: 3.8878699126688474 in 98.3737s
# Negative ELBO at step 1500: 3.5564847528487276 in 91.3821s
# Negative ELBO at step 2000: 3.4707653337325715 in 94.7896s
# Negative ELBO at step 2500: 3.575549254947457 in 96.3987s
# Beginning evaluation 2
# Maximizer:
# [[0.         0.80808081 0.55555556]]
# Evaluation 2: Next query is [[0.         0.80808081 0.55555556]
#  [0.02986495 0.96285702 0.76383184]] with EI value of [0.36251255]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 269.17498212547787 in 0.2957s
# Negative ELBO at step 500: 11.540415842852287 in 111.4633s
# Negative ELBO at step 1000: 5.611971701902345 in 102.6008s
# Negative ELBO at step 1500: 4.5317670739788545 in 111.5152s
# Negative ELBO at step 2000: 4.527217398855553 in 103.6429s
# Negative ELBO at step 2500: 4.506448446176371 in 116.4553s
# Beginning evaluation 3
# Maximizer:
# [[0.         1.         0.24242424]]
# Evaluation 3: Next query is [[0.         1.         0.24242424]
#  [0.02448004 0.97717456 0.14140362]] with EI value of [0.35278794]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 165.9454494818821 in 0.2987s
# Negative ELBO at step 500: 10.199406181632199 in 111.7355s
# Negative ELBO at step 1000: 5.794861546942609 in 114.1960s
# Negative ELBO at step 1500: 5.551216601803601 in 112.3896s
# Negative ELBO at step 2000: 5.2520121217503455 in 107.7759s
# Negative ELBO at step 2500: 5.150017162078495 in 117.0909s
# Beginning evaluation 4
# Maximizer:
# [[0.         0.78787879 0.18181818]]
# Evaluation 4: Next query is [[0.         0.78787879 0.18181818]
#  [0.04364037 0.98241958 0.0370155 ]] with EI value of [0.34323102]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1653.8093145016462 in 0.3146s
# Negative ELBO at step 500: 30.211718548517 in 127.7230s
# Negative ELBO at step 1000: 13.927029431772329 in 125.4970s
# Negative ELBO at step 1500: 9.696506898954517 in 129.2187s
# Negative ELBO at step 2000: 8.099794601877703 in 123.7499s
# Negative ELBO at step 2500: 6.325049151379546 in 126.5368s
# Beginning evaluation 5
# Maximizer:
# [[0.         1.         0.13131313]]
# Evaluation 5: Next query is [[0.         1.         0.13131313]
#  [0.02784481 0.99651345 0.92535954]] with EI value of [0.31377813]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 255.63699247581468 in 0.6360s
# Negative ELBO at step 500: 14.036508600146353 in 145.0267s
# Negative ELBO at step 1000: 8.764250478164733 in 136.5984s
# Negative ELBO at step 1500: 7.520434905228465 in 156.0477s
# Negative ELBO at step 2000: 6.724332199775001 in 141.3029s
# Negative ELBO at step 2500: 6.467349393330054 in 145.3436s
# Beginning evaluation 6
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 6: Next query is [[0.         1.         0.        ]
#  [0.03969918 0.89786565 0.0644204 ]] with EI value of [0.31433401]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7053.142080536181 in 0.4489s
# Negative ELBO at step 500: 131.6338487506967 in 170.2732s
# Negative ELBO at step 1000: 36.043128150762904 in 165.4934s
# Negative ELBO at step 1500: 22.035951887573766 in 158.2586s
# Negative ELBO at step 2000: 17.35326958490317 in 154.1499s
# Negative ELBO at step 2500: 13.168556638249177 in 172.0042s
# Beginning evaluation 7
# Maximizer:
# [[0.         0.76767677 0.01010101]]
# Evaluation 7: Next query is [[0.         0.76767677 0.01010101]
#  [0.05958625 0.94604947 0.02858703]] with EI value of [0.35044286]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1570.837259541884 in 0.4162s
# Negative ELBO at step 500: 44.71156796400035 in 165.9966s
# Negative ELBO at step 1000: 22.978890673647832 in 175.0295s
# Negative ELBO at step 1500: 12.633745968664693 in 169.2675s
# Negative ELBO at step 2000: 10.148715475795822 in 174.4665s
# Negative ELBO at step 2500: 9.029152950644962 in 171.0291s
# Beginning evaluation 8
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 8: Next query is [[0.         1.         0.        ]
#  [0.04459185 0.9499171  0.04998077]] with EI value of [0.28437554]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 5318.512968150089 in 0.4370s
# Negative ELBO at step 500: 111.24475611969726 in 183.3764s
# Negative ELBO at step 1000: 41.96569041932153 in 185.0789s
# Negative ELBO at step 1500: 23.28008746707159 in 194.9301s
# Negative ELBO at step 2000: 17.986666835985208 in 186.5286s
# Negative ELBO at step 2500: 16.699560597527565 in 187.8630s
# Beginning evaluation 9
# Maximizer:
# [[0.03030303 1.         0.        ]]
# Evaluation 9: Next query is [[0.03030303 1.         0.        ]
#  [0.00818707 0.03222656 0.03183269]] with EI value of [0.33512492]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 5387.229785176018 in 0.4601s
# Negative ELBO at step 500: 116.6906058712345 in 202.2285s
# Negative ELBO at step 1000: 47.92649289033528 in 205.4072s
# Negative ELBO at step 1500: 30.640573686942076 in 199.4185s
# Negative ELBO at step 2000: 19.408510569521187 in 200.8995s
# Negative ELBO at step 2500: 13.791901559710254 in 195.2573s
# Beginning evaluation 10
# Maximizer:
# [[0.03030303 1.         0.        ]]
# Evaluation 10: Next query is [[0.03030303 1.         0.        ]
#  [0.03198988 0.98199966 0.04201114]] with EI value of [0.35108964]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2817.298610450006 in 0.4602s
# Negative ELBO at step 500: 81.9145469810501 in 202.8367s
# Negative ELBO at step 1000: 33.09566082106404 in 203.4725s
# Negative ELBO at step 1500: 19.523316610230722 in 199.6109s
# Negative ELBO at step 2000: 15.685654839009473 in 208.8222s
# Negative ELBO at step 2500: 13.214374644804721 in 206.7173s
# Beginning evaluation 11
# Maximizer:
# [[0.01010101 1.         0.        ]]
# Evaluation 11: Next query is [[0.01010101 1.         0.        ]
#  [0.01728536 0.93991811 0.0246421 ]] with EI value of [0.28271196]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7220.324961970744 in 0.5372s
# Negative ELBO at step 500: 172.62653531653825 in 221.4027s
# Negative ELBO at step 1000: 71.55321026367943 in 219.3635s
# Negative ELBO at step 1500: 44.3656113679871 in 223.8334s
# Negative ELBO at step 2000: 27.7914313081489 in 218.2531s
# Negative ELBO at step 2500: 24.30672559679422 in 223.5750s
# Beginning evaluation 12
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 12: Next query is [[0.         1.         0.        ]
#  [0.33520549 0.97541066 0.00201947]] with EI value of [0.28440302]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 24858.70430509987 in 1.3157s
# Negative ELBO at step 500: 515.9088156711155 in 243.8634s
# Negative ELBO at step 1000: 222.4430884773429 in 239.8330s
# Negative ELBO at step 1500: 111.17945034294696 in 243.0379s
# Negative ELBO at step 2000: 71.75335106807535 in 251.8784s
# Negative ELBO at step 2500: 55.18411946387601 in 239.2810s
# Beginning evaluation 13
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 13: Next query is [[0.         1.         0.        ]
#  [0.0317121  0.11769334 0.97499435]] with EI value of [0.58149877]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 9651.135146684663 in 0.5830s
# Negative ELBO at step 500: 197.58671409014335 in 246.1831s
# Negative ELBO at step 1000: 94.70594034352669 in 263.1951s
# Negative ELBO at step 1500: 44.862742759294235 in 244.4222s
# Negative ELBO at step 2000: 31.228079340453824 in 249.9758s
# Negative ELBO at step 2500: 21.592415317677997 in 247.2980s
# Beginning evaluation 14
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 14: Next query is [[0.         1.         0.        ]
#  [0.01595469 0.97589503 0.0244791 ]] with EI value of [0.32311799]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 48845.99547564236 in 0.6148s
# Negative ELBO at step 500: 1160.4792924537749 in 280.0820s
# Negative ELBO at step 1000: 391.42815208102627 in 269.9688s
# Negative ELBO at step 1500: 258.9108750795264 in 277.0177s
# Negative ELBO at step 2000: 139.5212866244745 in 282.9475s
# Negative ELBO at step 2500: 105.43090772849533 in 263.3440s
# Beginning evaluation 15
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 15: Next query is [[0.         1.         0.        ]
#  [0.13819959 0.91002998 0.00155207]] with EI value of [0.45955648]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 43893.19706625008 in 0.5801s
# Negative ELBO at step 500: 781.8285112058513 in 274.1149s
# Negative ELBO at step 1000: 255.5107044008124 in 279.0383s
# Negative ELBO at step 1500: 155.59597892192727 in 277.8996s
# Negative ELBO at step 2000: 98.7867590514671 in 278.3738s
# Negative ELBO at step 2500: 65.402167564877 in 281.0103s
# Beginning evaluation 16
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 16: Next query is [[0.         1.         0.        ]
#  [0.86204511 0.9948009  0.89197814]] with EI value of [0.41511079]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 37001.53971694201 in 0.6071s
# Negative ELBO at step 500: 802.1570630978346 in 307.0362s
# Negative ELBO at step 1000: 304.94446685905444 in 297.4808s
# Negative ELBO at step 1500: 179.53085425911107 in 306.2434s
# Negative ELBO at step 2000: 82.05162912475879 in 304.8959s
# Beginning evaluation 17
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 17: Next query is [[0.         1.         0.        ]
#  [0.00170967 0.98464194 0.68205043]] with EI value of [0.49067656]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 46611.782394031456 in 0.6798s
# Negative ELBO at step 500: 1105.712159170892 in 301.1838s
# Negative ELBO at step 1000: 422.19169648452396 in 309.3741s
# Negative ELBO at step 1500: 236.73845859546122 in 306.5722s
# Negative ELBO at step 2000: 133.3483670621469 in 312.0824s
# Negative ELBO at step 2500: 85.65076040839122 in 308.2338s
# Beginning evaluation 18
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 18: Next query is [[0.         1.         0.        ]
#  [0.01869681 0.97685445 0.21695474]] with EI value of [0.39399407]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 143524.2726861722 in 0.8987s
# Negative ELBO at step 500: 2034.5702467843907 in 262.7410s
# Negative ELBO at step 1000: 880.1834191140777 in 260.8582s
# Negative ELBO at step 1500: 525.0312883228125 in 259.0200s
# Negative ELBO at step 2000: 273.44180828229884 in 262.5081s
# Negative ELBO at step 2500: 190.09840210197987 in 263.8162s
# Beginning evaluation 19
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 19: Next query is [[0.         1.         0.        ]
#  [0.0929386  0.98976848 0.13551056]] with EI value of [0.71499726]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 193260.94217581197 in 0.7543s
# Negative ELBO at step 500: 3041.4740689453224 in 273.9118s
# Negative ELBO at step 1000: 1270.6021854997716 in 274.3789s
# Negative ELBO at step 1500: 665.8996620846995 in 274.6852s
# Negative ELBO at step 2000: 454.12736469076816 in 272.2700s
# Negative ELBO at step 2500: 273.82735566968887 in 271.1941s
# Beginning run 4
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 4.557006312301507 in 0.1432s
# Negative ELBO at step 500: 2.126269404241334 in 50.2411s
# Negative ELBO at step 1000: 2.009950932722454 in 51.7680s
# Negative ELBO at step 1500: 1.9573931463148166 in 52.5615s
# Negative ELBO at step 2000: 1.9506061153324568 in 50.7605s
# Negative ELBO at step 2500: 1.8571271827025526 in 52.8686s
# Beginning evaluation 0
# Maximizer:
# [[0.58585859 0.72727273 1.        ]]
# Evaluation 0: Next query is [[0.58585859 0.72727273 1.        ]
#  [0.62203407 0.75249521 0.99622499]] with EI value of [0.42040953]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 12.971850032142127 in 0.2945s
# Negative ELBO at step 500: 3.206959512514273 in 61.9646s
# Negative ELBO at step 1000: 2.8958442489000262 in 64.1607s
# Negative ELBO at step 1500: 2.7752739921578606 in 62.3311s
# Negative ELBO at step 2000: 2.7047253453642695 in 60.7562s
# Negative ELBO at step 2500: 2.690767372483984 in 63.5422s
# Beginning evaluation 1
# Maximizer:
# [[0.24242424 0.95959596 1.        ]]
# Evaluation 1: Next query is [[0.24242424 0.95959596 1.        ]
#  [0.3038371  0.94413318 0.98306246]] with EI value of [0.38806972]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 55.22952002386208 in 0.1908s
# Negative ELBO at step 500: 4.608300778473666 in 74.1241s
# Negative ELBO at step 1000: 3.787559568763668 in 73.7000s
# Negative ELBO at step 1500: 3.5376066144108025 in 73.4488s
# Negative ELBO at step 2000: 3.4809944838961115 in 73.3555s
# Negative ELBO at step 2500: 3.488646041934751 in 72.4637s
# Beginning evaluation 2
# Maximizer:
# [[0.24242424 0.98989899 1.        ]]
# Evaluation 2: Next query is [[0.24242424 0.98989899 1.        ]
#  [0.07144296 0.98132193 0.92791029]] with EI value of [0.37164488]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 311.7768084625163 in 0.2275s
# Negative ELBO at step 500: 12.882531709549365 in 84.0224s
# Negative ELBO at step 1000: 6.73914131905237 in 83.8780s
# Negative ELBO at step 1500: 4.839617242983464 in 84.9654s
# Negative ELBO at step 2000: 4.432559057538751 in 85.2137s
# Negative ELBO at step 2500: 4.55399314438297 in 83.9854s
# Beginning evaluation 3
# Maximizer:
# [[0.5959596  0.84848485 1.        ]]
# Evaluation 3: Next query is [[0.5959596  0.84848485 1.        ]
#  [0.79400062 0.94285067 0.98038612]] with EI value of [0.37853207]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 164.22750867795946 in 0.3126s
# Negative ELBO at step 500: 7.697042834006892 in 93.0454s
# Negative ELBO at step 1000: 5.816156239557651 in 94.1078s
# Negative ELBO at step 1500: 5.410620103881433 in 96.9582s
# Negative ELBO at step 2000: 5.138905910299501 in 94.6946s
# Negative ELBO at step 2500: 5.060847605868493 in 96.7924s
# Beginning evaluation 4
# Maximizer:
# [[0.74747475 1.         1.        ]]
# Evaluation 4: Next query is [[0.74747475 1.         1.        ]
#  [0.78308748 0.96303207 0.99710617]] with EI value of [0.33401415]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 368.62567226860745 in 0.4824s
# Negative ELBO at step 500: 16.10145335650605 in 105.8594s
# Negative ELBO at step 1000: 7.303379698307843 in 106.7117s
# Negative ELBO at step 1500: 6.448716167369087 in 104.3765s
# Negative ELBO at step 2000: 5.978923010859524 in 107.1124s
# Negative ELBO at step 2500: 6.131284768868955 in 105.0741s
# Beginning evaluation 5
# Maximizer:
# [[1. 1. 1.]]
# Evaluation 5: Next query is [[1.         1.         1.        ]
#  [0.99118047 0.89970487 0.94364595]] with EI value of [0.28306042]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 562.6348146483714 in 0.3461s
# Negative ELBO at step 500: 22.888736597691448 in 116.9350s
# Negative ELBO at step 1000: 9.342711402886891 in 119.5687s
# Negative ELBO at step 1500: 7.644829208009462 in 116.1157s
# Negative ELBO at step 2000: 6.785954817897891 in 117.2862s
# Negative ELBO at step 2500: 7.019258111007579 in 118.9229s
# Beginning evaluation 6
# Maximizer:
# [[0.87878788 0.84848485 1.        ]]
# Evaluation 6: Next query is [[0.87878788 0.84848485 1.        ]
#  [0.91601679 0.8988941  0.92681297]] with EI value of [0.33751682]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 659.5490914352929 in 0.3323s
# Negative ELBO at step 500: 24.91903484281022 in 128.3691s
# Negative ELBO at step 1000: 13.228478359611461 in 128.1047s
# Negative ELBO at step 1500: 8.508183071034603 in 129.8889s
# Negative ELBO at step 2000: 7.989415699629838 in 131.2115s
# Negative ELBO at step 2500: 7.457972801502514 in 128.9827s
# Beginning evaluation 7
# Maximizer:
# [[0.91919192 0.95959596 1.        ]]
# Evaluation 7: Next query is [[0.91919192 0.95959596 1.        ]
#  [0.95580709 0.98611216 0.9847147 ]] with EI value of [0.3638722]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1216.1971625782248 in 0.4075s
# Negative ELBO at step 500: 42.93846648054428 in 142.0181s
# Negative ELBO at step 1000: 17.68383260422686 in 142.8453s
# Negative ELBO at step 1500: 11.865155865402805 in 141.6666s
# Negative ELBO at step 2000: 9.608180910741034 in 142.1288s
# Negative ELBO at step 2500: 9.035150770680211 in 139.3033s
# Beginning evaluation 8
# Maximizer:
# [[0.91919192 0.90909091 1.        ]]
# Evaluation 8: Next query is [[0.91919192 0.90909091 1.        ]
#  [0.95896472 0.87286986 0.96730185]] with EI value of [0.317941]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2893.268475221456 in 0.3584s
# Negative ELBO at step 500: 64.87817257220794 in 149.8903s
# Negative ELBO at step 1000: 31.795432103456953 in 152.2197s
# Negative ELBO at step 1500: 19.383750772937447 in 150.4389s
# Negative ELBO at step 2000: 13.574842204339692 in 151.0693s
# Negative ELBO at step 2500: 11.643551665770225 in 152.9798s
# Beginning evaluation 9
# Maximizer:
# [[0.90909091 0.57575758 1.        ]]
# Evaluation 9: Next query is [[0.90909091 0.57575758 1.        ]
#  [0.98313767 0.12192884 0.99407584]] with EI value of [0.40312653]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 3839.178381254492 in 0.4214s
# Negative ELBO at step 500: 85.11148602373063 in 162.8797s
# Negative ELBO at step 1000: 36.26907688300946 in 162.9950s
# Negative ELBO at step 1500: 27.764815173835803 in 163.1524s
# Negative ELBO at step 2000: 18.455468484971767 in 164.4827s
# Negative ELBO at step 2500: 15.720144474166526 in 163.1614s
# Beginning evaluation 10
# Maximizer:
# [[1.         0.15151515 1.        ]]
# Evaluation 10: Next query is [[1.         0.15151515 1.        ]
#  [0.12595101 0.97174391 0.06595791]] with EI value of [0.34193046]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7480.211982569384 in 0.5013s
# Negative ELBO at step 500: 159.953858026334 in 172.9791s
# Negative ELBO at step 1000: 55.11199349709745 in 174.7849s
# Negative ELBO at step 1500: 33.73917958070152 in 173.6589s
# Negative ELBO at step 2000: 22.278100976903303 in 171.3930s
# Negative ELBO at step 2500: 19.416112849047718 in 171.3869s
# Beginning evaluation 11
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 11: Next query is [[0.         1.         0.        ]
#  [0.08351664 0.04888352 0.98303085]] with EI value of [0.31082462]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 13792.921226359562 in 0.5208s
# Negative ELBO at step 500: 318.4902064882101 in 185.8602s
# Negative ELBO at step 1000: 122.78245991044308 in 187.3896s
# Negative ELBO at step 1500: 58.06388926058514 in 183.5734s
# Negative ELBO at step 2000: 42.01994761631686 in 184.7359s
# Negative ELBO at step 2500: 27.755683218626622 in 182.7923s
# Beginning evaluation 12
# Maximizer:
# [[0.         0.91919192 0.        ]]
# Evaluation 12: Next query is [[0.         0.91919192 0.        ]
#  [0.46535787 0.96329024 0.01672074]] with EI value of [0.37268964]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 23196.01757058127 in 0.6272s
# Negative ELBO at step 500: 343.0416667237054 in 197.0065s
# Negative ELBO at step 1000: 152.34688717218688 in 195.4973s
# Negative ELBO at step 1500: 79.78508287415389 in 194.7085s
# Negative ELBO at step 2000: 40.55781430645199 in 193.6709s
# Negative ELBO at step 2500: 34.682674739490906 in 194.2465s
# Beginning evaluation 13
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 13: Next query is [[0.         1.         0.        ]
#  [0.99080558 0.06469092 0.61683133]] with EI value of [0.40368622]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 31101.849645018887 in 0.5713s
# Negative ELBO at step 500: 690.4127859816471 in 206.5354s
# Negative ELBO at step 1000: 256.50708835618536 in 206.4022s
# Negative ELBO at step 1500: 159.42873074606996 in 207.8193s
# Negative ELBO at step 2000: 91.44751450859516 in 205.3859s
# Negative ELBO at step 2500: 55.85364757992786 in 211.9411s
# Beginning evaluation 14
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 14: Next query is [[0.         1.         0.        ]
#  [0.02017786 0.93383817 0.02747139]] with EI value of [0.45664955]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 186921.05931271001 in 0.5355s
# Negative ELBO at step 500: 1412.642889396306 in 213.7424s
# Negative ELBO at step 1000: 549.6157532000854 in 216.5521s
# Negative ELBO at step 1500: 292.54088398134473 in 216.3622s
# Negative ELBO at step 2000: 199.99988700382912 in 217.2793s
# Negative ELBO at step 2500: 137.5817959753845 in 217.4085s
# Beginning evaluation 15
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 15: Next query is [[0.         1.         0.        ]
#  [0.32578048 0.00423282 0.51798636]] with EI value of [0.58318954]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 76173.55293547788 in 0.6149s
# Negative ELBO at step 500: 1315.5787103934126 in 223.8906s
# Negative ELBO at step 1000: 566.5102561755128 in 223.5946s
# Negative ELBO at step 1500: 299.68646907781357 in 227.4940s
# Negative ELBO at step 2000: 176.23027438588005 in 227.7322s
# Negative ELBO at step 2500: 108.0071622497164 in 226.1346s
# Beginning evaluation 16
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 16: Next query is [[0.         1.         0.        ]
#  [0.40966851 0.9867988  0.53729946]] with EI value of [0.46560157]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 188002.2167300983 in 0.5887s
# Negative ELBO at step 500: 1818.3905360957442 in 241.5849s
# Negative ELBO at step 1000: 832.9774192483355 in 241.6973s
# Negative ELBO at step 1500: 409.2385940863602 in 241.9109s
# Negative ELBO at step 2000: 246.26705373135155 in 239.8108s
# Negative ELBO at step 2500: 174.6228549049263 in 238.0285s
# Beginning evaluation 17
# Maximizer:
# [[0.73737374 1.         1.        ]]
# Evaluation 17: Next query is [[0.73737374 1.         1.        ]
#  [0.97745725 0.88935799 0.01524906]] with EI value of [0.8026648]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 602430.7787003524 in 0.8361s
# Negative ELBO at step 500: 5069.558355193919 in 248.6079s
# Negative ELBO at step 1000: 1880.8732622766124 in 250.1770s
# Negative ELBO at step 1500: 977.9627648530643 in 250.8164s
# Negative ELBO at step 2000: 619.5329822938785 in 248.8242s
# Negative ELBO at step 2500: 463.63381523582973 in 245.9223s
# Beginning evaluation 18
# Maximizer:
# [[1. 1. 1.]]
# Evaluation 18: Next query is [[1.         1.         1.        ]
#  [0.9368943  0.98004115 0.58264452]] with EI value of [1.19949466]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 215815.43256116952 in 0.6917s
# Negative ELBO at step 500: 4169.264165356263 in 261.7873s
# Negative ELBO at step 1000: 1437.2568668916788 in 262.2184s
# Negative ELBO at step 1500: 855.258317338011 in 263.8599s
# Negative ELBO at step 2000: 518.1259739986968 in 262.0791s
# Negative ELBO at step 2500: 357.45157644924285 in 261.2371s
# Beginning evaluation 19
# Maximizer:
# [[0. 1. 0.]]
# Evaluation 19: Next query is [[0.         1.         0.        ]
#  [0.27957858 0.04471364 0.0054738 ]] with EI value of [0.75152699]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 376097.3356218744 in 0.7820s
# Negative ELBO at step 500: 4077.2047542652144 in 271.2680s
# Negative ELBO at step 1000: 1739.4233321827276 in 271.3443s
# Negative ELBO at step 1500: 949.2174226955412 in 273.2586s
# Negative ELBO at step 2000: 491.2158989257434 in 273.6743s
# Negative ELBO at step 2500: 361.1963374355493 in 274.9306s
# Beginning run 5
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 5.137151493432478 in 0.1441s
# Negative ELBO at step 500: 2.3585614696654087 in 53.2315s
# Negative ELBO at step 1000: 2.24981493743583 in 52.7860s
# Negative ELBO at step 1500: 2.18841538330431 in 52.5186s
# Negative ELBO at step 2000: 2.1468997427149525 in 51.1543s
# Negative ELBO at step 2500: 2.095947046894329 in 52.1797s
# Beginning evaluation 0
# Maximizer:
# [[0.52525253 0.         1.        ]]
# Evaluation 0: Next query is [[0.52525253 0.         1.        ]
#  [0.99922082 0.92440829 0.67691933]] with EI value of [0.33241385]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 99.82814069889517 in 0.1850s
# Negative ELBO at step 500: 4.771752934786822 in 62.1190s
# Negative ELBO at step 1000: 3.814143422228291 in 63.8084s
# Negative ELBO at step 1500: 3.076520834669296 in 64.2624s
# Negative ELBO at step 2000: 3.14111294072806 in 62.6430s
# Negative ELBO at step 2500: 3.1225445123494047 in 63.6988s
# Beginning evaluation 1
# Maximizer:
# [[0.95959596 1.         0.09090909]]
# Evaluation 1: Next query is [[0.95959596 1.         0.09090909]
#  [0.99982966 0.9299082  0.16828166]] with EI value of [0.37432707]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 80.22073872441736 in 0.1879s
# Negative ELBO at step 500: 5.883267122407796 in 74.6809s
# Negative ELBO at step 1000: 4.203211684362756 in 73.3633s
# Negative ELBO at step 1500: 4.1797948847271105 in 75.1430s
# Negative ELBO at step 2000: 4.032002717421379 in 72.8876s
# Negative ELBO at step 2500: 3.7891955156698853 in 74.9440s
# Beginning evaluation 2
# Maximizer:
# [[0.87878788 1.         0.43434343]]
# Evaluation 2: Next query is [[0.87878788 1.         0.43434343]
#  [0.99555732 0.97583257 0.98739431]] with EI value of [0.37167007]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 127.8327470584903 in 0.2563s
# Negative ELBO at step 500: 7.048923580108012 in 84.3578s
# Negative ELBO at step 1000: 5.2680697973511075 in 83.1957s
# Negative ELBO at step 1500: 4.596444132447572 in 84.3275s
# Negative ELBO at step 2000: 4.439903528688921 in 84.0560s
# Negative ELBO at step 2500: 4.669328640128743 in 86.1494s
# Beginning evaluation 3
# Maximizer:
# [[0.97979798 0.94949495 0.        ]]
# Evaluation 3: Next query is [[0.97979798 0.94949495 0.        ]
#  [0.93602525 0.86917337 0.02011348]] with EI value of [0.34876417]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 142.14628981014263 in 0.2465s
# Negative ELBO at step 500: 7.782691498777002 in 96.2491s
# Negative ELBO at step 1000: 6.3705794596264465 in 95.2360s
# Negative ELBO at step 1500: 5.596859249868155 in 96.9252s
# Negative ELBO at step 2000: 5.248697653342396 in 96.0870s
# Negative ELBO at step 2500: 5.225482750063726 in 97.4128s
# Beginning evaluation 4
# Maximizer:
# [[1. 1. 0.]]
# Evaluation 4: Next query is [[1.         1.         0.        ]
#  [0.97123809 0.7969484  0.00621638]] with EI value of [0.34531638]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 234.33269388142227 in 0.3382s
# Negative ELBO at step 500: 11.646362353940209 in 105.5656s
# Negative ELBO at step 1000: 7.018481627412766 in 106.2816s
# Negative ELBO at step 1500: 6.4402977693793835 in 106.6573s
# Negative ELBO at step 2000: 6.106304104537061 in 104.9463s
# Negative ELBO at step 2500: 6.121577748744744 in 106.5998s
# Beginning evaluation 5
# Maximizer:
# [[1. 1. 0.]]
# Evaluation 5: Next query is [[1.         1.         0.        ]
#  [0.93801274 0.90216489 0.05137519]] with EI value of [0.32585534]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1152.5837935421 in 0.4466s
# Negative ELBO at step 500: 33.130803335774004 in 116.6502s
# Negative ELBO at step 1000: 14.151103159725418 in 117.6366s
# Negative ELBO at step 1500: 10.204296022823872 in 118.4922s
# Negative ELBO at step 2000: 8.328552929526273 in 119.6041s
# Negative ELBO at step 2500: 7.337195227512647 in 117.7163s
# Beginning evaluation 6
# Maximizer:
# [[1.         1.         0.13131313]]
# Evaluation 6: Next query is [[1.         1.         0.13131313]
#  [0.96937336 0.97779069 0.07285034]] with EI value of [0.34513152]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 3709.4709422847595 in 0.3579s
# Negative ELBO at step 500: 78.52225240702346 in 129.4885s
# Negative ELBO at step 1000: 44.63469403706965 in 128.4813s
# Negative ELBO at step 1500: 19.91039794611232 in 129.9892s
# Negative ELBO at step 2000: 16.474828755003564 in 129.1002s
# Negative ELBO at step 2500: 11.54874499999817 in 128.1182s
# Beginning evaluation 7
# Maximizer:
# [[1.         1.         0.29292929]]
# Evaluation 7: Next query is [[1.         1.         0.29292929]
#  [0.76790451 0.99880777 0.04398999]] with EI value of [0.40890084]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1653.8903007217205 in 0.4157s
# Negative ELBO at step 500: 42.524224631199466 in 141.4110s
# Negative ELBO at step 1000: 20.82398594692325 in 141.9676s
# Negative ELBO at step 1500: 13.11979638479999 in 139.6189s
# Negative ELBO at step 2000: 9.850896469334778 in 140.2528s
# Negative ELBO at step 2500: 8.882280801753275 in 141.7238s
# Beginning evaluation 8
# Maximizer:
# [[1.         1.         0.35353535]]
# Evaluation 8: Next query is [[1.         1.         0.35353535]
#  [0.97140922 0.89445847 0.0672075 ]] with EI value of [0.31470126]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 10944.59386231112 in 0.5675s
# Negative ELBO at step 500: 135.51188718418942 in 152.9420s
# Negative ELBO at step 1000: 70.2496181613505 in 148.5277s
# Negative ELBO at step 1500: 33.219171541604396 in 152.3636s
# Negative ELBO at step 2000: 22.27283137513274 in 151.3287s
# Negative ELBO at step 2500: 17.001639812764648 in 149.3524s
# Beginning evaluation 9
# Maximizer:
# [[1.         1.         0.35353535]]
# Evaluation 9: Next query is [[1.         1.         0.35353535]
#  [0.90824935 0.40396695 0.99621821]] with EI value of [0.38772945]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2207.3173955898737 in 0.4483s
# Negative ELBO at step 500: 64.99700065108318 in 164.7129s
# Negative ELBO at step 1000: 30.366430088979822 in 162.1240s
# Negative ELBO at step 1500: 19.142331912298175 in 163.0593s
# Negative ELBO at step 2000: 14.086184116540217 in 162.6682s
# Negative ELBO at step 2500: 12.094712992044691 in 168.2136s
# Beginning evaluation 10
# Maximizer:
# [[1.         1.         0.41414141]]
# Evaluation 10: Next query is [[1.         1.         0.41414141]
#  [0.98346856 0.99703814 0.24417098]] with EI value of [0.27631735]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 41990.951711149864 in 0.4960s
# Negative ELBO at step 500: 563.6789305837768 in 172.6635s
# Negative ELBO at step 1000: 198.08897175254629 in 175.9951s
# Negative ELBO at step 1500: 96.0760450893761 in 175.3672s
# Negative ELBO at step 2000: 53.25297863227594 in 172.7144s
# Negative ELBO at step 2500: 38.63224512841746 in 172.7781s
# Beginning evaluation 11
# Maximizer:
# [[1.         1.         0.32323232]]
# Evaluation 11: Next query is [[1.         1.         0.32323232]
#  [0.68229743 0.94165838 0.98724498]] with EI value of [0.85257651]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 16193.096500834414 in 0.4760s
# Negative ELBO at step 500: 254.84768202582444 in 182.4748s
# Negative ELBO at step 1000: 106.53321145024996 in 186.3095s
# Negative ELBO at step 1500: 63.71698338465899 in 184.0300s
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-15-e9c2acc81ae4> in <module>
#      40         model, inputs, u_mean, inducing_vars = train_and_visualize(X, y,
#      41                                                                    num_inducing_init + evaluation + 1,
# ---> 42                                                                    "Run_{}_Evaluation_{}".format(run, evaluation))
#      43
#      44         best_guess_results[run, evaluation, :] = best_guess(model)
#
# <ipython-input-6-4e02aba53f99> in train_and_visualize(X, y, num_inducing, title)
#       6                                                                          obj_low=objective_low,
#       7                                                                          obj_high=objective_high,
# ----> 8                                                                          num_steps=3000)
#       9     likelihood = gpflow.likelihoods.Gaussian()
#      10     model = PBO.models.learning.init_SVGP_fullcov(q_mu, q_sqrt, u, k, likelihood)
#
# ~/PBO/models/learning_stochastic.py in train_model_fullcov(X, y, num_inducing, obj_low, obj_high, lengthscale, num_steps, indifference_threshold)
#     388
#     389     for i in range(num_steps):
# --> 390         optimizer.minimize(neg_elbo, var_list=trainable_vars)
#     391
#     392         if i % 500 == 0:
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/keras/optimizer_v2/optimizer_v2.py in minimize(self, loss, var_list, grad_loss, name)
#     314     """
#     315     grads_and_vars = self._compute_gradients(
# --> 316         loss, var_list=var_list, grad_loss=grad_loss)
#     317
#     318     return self.apply_gradients(grads_and_vars, name=name)
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/keras/optimizer_v2/optimizer_v2.py in _compute_gradients(self, loss, var_list, grad_loss)
#     348       if not callable(var_list):
#     349         tape.watch(var_list)
# --> 350       loss_value = loss()
#     351     if callable(var_list):
#     352       var_list = var_list()
#
# ~/PBO/models/learning_stochastic.py in <lambda>()
#     374                                      indifference_threshold=indifference_threshold,
#     375                                      n_inducing_sample=50,
# --> 376                                      n_f_given_inducing_sample=50)
#     377
#     378     optimizer = tf.keras.optimizers.Adam()
#
# ~/PBO/models/learning_stochastic.py in elbo_fullcov(q_mu, q_sqrt_latent, inducing_inputs, D_idxs, max_idxs, kernel, inputs, indifference_threshold, n_inducing_sample, n_f_given_inducing_sample)
#      59
#      60     logdet_Kmm = tf.linalg.logdet(Kmm)
# ---> 61     invKmm = cholesky_matrix_inverse(Kmm)
#      62
#      63     num_data = D_idxs.size()
#
# ~/PBO/models/learning_stochastic.py in cholesky_matrix_inverse(A)
#     181     """
#     182     L = tf.linalg.cholesky(A)
# --> 183     L_inv = tf.linalg.triangular_solve(L, tf.eye(A.shape[0], dtype=tf.float64))
#     184     return tf.linalg.matrix_transpose(L_inv) @ L_inv
#     185
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_linalg_ops.py in matrix_triangular_solve(matrix, rhs, lower, adjoint, name)
#    1894         raise
#    1895     except _core._NotOkStatusException as e:
# -> 1896       _ops.raise_from_not_ok_status(e, name)
#    1897   # Add nodes to the TensorFlow graph.
#    1898   if lower is None:
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Input matrix is not invertible. [Op:MatrixTriangularSolve]

# %%
model

# %%
run
# Out:
# 5

# %%
q_mu, q_sqrt, u, inputs, k, indifference_threshold = train_model_fullcov(X, y, 
                                                                         num_inducing=num_inducing_init + evaluation + 1,
                                                                         obj_low=objective_low,
                                                                         obj_high=objective_high,
                                                                         num_steps=3000)
# Out:
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 11510.962587647811 in 0.5924s
# Negative ELBO at step 500: 277.2154424164847 in 184.2947s
# Negative ELBO at step 1000: 94.97496947874512 in 187.1631s
# Negative ELBO at step 1500: 57.367661811113976 in 187.3401s
# Negative ELBO at step 2000: 33.90685986180857 in 186.6289s
# Negative ELBO at step 2500: 27.572881712780564 in 188.1012s

# %%
print_summary(k)
# Out:
# <table>
# <thead>
# <tr><th>name                          </th><th>class    </th><th>transform  </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                             </th></tr>
# </thead>
# <tbody>
# <tr><td>SquaredExponential.variance   </td><td>Parameter</td><td>Softplus   </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.2037156742358075                </td></tr>
# <tr><td>SquaredExponential.lengthscale</td><td>Parameter</td><td>Softplus   </td><td>       </td><td>True       </td><td>(3,)   </td><td>float64</td><td>[0.82366564 0.82809989 0.81827668]</td></tr>
# </tbody>
# </table>

# %%
print_summary(model)
# Out:
# <table>
# <thead>
# <tr><th>name                    </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape      </th><th>dtype  </th><th>value                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>SVGP.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()         </td><td>float64</td><td>1.1749471700546303                    </td></tr>
# <tr><td>SVGP.kernel.lengthscale </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(3,)       </td><td>float64</td><td>[0.86938922 0.84125363 0.86010575]    </td></tr>
# <tr><td>SVGP.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()         </td><td>float64</td><td>0.9999999999999999                    </td></tr>
# <tr><td>SVGP.inducing_variable.Z</td><td>Parameter</td><td>                </td><td>       </td><td>False      </td><td>(14, 3)    </td><td>float64</td><td>[[0.46261772, 0.6743687, 0.36129394...</td></tr>
# <tr><td>SVGP.q_mu               </td><td>Parameter</td><td>                </td><td>       </td><td>False      </td><td>(14, 1)    </td><td>float64</td><td>[[3.67998729e-02...                   </td></tr>
# <tr><td>SVGP.q_sqrt             </td><td>Parameter</td><td>FillTriangular  </td><td>       </td><td>False      </td><td>(1, 14, 14)</td><td>float64</td><td>[[[0.50164886, 0., 0....              </td></tr>
# </tbody>
# </table>

# %%
model.kernel.lengthscale.transform = gpflow.utilities.bijectors.positive(lower=gpflow.default_jitter())

# %%
print_summary(model)
# Out:
# <table>
# <thead>
# <tr><th>name                    </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape      </th><th>dtype  </th><th>value                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>SVGP.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()         </td><td>float64</td><td>1.1749471700546303                    </td></tr>
# <tr><td>SVGP.kernel.lengthscale </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>(3,)       </td><td>float64</td><td>[0.86938922 0.84125363 0.86010575]    </td></tr>
# <tr><td>SVGP.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()         </td><td>float64</td><td>0.9999999999999999                    </td></tr>
# <tr><td>SVGP.inducing_variable.Z</td><td>Parameter</td><td>                </td><td>       </td><td>False      </td><td>(14, 3)    </td><td>float64</td><td>[[0.46261772, 0.6743687, 0.36129394...</td></tr>
# <tr><td>SVGP.q_mu               </td><td>Parameter</td><td>                </td><td>       </td><td>False      </td><td>(14, 1)    </td><td>float64</td><td>[[3.67998729e-02...                   </td></tr>
# <tr><td>SVGP.q_sqrt             </td><td>Parameter</td><td>FillTriangular  </td><td>       </td><td>False      </td><td>(1, 14, 14)</td><td>float64</td><td>[[[0.50164886, 0., 0....              </td></tr>
# </tbody>
# </table>

# %%
pickle.dump((X_results, y_results, best_guess_results), open(results_dir + "Xybestguess.p", "wb"))

# %%
def dist(x, y):
    """
    x and y have shape (..., input_dims)
    """
    return np.sqrt(np.sum((x - y) * (x - y), axis=-1))

xx = uniform_grid(input_dims, num_discrete_per_dim, low=objective_low, high=objective_high)
global_min = xx[np.argmin(objective(xx))][0]

for i in range(best_guess_results.shape[0]):
    diff_from_min = dist(best_guess_results[i], global_min)
    
    x_axis = list(range(num_combs+1, num_combs+1+num_evals))
    plt.figure(figsize=(12, 6))
    plt.plot(x_axis, diff_from_min, 'kx', mew=2)
    plt.xticks(x_axis)
    plt.xlabel('Evaluations', fontsize=18)
    plt.ylabel('Best guess distance', fontsize=16)
    plt.title("Run %s" % i)
    plt.show()
