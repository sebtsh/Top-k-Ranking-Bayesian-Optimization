# %% [markdown]
# # Preferential Bayesian Optimization: Dueling-Thompson Sampling
#
# Implementation of the algorithm by Gonzalez et al (2017).

# %%
import numpy as np
import gpflow
import tensorflow as tf
import matplotlib.pyplot as plt
import sys
import os
import datetime
import pickle

from gpflow.utilities import set_trainable, print_summary
gpflow.config.set_default_summary_fmt("notebook")

sys.path.append(os.path.split(os.path.split(os.path.split(os.getcwd())[0])[0])[0]) # Move 3 levels up directory to import PBO
import PBO

# %%
def log(message):
    print(str(datetime.datetime.now()) + ': ' + message)

# %%
objective = PBO.objectives.six_hump_camel
objective_low = -1.5
objective_high = 1.5
objective_name = "SHC"
acquisition_name = "DTS"
experiment_name = "PBO" + "_" + acquisition_name + "_" + objective_name

# %%
num_runs = 20
num_evals = 20
num_samples = 100
num_choices = 2
input_dims = 2
num_maximizers = 20
num_init_points = 3
num_inducing_init = 3
num_discrete_per_dim = 50

# %%
results_dir = os.getcwd() + '/results/' + experiment_name + '/'

try:
    # Create target Directory
    os.makedirs(results_dir)
    print("Directory " , results_dir ,  " created ") 
except FileExistsError:
    print("Directory " , results_dir ,  " already exists")
# Out:
# Directory  /home/sebtsh/PBO/notebooks/DTS/results/PBO_DTS_SHC/  already exists

# %%
def visualize_model(query_points, y, m, title="Model", cmap="Spectral"):
    if query_points.shape[-1] != 2:
        return

    pos_vals = []
    neg_vals = []
    for i in range(len(y)):
        if y[i]:
            pos_vals.append(query_points[i])
        else:
            neg_vals.append(query_points[i])
    pos_vals = np.array(pos_vals)
    neg_vals = np.array(neg_vals)

    num_discrete_points = num_discrete_per_dim
    side = np.linspace(0, 1, num_discrete_points)
    X,Y = np.meshgrid(side,side)
    preds = tf.transpose(tf.reshape(m.predict_y(combs)[0], [num_discrete_points, num_discrete_points]))
    variances = tf.transpose(tf.reshape(PBO.acquisitions.dts.variance_logistic_f(m, combs), [num_discrete_points, num_discrete_points]))

    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.suptitle(title)
    fig.set_size_inches(18.5, 6.88)
    fig.set_dpi((200))
    
    ax1.axis('equal')
    if len(pos_vals) != 0:
        ax1.scatter(*pos_vals.T, c="black", marker="o")
    if len(neg_vals) != 0:
        ax1.scatter(*neg_vals.T, c="black", marker="x")
    im1 = ax1.imshow(preds, interpolation='nearest', extent=(0.0, 1.0, 0.0, 1.0), origin='lower', cmap=cmap)
    ax1.set_title("Mean of y(x, x')")
    ax1.set_xlabel("x")
    ax1.set_ylabel("x'")
    ax1.axvline(x=0.757, linestyle='--')
    fig.colorbar(im1, ax=ax1)

    ax2.axis('equal')
    if len(pos_vals) != 0:
        ax2.scatter(*pos_vals.T, c="black", marker="o")
    if len(neg_vals) != 0:
        ax2.scatter(*neg_vals.T, c="black", marker="x")
    im2 = ax2.imshow(variances, interpolation='nearest', extent=(0.0, 1.0, 0.0, 1.0), origin='lower', cmap=cmap)
    ax2.set_title("Variance of y(x, x')")
    ax2.set_xlabel("x")
    ax2.set_ylabel("x'")
    fig.colorbar(im2, ax=ax2)
    
    plt.savefig(fname=results_dir + title + ".png")

    plt.show()

# %%
def std_representation(X, num_choices):
    """
    :param X: tensor of shape (num_data, input_dims * num_choices)
    :return: tensor of shape (num_data, num_choices, input_dims)
    """
    input_dims = X.shape[-1] // num_choices
    ret_val = np.zeros((X.shape[0], num_choices, input_dims))
    
    for i in range(num_choices):
        ret_val[:, i, :] = X[:, input_dims*i:input_dims*(i+1)]
        
    return ret_val

# %%
def visualize_f_sample(f_vals, cmap="Spectral"):
    fig, (ax1) = plt.subplots(1)
    fig.suptitle('Sampled f values')
    fig.set_size_inches(4, 3.3)
    fig.set_dpi((100))
    
    ax1.axis('equal')
    im1 = ax1.imshow(tf.transpose(tf.reshape(f_vals, [num_discrete_points, num_discrete_points])),
                     interpolation='nearest', extent=(0.0, 1.0, 0.0, 1.0), origin='lower', cmap=cmap)
    ax1.set_xlabel("x")
    ax1.set_ylabel("x'")
    ax1.axvline(x=0.757, linestyle='--')
    fig.colorbar(im1, ax=ax1)

# %%
def get_noisy_observation_dts(X, objective):
    """
    :param X: tensor of shape (num_data, input_dims * 2)
    :param objective: objective function
    """
    num_data = X.shape[0]
    X_std = std_representation(X, num_choices) # (num_data, num_choices, input_dims)
    f = PBO.objectives.objective_get_f_neg(X_std, objective)
    obs = np.array(PBO.observation_model.gen_observation_from_f(X_std, f, 1))  # (num_data, 1, input_dims)

    ret_val = np.zeros((num_data, 1), dtype=np.int8)
    for i in range(num_data):
        if np.allclose(X_std[i, 0], obs[i, 0]):
            ret_val[i] = 1
    return ret_val

# %%
def train_and_visualize(X, y, lengthscale, title):

    kernel = gpflow.kernels.Product([gpflow.kernels.RBF(lengthscale=lengthscale, 
                                                        active_dims=[i, i+input_dims]) 
                                     for i in range(input_dims)])
    m = gpflow.models.VGP(data=(X, y),
                      kernel=kernel,
                      likelihood=gpflow.likelihoods.Bernoulli())
    optimizer = gpflow.optimizers.Scipy()
    optimizer.minimize(lambda: -m.log_likelihood(), m.trainable_variables)
    visualize_model(X, y, m, title=title)
    return m

# %%
def uniform_grid(input_dims, num_discrete_per_dim, low, high):
    """
    Returns an array with all possible permutations of discrete values in input_dims number of dimensions.
    :param input_dims: int
    :param num_discrete_per_dim: int
    :param low: int
    :param high: int
    :return: tensor of shape (num_discrete_per_dim ** input_dims, input_dims)
    """
    num_points = num_discrete_per_dim ** input_dims
    out = np.zeros([num_points, input_dims])
    discrete_points = np.linspace(low, high, num_discrete_per_dim)
    for i in range(num_points):
        for dim in range(input_dims):
            val = num_discrete_per_dim ** (dim)
            out[i, dim] = discrete_points[int((i // val) % num_discrete_per_dim)]
    return out

# %%
def best_guess(m, discrete_space, combs):
    return PBO.acquisitions.dts.soft_copeland_maximizer(m.predict_f(combs)[0], discrete_space)

# %%
def flip(X):
    """
    :param X: tensor of shape (num_data, input_dims * 2)
    :return: tensor of shape (num_data, input_dims * 2), where the first input_dims is swapped with the second
    """
    input_dims = X.shape[-1] // 2
    ret_val = np.zeros((X.shape))
    for i in range(X.shape[0]):
        ret_val[i, :input_dims] = X[i, input_dims:]
        ret_val[i, input_dims:] = X[i, :input_dims]
    return ret_val

# %%
def flip_y(y):
    """
    :param y: tensor of shape (num_data, 1), with int values either 0 or 1
    """
    return (y + 1) % 2

# %% [markdown]
# Create the initial values for each run:

# %%
np.random.seed(0)
init_points = np.random.uniform(low=objective_low, high=objective_high, size=[num_runs, num_init_points, input_dims])
num_combs = int((num_init_points-1) * num_init_points / 2)
init_vals = np.zeros([num_runs, num_combs, num_choices, input_dims])
for run in range(num_runs):
    cur_idx = 0
    for init_point in range(num_init_points-1):
        for next_point in range(init_point+1, num_init_points):
            init_vals[run, cur_idx, 0] = init_points[run, init_point]
            init_vals[run, cur_idx, 1] = init_points[run, next_point]
            cur_idx += 1

init_vals = np.reshape(init_vals, [num_runs, num_combs, num_choices * input_dims])
# symmetric_vals = np.flip(init_vals, axis=-2)
# symmetric_points = np.reshape(symmetric_vals, [num_runs, num_combs, num_choices * input_dims])

# init_vals = np.concatenate([init_points, symmetric_points], axis=-2)  # Model always has info about symmetric points

# %%
discrete_space = uniform_grid(input_dims, num_discrete_per_dim, objective_low, objective_high)
combs = PBO.acquisitions.dts.combinations(discrete_space)

# %% [markdown]
# Store the results in these arrays:

# %%
num_data_at_end = (num_combs + num_evals) * 2
X_results = np.zeros([num_runs, num_data_at_end, input_dims * num_choices])
y_results = np.zeros([num_runs, num_data_at_end, 1])
best_guess_results = np.zeros([num_runs, num_evals, input_dims])

# %%
for run in range(num_runs):
    #Fit a GP with kernel k to Dn
    
    X = init_vals[run]
    y = get_noisy_observation_dts(X, objective)
    
    X = np.vstack([X, flip(X)])
    y = np.vstack([y, flip_y(y)])
    
    model = train_and_visualize(X, y, lengthscale=0.1, title="Run_{}_Initial_model".format(run))  #TODO: CHECK LENGTHSCALE
    
    for evaluation in range(num_evals):
        log("Starting evaluation " + str(evaluation))
        
        # Sample f using RFF
        f_vals = PBO.acquisitions.dts.sample_f(model, X, combs)

        # 2 and 3. Compute the acquisition for duels alpha and get next duel
        log("Computing acquisition function")
        x_next = PBO.acquisitions.dts.soft_copeland_maximizer(f_vals, discrete_space)        
        
        all_pairs = np.concatenate([np.tile(x_next, (discrete_space.shape[0], 1)), discrete_space], axis=1)
        next_vars = np.squeeze(PBO.acquisitions.dts.variance_logistic_f(model, all_pairs), 
                               axis=1)
        xprime_next = discrete_space[np.argmax(next_vars)]
        
        x_xprime_next = np.expand_dims(np.concatenate([x_next, xprime_next]), axis=0)
        
        # Change by random small values otherwise Fourier features matrix becomes non-invertible\n",
        if np.all(np.equal(x_xprime_next, flip(x_xprime_next))):
            for i in range(len(x_xprime_next[0])):
                if x_xprime_next[0][i] < 0:
                    x_xprime_next[0][i] += np.random.uniform(low=0., high=1e-3)
                else:
                    x_xprime_next[0][i] -= np.random.uniform(low=0., high=1e-3)
        
        log("x and x_prime: \n" + str(x_xprime_next))
        
        # 4. Run the duel and get y
        y_next = get_noisy_observation_dts(x_xprime_next, objective)
        log("y_next: \n" + str(y_next))
        
        # 5. Augment X and Y, and add symmetric points
        X = np.vstack([X, x_xprime_next, flip(x_xprime_next)])
        y = np.vstack([y, y_next, flip_y(y_next)])
        
        # Fit a GP with kernel k to Dj and learn pi(x).
        model = train_and_visualize(X, y, lengthscale=0.1, title="Run_{}_Evaluation_{}".format(run, evaluation))
        
        # Get current best guess
        best_guess_results[run, evaluation] = best_guess(model, discrete_space, combs)

    X_results[run] = X
    y_results[run] = y
# Out:
# 2020-03-07 22:55:42.109952: Starting evaluation 0
# 2020-03-07 22:55:48.530328: Computing acquisition function
# 2020-03-07 22:55:48.617816: x and x_prime:
# [[ 1.5         0.39795918 -1.43877551 -1.5       ]]
# 2020-03-07 22:55:48.618937: y_next:
# [[1]]
# 2020-03-07 22:55:53.318257: Starting evaluation 1
# 2020-03-07 22:55:59.732192: Computing acquisition function
# 2020-03-07 22:55:59.842934: x and x_prime:
# [[ 1.5         0.76530612 -1.5         1.5       ]]
# 2020-03-07 22:55:59.845284: y_next:
# [[1]]
# 2020-03-07 22:56:05.592762: Starting evaluation 2
# 2020-03-07 22:56:11.597806: Computing acquisition function
# 2020-03-07 22:56:11.703190: x and x_prime:
# [[-1.5         0.8877551   1.5        -0.76530612]]
# 2020-03-07 22:56:11.704464: y_next:
# [[0]]
# 2020-03-07 22:56:17.845773: Starting evaluation 3
# 2020-03-07 22:56:24.556936: Computing acquisition function
# 2020-03-07 22:56:24.642379: x and x_prime:
# [[ 1.5        -1.5        -1.5        -1.31632653]]
# 2020-03-07 22:56:24.643167: y_next:
# [[1]]
# 2020-03-07 22:56:31.359918: Starting evaluation 4
# 2020-03-07 22:56:37.428968: Computing acquisition function
# 2020-03-07 22:56:37.535678: x and x_prime:
# [[-0.58163265  0.15306122 -1.5        -0.70408163]]
# 2020-03-07 22:56:37.537256: y_next:
# [[1]]
# 2020-03-07 22:56:44.769314: Starting evaluation 5
# 2020-03-07 22:56:50.935313: Computing acquisition function
# 2020-03-07 22:56:51.036208: x and x_prime:
# [[-0.2755102   0.52040816  1.5         1.31632653]]
# 2020-03-07 22:56:51.037114: y_next:
# [[1]]
# 2020-03-07 22:56:58.140199: Starting evaluation 6
# 2020-03-07 22:57:04.333563: Computing acquisition function
# 2020-03-07 22:57:04.411637: x and x_prime:
# [[ 0.33673469 -0.03061224 -1.5         1.5       ]]
# 2020-03-07 22:57:04.412874: y_next:
# [[1]]
# 2020-03-07 22:57:12.736612: Starting evaluation 7
# 2020-03-07 22:57:19.030984: Computing acquisition function
# 2020-03-07 22:57:19.122156: x and x_prime:
# [[-0.58163265 -0.03061224  1.5        -0.15306122]]
# 2020-03-07 22:57:19.123127: y_next:
# [[1]]
# 2020-03-07 22:57:28.304817: Starting evaluation 8
# 2020-03-07 22:57:34.650762: Computing acquisition function
# 2020-03-07 22:57:34.737532: x and x_prime:
# [[-0.39795918  0.76530612  1.5        -1.37755102]]
# 2020-03-07 22:57:34.738325: y_next:
# [[1]]
# 2020-03-07 22:57:44.485183: Starting evaluation 9
# 2020-03-07 22:57:50.588539: Computing acquisition function
# 2020-03-07 22:57:50.673272: x and x_prime:
# [[-0.82653061  1.25510204  1.5         1.31632653]]
# 2020-03-07 22:57:50.674082: y_next:
# [[1]]
# 2020-03-07 22:58:00.934212: Starting evaluation 10
# 2020-03-07 22:58:10.149485: Computing acquisition function
# 2020-03-07 22:58:10.253178: x and x_prime:
# [[-1.5         0.70408163 -1.5         1.13265306]]
# 2020-03-07 22:58:10.255181: y_next:
# [[1]]
# 2020-03-07 22:58:26.350627: Starting evaluation 11
# 2020-03-07 22:58:32.908244: Computing acquisition function
# 2020-03-07 22:58:33.182507: x and x_prime:
# [[ 1.5         0.52040816  1.5        -0.45918367]]
# 2020-03-07 22:58:33.183926: y_next:
# [[0]]
# 2020-03-07 22:58:45.393217: Starting evaluation 12
# 2020-03-07 22:58:51.748499: Computing acquisition function
# 2020-03-07 22:58:51.877156: x and x_prime:
# [[ 1.5         1.07142857 -1.5        -0.21428571]]
# 2020-03-07 22:58:51.878308: y_next:
# [[0]]
# 2020-03-07 22:59:03.638292: Starting evaluation 13
# 2020-03-07 22:59:10.230262: Computing acquisition function
# 2020-03-07 22:59:10.317018: x and x_prime:
# [[-1.5         0.33673469  1.5        -1.01020408]]
# 2020-03-07 22:59:10.318103: y_next:
# [[0]]
# 2020-03-07 22:59:24.608979: Starting evaluation 14
# 2020-03-07 22:59:31.103671: Computing acquisition function
# 2020-03-07 22:59:31.199833: x and x_prime:
# [[ 1.5        -0.8877551   1.5        -0.70408163]]
# 2020-03-07 22:59:31.201154: y_next:
# [[0]]
# 2020-03-07 22:59:44.792268: Starting evaluation 15
# 2020-03-07 22:59:51.166621: Computing acquisition function
# 2020-03-07 22:59:51.255119: x and x_prime:
# [[ 0.58163265  0.82653061 -1.5        -1.5       ]]
# 2020-03-07 22:59:51.256078: y_next:
# [[1]]
# 2020-03-07 23:00:04.272385: Starting evaluation 16
# 2020-03-07 23:00:10.962084: Computing acquisition function
# 2020-03-07 23:00:11.057971: x and x_prime:
# [[ 0.94897959  0.09183673 -1.5        -1.5       ]]
# 2020-03-07 23:00:11.059581: y_next:
# [[1]]
# 2020-03-07 23:00:28.401307: Starting evaluation 17
# 2020-03-07 23:00:34.412071: Computing acquisition function
# 2020-03-07 23:00:34.592769: x and x_prime:
# [[ 0.94897959  0.82653061 -1.07142857 -1.5       ]]
# 2020-03-07 23:00:34.594978: y_next:
# [[1]]
# 2020-03-07 23:00:55.309800: Starting evaluation 18
# 2020-03-07 23:01:02.349426: Computing acquisition function
# 2020-03-07 23:01:02.441055: x and x_prime:
# [[ 1.43877551 -0.15306122 -1.37755102 -0.03061224]]
# 2020-03-07 23:01:02.442654: y_next:
# [[1]]
# 2020-03-07 23:01:17.525916: Starting evaluation 19
# 2020-03-07 23:01:24.454192: Computing acquisition function
# 2020-03-07 23:01:24.533429: x and x_prime:
# [[-0.39795918 -1.13265306 -1.5        -1.5       ]]
# 2020-03-07 23:01:24.534254: y_next:
# [[1]]
# 2020-03-07 23:01:42.914791: Starting evaluation 0
# 2020-03-07 23:01:50.195358: Computing acquisition function
# 2020-03-07 23:01:50.277341: x and x_prime:
# [[ 0.70408163 -0.8877551  -1.5        -1.5       ]]
# 2020-03-07 23:01:50.278830: y_next:
# [[1]]
# 2020-03-07 23:01:55.807732: Starting evaluation 1
# 2020-03-07 23:02:02.952262: Computing acquisition function
# 2020-03-07 23:02:03.026152: x and x_prime:
# [[-1.43877551 -1.07142857  0.52040816 -1.37755102]]
# 2020-03-07 23:02:03.026967: y_next:
# [[1]]
# 2020-03-07 23:02:10.806780: Starting evaluation 2
# 2020-03-07 23:02:17.019018: Computing acquisition function
# 2020-03-07 23:02:17.139273: x and x_prime:
# [[ 1.01020408 -0.58163265 -0.15306122  0.8877551 ]]
# 2020-03-07 23:02:17.140294: y_next:
# [[0]]
# 2020-03-07 23:02:24.117669: Starting evaluation 3
# 2020-03-07 23:02:30.092962: Computing acquisition function
# 2020-03-07 23:02:30.173462: x and x_prime:
# [[-1.13265306 -1.25510204  1.01020408 -1.13265306]]
# 2020-03-07 23:02:30.174611: y_next:
# [[0]]
# 2020-03-07 23:02:39.146564: Starting evaluation 4
# 2020-03-07 23:02:45.470991: Computing acquisition function
# 2020-03-07 23:02:45.560607: x and x_prime:
# [[-1.13265306  0.09183673 -1.5        -1.5       ]]
# 2020-03-07 23:02:45.561795: y_next:
# [[1]]
# 2020-03-07 23:02:57.221589: Starting evaluation 5
# 2020-03-07 23:03:05.661690: Computing acquisition function
# 2020-03-07 23:03:05.845285: x and x_prime:
# [[-1.01020408 -0.15306122 -0.8877551  -1.43877551]]
# 2020-03-07 23:03:05.847309: y_next:
# [[1]]
# 2020-03-07 23:03:18.829964: Starting evaluation 6
# 2020-03-07 23:03:26.466588: Computing acquisition function
# 2020-03-07 23:03:26.575634: x and x_prime:
# [[-0.52040816  0.15306122 -0.94897959 -1.43877551]]
# 2020-03-07 23:03:26.576879: y_next:
# [[1]]
# 2020-03-07 23:03:38.233406: Starting evaluation 7
# 2020-03-07 23:03:44.348791: Computing acquisition function
# 2020-03-07 23:03:44.457071: x and x_prime:
# [[-0.82653061 -0.15306122 -0.52040816 -1.07142857]]
# 2020-03-07 23:03:44.458029: y_next:
# [[0]]
# 2020-03-07 23:03:57.052038: Starting evaluation 8
# 2020-03-07 23:04:04.366969: Computing acquisition function
# 2020-03-07 23:04:04.455112: x and x_prime:
# [[ 1.37755102  0.70408163  1.37755102 -0.39795918]]
# 2020-03-07 23:04:04.456383: y_next:
# [[1]]
# 2020-03-07 23:04:18.624956: Starting evaluation 9
# 2020-03-07 23:04:24.456326: Computing acquisition function
# 2020-03-07 23:04:24.546615: x and x_prime:
# [[ 1.31632653  0.39795918  0.94897959 -0.8877551 ]]
# 2020-03-07 23:04:24.547940: y_next:
# [[0]]
# 2020-03-07 23:04:40.508066: Starting evaluation 10
# 2020-03-07 23:04:46.894856: Computing acquisition function
# 2020-03-07 23:04:46.976726: x and x_prime:
# [[-0.64285714  0.76530612  1.25510204 -0.82653061]]
# 2020-03-07 23:04:46.977509: y_next:
# [[0]]
# 2020-03-07 23:05:01.435504: Starting evaluation 11
# 2020-03-07 23:05:08.156581: Computing acquisition function
# 2020-03-07 23:05:08.254526: x and x_prime:
# [[ 0.33673469 -0.39795918 -0.15306122  0.94897959]]
# 2020-03-07 23:05:08.255620: y_next:
# [[0]]
# 2020-03-07 23:05:24.435396: Starting evaluation 12
# 2020-03-07 23:05:32.591979: Computing acquisition function
# 2020-03-07 23:05:32.708280: x and x_prime:
# [[-0.03061224 -1.5        -1.5        -1.19387755]]
# 2020-03-07 23:05:32.709215: y_next:
# [[0]]
# 2020-03-07 23:05:52.764198: Starting evaluation 13
# 2020-03-07 23:06:01.852993: Computing acquisition function
# 2020-03-07 23:06:01.992850: x and x_prime:
# [[-0.70408163  0.52040816 -0.39795918 -1.37755102]]
# 2020-03-07 23:06:01.995555: y_next:
# [[1]]
# 2020-03-07 23:06:19.753325: Starting evaluation 14
# 2020-03-07 23:06:26.871548: Computing acquisition function
# 2020-03-07 23:06:26.991615: x and x_prime:
# [[1.37755102 0.21428571 0.45918367 0.03061224]]
# 2020-03-07 23:06:26.993067: y_next:
# [[0]]
# 2020-03-07 23:06:47.679298: Starting evaluation 15
# 2020-03-07 23:06:54.756955: Computing acquisition function
# 2020-03-07 23:06:54.860651: x and x_prime:
# [[-0.03061224  0.33673469 -0.15306122 -1.43877551]]
# 2020-03-07 23:06:54.861982: y_next:
# [[1]]
# 2020-03-07 23:07:17.537146: Starting evaluation 16
# 2020-03-07 23:07:23.916982: Computing acquisition function
# 2020-03-07 23:07:24.009700: x and x_prime:
# [[ 0.15306122  1.43877551  1.25510204 -0.76530612]]
# 2020-03-07 23:07:24.012300: y_next:
# [[0]]
# 2020-03-07 23:07:45.883644: Starting evaluation 17
# 2020-03-07 23:07:52.437256: Computing acquisition function
# 2020-03-07 23:07:52.522178: x and x_prime:
# [[-0.33673469  1.25510204  1.07142857 -1.25510204]]
# 2020-03-07 23:07:52.523055: y_next:
# [[0]]
# 2020-03-07 23:08:22.272281: Starting evaluation 18
# 2020-03-07 23:08:31.139697: Computing acquisition function
# 2020-03-07 23:08:31.225522: x and x_prime:
# [[ 0.09183673 -0.64285714 -1.5        -1.25510204]]
# 2020-03-07 23:08:31.227238: y_next:
# [[1]]
# 2020-03-07 23:08:54.392482: Starting evaluation 19
# 2020-03-07 23:09:00.700380: Computing acquisition function
# 2020-03-07 23:09:00.788951: x and x_prime:
# [[-1.25510204 -1.25510204 -0.15306122 -1.07142857]]
# 2020-03-07 23:09:00.790569: y_next:
# [[0]]
# 2020-03-07 23:09:28.700909: Starting evaluation 0
# 2020-03-07 23:09:35.081286: Computing acquisition function
# 2020-03-07 23:09:35.237028: x and x_prime:
# [[-1.19387755  0.33673469 -1.01020408 -1.37755102]]
# 2020-03-07 23:09:35.239062: y_next:
# [[1]]
# 2020-03-07 23:09:41.754528: Starting evaluation 1
# 2020-03-07 23:09:49.795945: Computing acquisition function
# 2020-03-07 23:09:49.944572: x and x_prime:
# [[ 0.39795918  1.37755102 -0.76530612 -1.37755102]]
# 2020-03-07 23:09:49.947760: y_next:
# [[1]]
# 2020-03-07 23:09:56.811117: Starting evaluation 2
# 2020-03-07 23:10:03.078931: Computing acquisition function
# 2020-03-07 23:10:03.185261: x and x_prime:
# [[-1.43877551 -0.39795918 -1.13265306 -1.5       ]]
# 2020-03-07 23:10:03.186606: y_next:
# [[1]]
# 2020-03-07 23:10:10.207832: Starting evaluation 3
# 2020-03-07 23:10:16.362910: Computing acquisition function
# 2020-03-07 23:10:16.484663: x and x_prime:
# [[-1.31632653 -0.2755102  -1.37755102 -0.94897959]]
# 2020-03-07 23:10:16.487006: y_next:
# [[1]]
# 2020-03-07 23:10:24.505881: Starting evaluation 4
# 2020-03-07 23:10:30.749103: Computing acquisition function
# 2020-03-07 23:10:30.924024: x and x_prime:
# [[ 1.31632653  1.5        -1.5        -1.5       ]]
# 2020-03-07 23:10:30.925110: y_next:
# [[1]]
# 2020-03-07 23:10:40.149242: Starting evaluation 5
# 2020-03-07 23:10:46.836234: Computing acquisition function
# 2020-03-07 23:10:46.926076: x and x_prime:
# [[-0.39795918 -1.25510204 -1.43877551 -0.52040816]]
# 2020-03-07 23:10:46.926869: y_next:
# [[0]]
# 2020-03-07 23:11:02.176084: Starting evaluation 6
# 2020-03-07 23:11:11.206519: Computing acquisition function
# 2020-03-07 23:11:11.303571: x and x_prime:
# [[-0.76530612  1.5        -1.5        -1.5       ]]
# 2020-03-07 23:11:11.305035: y_next:
# [[1]]
# 2020-03-07 23:11:23.412155: Starting evaluation 7
# 2020-03-07 23:11:30.054429: Computing acquisition function
# 2020-03-07 23:11:30.138492: x and x_prime:
# [[-0.52040816 -0.45918367 -1.5        -1.5       ]]
# 2020-03-07 23:11:30.140118: y_next:
# [[1]]
# 2020-03-07 23:11:41.078073: Starting evaluation 8
# 2020-03-07 23:11:47.591028: Computing acquisition function
# 2020-03-07 23:11:47.689020: x and x_prime:
# [[ 0.58163265 -0.70408163 -1.5        -1.5       ]]
# 2020-03-07 23:11:47.690242: y_next:
# [[1]]
# 2020-03-07 23:12:01.858759: Starting evaluation 9
# 2020-03-07 23:12:07.776314: Computing acquisition function
# 2020-03-07 23:12:07.909245: x and x_prime:
# [[-0.39795918  0.58163265 -1.5        -1.5       ]]
# 2020-03-07 23:12:07.910751: y_next:
# [[1]]
# 2020-03-07 23:12:23.412924: Starting evaluation 10
# 2020-03-07 23:12:29.398535: Computing acquisition function
# 2020-03-07 23:12:29.490539: x and x_prime:
# [[ 0.45918367  1.37755102 -0.8877551  -0.70408163]]
# 2020-03-07 23:12:29.492859: y_next:
# [[0]]
# 2020-03-07 23:12:47.155146: Starting evaluation 11
# 2020-03-07 23:12:53.670547: Computing acquisition function
# 2020-03-07 23:12:53.755893: x and x_prime:
# [[-0.64285714 -0.45918367 -0.94897959 -1.5       ]]
# 2020-03-07 23:12:53.757646: y_next:
# [[1]]
# 2020-03-07 23:13:08.603546: Starting evaluation 12
# 2020-03-07 23:13:14.570439: Computing acquisition function
# 2020-03-07 23:13:14.648960: x and x_prime:
# [[ 0.33673469 -0.21428571 -1.43877551 -1.19387755]]
# 2020-03-07 23:13:14.649761: y_next:
# [[1]]
# 2020-03-07 23:13:31.620795: Starting evaluation 13
# 2020-03-07 23:13:38.142240: Computing acquisition function
# 2020-03-07 23:13:38.228258: x and x_prime:
# [[ 0.58163265 -1.31632653 -1.5        -1.25510204]]
# 2020-03-07 23:13:38.229087: y_next:
# [[1]]
# 2020-03-07 23:13:57.868593: Starting evaluation 14
# 2020-03-07 23:14:06.006433: Computing acquisition function
# 2020-03-07 23:14:06.090788: x and x_prime:
# [[-0.33673469 -0.09183673 -0.39795918 -1.37755102]]
# 2020-03-07 23:14:06.092213: y_next:
# [[1]]
# 2020-03-07 23:14:26.713193: Starting evaluation 15
# 2020-03-07 23:14:33.188646: Computing acquisition function
# 2020-03-07 23:14:33.280789: x and x_prime:
# [[-1.19387755 -0.52040816  0.21428571 -0.82653061]]
# 2020-03-07 23:14:33.282412: y_next:
# [[0]]
# 2020-03-07 23:14:51.797878: Starting evaluation 16
# 2020-03-07 23:14:57.675681: Computing acquisition function
# 2020-03-07 23:14:57.748486: x and x_prime:
# [[-1.25510204  0.15306122 -0.76530612 -0.8877551 ]]
# 2020-03-07 23:14:57.749339: y_next:
# [[0]]
# 2020-03-07 23:15:18.837530: Starting evaluation 17
# 2020-03-07 23:15:25.834957: Computing acquisition function
# 2020-03-07 23:15:25.918308: x and x_prime:
# [[ 1.37755102 -1.31632653 -1.5        -1.5       ]]
# 2020-03-07 23:15:25.919094: y_next:
# [[1]]
# 2020-03-07 23:15:48.804489: Starting evaluation 18
# 2020-03-07 23:15:56.286395: Computing acquisition function
# 2020-03-07 23:15:56.434741: x and x_prime:
# [[ 1.5         1.07142857 -1.43877551 -1.19387755]]
# 2020-03-07 23:15:56.436475: y_next:
# [[1]]
# 2020-03-07 23:16:19.261638: Starting evaluation 19
# 2020-03-07 23:16:25.540606: Computing acquisition function
# 2020-03-07 23:16:25.681610: x and x_prime:
# [[ 1.25510204  0.70408163 -0.94897959 -0.76530612]]
# 2020-03-07 23:16:25.682411: y_next:
# [[0]]
# 2020-03-07 23:16:50.031727: Starting evaluation 0
# 2020-03-07 23:16:56.331986: Computing acquisition function
# 2020-03-07 23:16:56.443659: x and x_prime:
# [[-1.43877551  1.19387755 -1.5        -1.5       ]]
# 2020-03-07 23:16:56.444993: y_next:
# [[1]]
# 2020-03-07 23:17:01.839683: Starting evaluation 1
# 2020-03-07 23:17:09.374390: Computing acquisition function
# 2020-03-07 23:17:09.444343: x and x_prime:
# [[ 0.39795918 -1.43877551 -1.5        -1.5       ]]
# 2020-03-07 23:17:09.445136: y_next:
# [[1]]
# 2020-03-07 23:17:16.022275: Starting evaluation 2
# 2020-03-07 23:17:22.583786: Computing acquisition function
# 2020-03-07 23:17:22.739400: x and x_prime:
# [[-0.94897959  0.94897959 -1.37755102 -1.25510204]]
# 2020-03-07 23:17:22.740305: y_next:
# [[1]]
# 2020-03-07 23:17:29.964056: Starting evaluation 3
# 2020-03-07 23:17:37.877412: Computing acquisition function
# 2020-03-07 23:17:38.007152: x and x_prime:
# [[ 0.94897959 -0.09183673 -1.5        -1.5       ]]
# 2020-03-07 23:17:38.007946: y_next:
# [[1]]
# 2020-03-07 23:17:45.954280: Starting evaluation 4
# 2020-03-07 23:17:51.654404: Computing acquisition function
# 2020-03-07 23:17:51.729770: x and x_prime:
# [[-0.94897959 -0.03061224 -1.5        -1.5       ]]
# 2020-03-07 23:17:51.730540: y_next:
# [[1]]
# 2020-03-07 23:18:00.257816: Starting evaluation 5
# 2020-03-07 23:18:06.752846: Computing acquisition function
# 2020-03-07 23:18:06.838007: x and x_prime:
# [[0.03061224 0.70408163 1.37755102 0.2755102 ]]
# 2020-03-07 23:18:06.838811: y_next:
# [[1]]
# 2020-03-07 23:18:18.179639: Starting evaluation 6
# 2020-03-07 23:18:24.960099: Computing acquisition function
# 2020-03-07 23:18:25.039877: x and x_prime:
# [[-0.39795918 -0.2755102  -1.43877551 -1.19387755]]
# 2020-03-07 23:18:25.040666: y_next:
# [[1]]
# 2020-03-07 23:18:36.297029: Starting evaluation 7
# 2020-03-07 23:18:43.309876: Computing acquisition function
# 2020-03-07 23:18:43.389590: x and x_prime:
# [[-0.64285714  0.8877551   1.25510204  0.76530612]]
# 2020-03-07 23:18:43.390457: y_next:
# [[1]]
# 2020-03-07 23:18:57.903594: Starting evaluation 8
# 2020-03-07 23:19:04.782030: Computing acquisition function
# 2020-03-07 23:19:04.859889: x and x_prime:
# [[-1.19387755 -1.01020408 -1.07142857  0.52040816]]
# 2020-03-07 23:19:04.861315: y_next:
# [[0]]
# 2020-03-07 23:19:17.002758: Starting evaluation 9
# 2020-03-07 23:19:23.427343: Computing acquisition function
# 2020-03-07 23:19:23.517819: x and x_prime:
# [[-1.19387755 -0.76530612 -0.45918367 -0.58163265]]
# 2020-03-07 23:19:23.519521: y_next:
# [[0]]
# 2020-03-07 23:19:36.461478: Starting evaluation 10
# 2020-03-07 23:19:42.374656: Computing acquisition function
# 2020-03-07 23:19:42.490854: x and x_prime:
# [[-0.15306122  1.31632653  1.25510204  0.45918367]]
# 2020-03-07 23:19:42.492229: y_next:
# [[0]]
# 2020-03-07 23:19:56.651916: Starting evaluation 11
# 2020-03-07 23:20:03.258472: Computing acquisition function
# 2020-03-07 23:20:03.336809: x and x_prime:
# [[-0.33673469  0.03061224 -0.82653061 -1.07142857]]
# 2020-03-07 23:20:03.337615: y_next:
# [[1]]
# 2020-03-07 23:20:19.255311: Starting evaluation 12
# 2020-03-07 23:20:26.650597: Computing acquisition function
# 2020-03-07 23:20:26.740070: x and x_prime:
# [[-0.76530612  0.52040816 -0.52040816 -1.19387755]]
# 2020-03-07 23:20:26.741494: y_next:
# [[1]]
# 2020-03-07 23:20:46.133700: Starting evaluation 13
# 2020-03-07 23:20:54.175684: Computing acquisition function
# 2020-03-07 23:20:54.265199: x and x_prime:
# [[-0.45918367  0.33673469 -0.15306122 -0.76530612]]
# 2020-03-07 23:20:54.266297: y_next:
# [[1]]
# 2020-03-07 23:21:12.014034: Starting evaluation 14
# 2020-03-07 23:21:18.578528: Computing acquisition function
# 2020-03-07 23:21:18.665515: x and x_prime:
# [[-0.70408163  0.33673469 -0.03061224 -1.31632653]]
# 2020-03-07 23:21:18.666299: y_next:
# [[1]]
# 2020-03-07 23:21:38.331871: Starting evaluation 15
# 2020-03-07 23:21:44.664804: Computing acquisition function
# 2020-03-07 23:21:45.009423: x and x_prime:
# [[-0.33673469 -0.76530612 -0.70408163 -1.37755102]]
# 2020-03-07 23:21:45.010884: y_next:
# [[1]]
# 2020-03-07 23:22:07.064698: Starting evaluation 16
# 2020-03-07 23:22:14.358148: Computing acquisition function
# 2020-03-07 23:22:14.446047: x and x_prime:
# [[-1.13265306  1.19387755 -0.94897959 -1.07142857]]
# 2020-03-07 23:22:14.447008: y_next:
# [[1]]
# 2020-03-07 23:22:35.210906: Starting evaluation 17
# 2020-03-07 23:22:41.461322: Computing acquisition function
# 2020-03-07 23:22:41.621958: x and x_prime:
# [[-0.21428571  0.8877551  -0.52040816 -1.43877551]]
# 2020-03-07 23:22:41.622771: y_next:
# [[1]]
# 2020-03-07 23:23:03.235166: Starting evaluation 18
# 2020-03-07 23:23:09.311979: Computing acquisition function
# 2020-03-07 23:23:09.387023: x and x_prime:
# [[-0.21428571 -0.94897959 -1.19387755 -1.13265306]]
# 2020-03-07 23:23:09.388117: y_next:
# [[1]]
# 2020-03-07 23:23:34.788575: Starting evaluation 19
# 2020-03-07 23:23:42.346195: Computing acquisition function
# 2020-03-07 23:23:42.435014: x and x_prime:
# [[ 0.09183673 -1.13265306 -0.64285714 -1.5       ]]
# 2020-03-07 23:23:42.436616: y_next:
# [[1]]
# 2020-03-07 23:24:09.802410: Starting evaluation 0
# 2020-03-07 23:24:16.015664: Computing acquisition function
# 2020-03-07 23:24:16.110908: x and x_prime:
# [[ 0.70408163 -1.31632653 -1.5        -1.5       ]]
# 2020-03-07 23:24:16.112626: y_next:
# [[1]]
# 2020-03-07 23:24:21.653710: Starting evaluation 1
# 2020-03-07 23:24:27.566455: Computing acquisition function
# 2020-03-07 23:24:27.639695: x and x_prime:
# [[ 0.15306122 -0.39795918 -0.58163265  1.25510204]]
# 2020-03-07 23:24:27.641107: y_next:
# [[1]]
# 2020-03-07 23:24:33.614086: Starting evaluation 2
# 2020-03-07 23:24:40.839796: Computing acquisition function
# 2020-03-07 23:24:40.921093: x and x_prime:
# [[-1.01020408 -0.82653061 -1.5        -1.5       ]]
# 2020-03-07 23:24:40.921970: y_next:
# [[1]]
# 2020-03-07 23:24:49.364097: Starting evaluation 3
# 2020-03-07 23:24:55.901786: Computing acquisition function
# 2020-03-07 23:24:56.017755: x and x_prime:
# [[ 0.52040816  0.8877551  -1.5        -1.5       ]]
# 2020-03-07 23:24:56.018803: y_next:
# [[1]]
# 2020-03-07 23:25:04.531310: Starting evaluation 4
# 2020-03-07 23:25:12.259918: Computing acquisition function
# 2020-03-07 23:25:12.349756: x and x_prime:
# [[-0.33673469  1.13265306  0.09183673 -1.01020408]]
# 2020-03-07 23:25:12.351073: y_next:
# [[0]]
# 2020-03-07 23:25:21.629914: Starting evaluation 5
# 2020-03-07 23:25:28.899025: Computing acquisition function
# 2020-03-07 23:25:28.980968: x and x_prime:
# [[ 0.33673469  0.21428571 -1.13265306  1.25510204]]
# 2020-03-07 23:25:28.982113: y_next:
# [[1]]
# 2020-03-07 23:25:40.438289: Starting evaluation 6
# 2020-03-07 23:25:47.033390: Computing acquisition function
# 2020-03-07 23:25:47.109440: x and x_prime:
# [[ 1.19387755  0.2755102  -1.5        -1.5       ]]
# 2020-03-07 23:25:47.110214: y_next:
# [[1]]
# 2020-03-07 23:25:57.247899: Starting evaluation 7
# 2020-03-07 23:26:03.316739: Computing acquisition function
# 2020-03-07 23:26:03.396462: x and x_prime:
# [[ 0.64285714 -0.52040816 -0.70408163  1.5       ]]
# 2020-03-07 23:26:03.397556: y_next:
# [[1]]
# 2020-03-07 23:26:14.367429: Starting evaluation 8
# 2020-03-07 23:26:20.052808: Computing acquisition function
# 2020-03-07 23:26:20.167688: x and x_prime:
# [[ 0.76530612 -1.13265306 -1.07142857  1.37755102]]
# 2020-03-07 23:26:20.168925: y_next:
# [[1]]
# 2020-03-07 23:26:33.182387: Starting evaluation 9
# 2020-03-07 23:26:39.482300: Computing acquisition function
# 2020-03-07 23:26:39.566773: x and x_prime:
# [[ 1.43877551  1.07142857 -1.5        -1.5       ]]
# 2020-03-07 23:26:39.567649: y_next:
# [[1]]
# 2020-03-07 23:26:54.363585: Starting evaluation 10
# 2020-03-07 23:27:01.587688: Computing acquisition function
# 2020-03-07 23:27:01.869474: x and x_prime:
# [[ 0.2755102   0.45918367 -1.13265306 -1.19387755]]
# 2020-03-07 23:27:01.871314: y_next:
# [[1]]
# 2020-03-07 23:27:18.598895: Starting evaluation 11
# 2020-03-07 23:27:25.825895: Computing acquisition function
# 2020-03-07 23:27:25.932811: x and x_prime:
# [[-0.39795918  1.5         0.45918367  0.09183673]]
# 2020-03-07 23:27:25.934158: y_next:
# [[0]]
# 2020-03-07 23:27:41.687757: Starting evaluation 12
# 2020-03-07 23:27:47.981472: Computing acquisition function
# 2020-03-07 23:27:48.072105: x and x_prime:
# [[-0.21428571 -0.76530612 -0.09183673  0.52040816]]
# 2020-03-07 23:27:48.072915: y_next:
# [[1]]
# 2020-03-07 23:28:06.437673: Starting evaluation 13
# 2020-03-07 23:28:13.578482: Computing acquisition function
# 2020-03-07 23:28:13.664998: x and x_prime:
# [[ 0.33673469 -1.07142857 -1.37755102 -1.13265306]]
# 2020-03-07 23:28:13.666043: y_next:
# [[1]]
# 2020-03-07 23:28:32.729476: Starting evaluation 14
# 2020-03-07 23:28:38.830819: Computing acquisition function
# 2020-03-07 23:28:38.923888: x and x_prime:
# [[-0.76530612 -0.8877551   0.15306122  0.2755102 ]]
# 2020-03-07 23:28:38.924898: y_next:
# [[0]]
# 2020-03-07 23:29:02.452823: Starting evaluation 15
# 2020-03-07 23:29:08.880117: Computing acquisition function
# 2020-03-07 23:29:08.972199: x and x_prime:
# [[ 0.45918367 -1.5        -0.76530612 -1.31632653]]
# 2020-03-07 23:29:08.973087: y_next:
# [[0]]
# 2020-03-07 23:29:28.483540: Starting evaluation 16
# 2020-03-07 23:29:34.594734: Computing acquisition function
# 2020-03-07 23:29:34.692521: x and x_prime:
# [[ 0.8877551  -0.70408163 -1.5        -0.76530612]]
# 2020-03-07 23:29:34.693952: y_next:
# [[1]]
# 2020-03-07 23:29:56.048136: Starting evaluation 17
# 2020-03-07 23:30:01.794550: Computing acquisition function
# 2020-03-07 23:30:01.869640: x and x_prime:
# [[-0.8877551   1.01020408  0.03061224 -0.8877551 ]]
# 2020-03-07 23:30:01.870412: y_next:
# [[0]]
# 2020-03-07 23:30:22.832499: Starting evaluation 18
# 2020-03-07 23:30:30.683078: Computing acquisition function
# 2020-03-07 23:30:30.767998: x and x_prime:
# [[-0.2755102   0.64285714 -0.8877551  -0.58163265]]
# 2020-03-07 23:30:30.768783: y_next:
# [[1]]
# 2020-03-07 23:30:55.993298: Starting evaluation 19
# 2020-03-07 23:31:02.263881: Computing acquisition function
# 2020-03-07 23:31:02.375681: x and x_prime:
# [[ 1.5        -0.45918367 -1.5        -1.5       ]]
# 2020-03-07 23:31:02.376584: y_next:
# [[1]]
# 2020-03-07 23:31:26.282875: Starting evaluation 0
# 2020-03-07 23:31:33.570327: Computing acquisition function
# 2020-03-07 23:31:33.684771: x and x_prime:
# [[ 1.07142857 -0.21428571 -1.5        -1.5       ]]
# 2020-03-07 23:31:33.686231: y_next:
# [[1]]
# 2020-03-07 23:31:40.606980: Starting evaluation 1
# 2020-03-07 23:31:47.113006: Computing acquisition function
# 2020-03-07 23:31:47.196616: x and x_prime:
# [[-0.15306122  1.19387755  0.09183673  0.03061224]]
# 2020-03-07 23:31:47.197500: y_next:
# [[0]]
# 2020-03-07 23:31:53.441197: Starting evaluation 2
# 2020-03-07 23:32:01.178511: Computing acquisition function
# 2020-03-07 23:32:01.258290: x and x_prime:
# [[-1.07142857  0.03061224 -0.64285714  0.64285714]]
# 2020-03-07 23:32:01.259224: y_next:
# [[0]]
# 2020-03-07 23:32:09.044932: Starting evaluation 3
# 2020-03-07 23:32:14.899744: Computing acquisition function
# 2020-03-07 23:32:15.010000: x and x_prime:
# [[-0.58163265 -1.25510204 -1.5        -1.5       ]]
# 2020-03-07 23:32:15.010941: y_next:
# [[1]]
# 2020-03-07 23:32:23.329689: Starting evaluation 4
# 2020-03-07 23:32:31.616477: Computing acquisition function
# 2020-03-07 23:32:31.700999: x and x_prime:
# [[-1.01020408 -1.5        -0.64285714 -0.82653061]]
# 2020-03-07 23:32:31.702134: y_next:
# [[0]]
# 2020-03-07 23:32:41.553038: Starting evaluation 5
# 2020-03-07 23:32:48.157150: Computing acquisition function
# 2020-03-07 23:32:48.254002: x and x_prime:
# [[ 1.07142857  0.33673469 -1.25510204 -1.31632653]]
# 2020-03-07 23:32:48.254610: y_next:
# [[1]]
# 2020-03-07 23:32:56.984192: Starting evaluation 6
# 2020-03-07 23:33:02.954523: Computing acquisition function
# 2020-03-07 23:33:03.028499: x and x_prime:
# [[-0.76530612  0.45918367 -0.58163265  0.09183673]]
# 2020-03-07 23:33:03.029326: y_next:
# [[0]]
# 2020-03-07 23:33:12.179709: Starting evaluation 7
# 2020-03-07 23:33:17.965106: Computing acquisition function
# 2020-03-07 23:33:18.043727: x and x_prime:
# [[ 1.25510204 -0.8877551  -1.07142857 -1.5       ]]
# 2020-03-07 23:33:18.044592: y_next:
# [[1]]
# 2020-03-07 23:33:28.326121: Starting evaluation 8
# 2020-03-07 23:33:34.278866: Computing acquisition function
# 2020-03-07 23:33:34.373221: x and x_prime:
# [[-0.58163265  0.21428571 -1.25510204 -0.58163265]]
# 2020-03-07 23:33:34.374374: y_next:
# [[1]]
# 2020-03-07 23:33:46.789058: Starting evaluation 9
# 2020-03-07 23:33:53.034895: Computing acquisition function
# 2020-03-07 23:33:53.126647: x and x_prime:
# [[ 1.5        -1.43877551 -1.19387755 -1.31632653]]
# 2020-03-07 23:33:53.127460: y_next:
# [[1]]
# 2020-03-07 23:34:09.613791: Starting evaluation 10
# 2020-03-07 23:34:16.075590: Computing acquisition function
# 2020-03-07 23:34:16.237062: x and x_prime:
# [[ 0.52040816 -1.37755102 -1.5        -1.5       ]]
# 2020-03-07 23:34:16.238192: y_next:
# [[1]]
# 2020-03-07 23:34:30.400698: Starting evaluation 11
# 2020-03-07 23:34:37.020960: Computing acquisition function
# 2020-03-07 23:34:37.107984: x and x_prime:
# [[-0.15306122  0.09183673 -1.01020408 -0.15306122]]
# 2020-03-07 23:34:37.109110: y_next:
# [[1]]
# 2020-03-07 23:34:50.896402: Starting evaluation 12
# 2020-03-07 23:34:57.196804: Computing acquisition function
# 2020-03-07 23:34:57.274822: x and x_prime:
# [[-0.94897959 -1.43877551  0.33673469 -1.5       ]]
# 2020-03-07 23:34:57.276509: y_next:
# [[0]]
# 2020-03-07 23:35:15.551894: Starting evaluation 13
# 2020-03-07 23:35:21.619859: Computing acquisition function
# 2020-03-07 23:35:21.707546: x and x_prime:
# [[-0.8877551 -0.8877551  0.8877551 -1.5      ]]
# 2020-03-07 23:35:21.708655: y_next:
# [[1]]
# 2020-03-07 23:35:42.291139: Starting evaluation 14
# 2020-03-07 23:35:48.105585: Computing acquisition function
# 2020-03-07 23:35:48.213934: x and x_prime:
# [[-0.15306122 -1.07142857 -1.13265306 -1.37755102]]
# 2020-03-07 23:35:48.214714: y_next:
# [[1]]
# 2020-03-07 23:36:06.775132: Starting evaluation 15
# 2020-03-07 23:36:12.741354: Computing acquisition function
# 2020-03-07 23:36:12.825800: x and x_prime:
# [[ 0.70408163 -1.07142857 -1.25510204 -1.01020408]]
# 2020-03-07 23:36:12.826813: y_next:
# [[1]]
# 2020-03-07 23:36:29.108277: Starting evaluation 16
# 2020-03-07 23:36:34.790044: Computing acquisition function
# 2020-03-07 23:36:34.873608: x and x_prime:
# [[ 0.39795918 -0.03061224  0.2755102   1.19387755]]
# 2020-03-07 23:36:34.874456: y_next:
# [[1]]
# 2020-03-07 23:36:51.487056: Starting evaluation 17
# 2020-03-07 23:36:56.685178: Computing acquisition function
# 2020-03-07 23:36:56.768605: x and x_prime:
# [[-0.15306122  0.33673469  0.21428571  1.13265306]]
# 2020-03-07 23:36:56.770053: y_next:
# [[1]]
# 2020-03-07 23:37:16.460941: Starting evaluation 18
# 2020-03-07 23:37:22.187686: Computing acquisition function
# 2020-03-07 23:37:22.277162: x and x_prime:
# [[ 0.52040816  0.39795918 -1.43877551  0.21428571]]
# 2020-03-07 23:37:22.278819: y_next:
# [[1]]
# 2020-03-07 23:37:42.816667: Starting evaluation 19
# 2020-03-07 23:37:49.643902: Computing acquisition function
# 2020-03-07 23:37:49.774278: x and x_prime:
# [[ 1.31632653 -0.8877551  -0.58163265 -0.94897959]]
# 2020-03-07 23:37:49.775500: y_next:
# [[1]]
# 2020-03-07 23:38:12.472259: Starting evaluation 0
# 2020-03-07 23:38:17.802507: Computing acquisition function
# 2020-03-07 23:38:17.882144: x and x_prime:
# [[ 1.43877551  0.33673469 -0.94897959  0.09183673]]
# 2020-03-07 23:38:17.882811: y_next:
# [[1]]
# 2020-03-07 23:38:22.430506: Starting evaluation 1
# 2020-03-07 23:38:28.508597: Computing acquisition function
# 2020-03-07 23:38:28.587591: x and x_prime:
# [[ 0.52040816  0.76530612 -0.39795918  0.09183673]]
# 2020-03-07 23:38:28.588389: y_next:
# [[1]]
# 2020-03-07 23:38:34.037924: Starting evaluation 2
# 2020-03-07 23:38:42.884251: Computing acquisition function
# 2020-03-07 23:38:42.970822: x and x_prime:
# [[-0.94897959  0.58163265  1.25510204  0.09183673]]
# 2020-03-07 23:38:42.971731: y_next:
# [[0]]
# 2020-03-07 23:38:50.191699: Starting evaluation 3
# 2020-03-07 23:38:55.643131: Computing acquisition function
# 2020-03-07 23:38:55.712525: x and x_prime:
# [[-0.09183673 -0.15306122  0.94897959  0.15306122]]
# 2020-03-07 23:38:55.713101: y_next:
# [[1]]
# 2020-03-07 23:39:02.549837: Starting evaluation 4
# 2020-03-07 23:39:08.887256: Computing acquisition function
# 2020-03-07 23:39:08.966796: x and x_prime:
# [[-0.21428571  0.70408163 -0.76530612 -0.2755102 ]]
# 2020-03-07 23:39:08.968218: y_next:
# [[1]]
# 2020-03-07 23:39:17.851336: Starting evaluation 5
# 2020-03-07 23:39:23.375067: Computing acquisition function
# 2020-03-07 23:39:23.448214: x and x_prime:
# [[-0.94897959  0.15306122  0.03061224  0.52040816]]
# 2020-03-07 23:39:23.449236: y_next:
# [[0]]
# 2020-03-07 23:39:32.416486: Starting evaluation 6
# 2020-03-07 23:39:40.020965: Computing acquisition function
# 2020-03-07 23:39:40.104780: x and x_prime:
# [[-0.64285714 -1.5        -1.5        -1.5       ]]
# 2020-03-07 23:39:40.105625: y_next:
# [[1]]
# 2020-03-07 23:39:48.886671: Starting evaluation 7
# 2020-03-07 23:39:55.168164: Computing acquisition function
# 2020-03-07 23:39:55.258625: x and x_prime:
# [[-1.31632653 -1.01020408 -0.76530612 -1.07142857]]
# 2020-03-07 23:39:55.260120: y_next:
# [[1]]
# 2020-03-07 23:40:03.844854: Starting evaluation 8
# 2020-03-07 23:40:09.438363: Computing acquisition function
# 2020-03-07 23:40:09.519825: x and x_prime:
# [[-0.39795918  1.31632653 -0.76530612 -0.76530612]]
# 2020-03-07 23:40:09.521120: y_next:
# [[0]]
# 2020-03-07 23:40:18.483331: Starting evaluation 9
# 2020-03-07 23:40:23.920167: Computing acquisition function
# 2020-03-07 23:40:23.998901: x and x_prime:
# [[-0.03061224  1.37755102 -1.25510204 -0.76530612]]
# 2020-03-07 23:40:24.000625: y_next:
# [[0]]
# 2020-03-07 23:40:33.221813: Starting evaluation 10
# 2020-03-07 23:40:39.266910: Computing acquisition function
# 2020-03-07 23:40:39.340620: x and x_prime:
# [[-0.21428571  0.2755102  -0.39795918 -0.21428571]]
# 2020-03-07 23:40:39.341392: y_next:
# [[0]]
# 2020-03-07 23:40:49.889464: Starting evaluation 11
# 2020-03-07 23:40:56.217781: Computing acquisition function
# 2020-03-07 23:40:56.300110: x and x_prime:
# [[-0.2755102  -1.19387755 -0.70408163  1.07142857]]
# 2020-03-07 23:40:56.300988: y_next:
# [[0]]
# 2020-03-07 23:41:07.428049: Starting evaluation 12
# 2020-03-07 23:41:15.148404: Computing acquisition function
# 2020-03-07 23:41:15.222062: x and x_prime:
# [[ 1.37755102 -0.33673469 -1.07142857  0.21428571]]
# 2020-03-07 23:41:15.222820: y_next:
# [[0]]
# 2020-03-07 23:41:29.905654: Starting evaluation 13
# 2020-03-07 23:41:35.218895: Computing acquisition function
# 2020-03-07 23:41:35.294547: x and x_prime:
# [[ 0.33673469  0.21428571  1.43877551 -0.03061224]]
# 2020-03-07 23:41:35.295310: y_next:
# [[1]]
# 2020-03-07 23:41:48.996398: Starting evaluation 14
# 2020-03-07 23:41:54.100988: Computing acquisition function
# 2020-03-07 23:41:54.176155: x and x_prime:
# [[-0.03061224 -0.45918367  1.43877551 -0.15306122]]
# 2020-03-07 23:41:54.176960: y_next:
# [[0]]
# 2020-03-07 23:42:06.411739: Starting evaluation 15
# 2020-03-07 23:42:13.643734: Computing acquisition function
# 2020-03-07 23:42:13.791123: x and x_prime:
# [[ 1.43877551 -1.43877551 -1.5        -1.5       ]]
# 2020-03-07 23:42:13.792927: y_next:
# [[1]]
# 2020-03-07 23:42:30.467861: Starting evaluation 16
# 2020-03-07 23:42:36.091528: Computing acquisition function
# 2020-03-07 23:42:36.179031: x and x_prime:
# [[-0.21428571 -1.43877551 -1.31632653 -0.58163265]]
# 2020-03-07 23:42:36.179970: y_next:
# [[0]]
# 2020-03-07 23:42:54.679649: Starting evaluation 17
# 2020-03-07 23:43:00.124640: Computing acquisition function
# 2020-03-07 23:43:00.205119: x and x_prime:
# [[ 1.07142857 -0.21428571  0.52040816 -0.45918367]]
# 2020-03-07 23:43:00.206050: y_next:
# [[0]]
# 2020-03-07 23:43:18.802018: Starting evaluation 18
# 2020-03-07 23:43:24.711546: Computing acquisition function
# 2020-03-07 23:43:24.786713: x and x_prime:
# [[-0.03061224  0.15306122 -0.94897959  0.52040816]]
# 2020-03-07 23:43:24.787699: y_next:
# [[0]]
# 2020-03-07 23:43:40.558713: Starting evaluation 19
# 2020-03-07 23:43:46.140541: Computing acquisition function
# 2020-03-07 23:43:46.222204: x and x_prime:
# [[ 0.21428571  0.33673469 -0.15306122 -0.82653061]]
# 2020-03-07 23:43:46.223069: y_next:
# [[1]]
# 2020-03-07 23:44:03.117847: Starting evaluation 0
# 2020-03-07 23:44:08.347229: Computing acquisition function
# 2020-03-07 23:44:08.423085: x and x_prime:
# [[-0.03061224 -0.45918367 -1.5        -1.5       ]]
# 2020-03-07 23:44:08.423684: y_next:
# [[1]]
# 2020-03-07 23:44:13.756627: Starting evaluation 1
# 2020-03-07 23:44:19.408410: Computing acquisition function
# 2020-03-07 23:44:19.493950: x and x_prime:
# [[ 0.21428571  0.45918367 -1.25510204 -1.43877551]]
# 2020-03-07 23:44:19.495086: y_next:
# [[1]]
# 2020-03-07 23:44:25.214028: Starting evaluation 2
# 2020-03-07 23:44:31.962218: Computing acquisition function
# 2020-03-07 23:44:32.044076: x and x_prime:
# [[-1.5        -0.64285714  0.45918367  0.33673469]]
# 2020-03-07 23:44:32.045418: y_next:
# [[0]]
# 2020-03-07 23:44:38.374741: Starting evaluation 3
# 2020-03-07 23:44:44.365518: Computing acquisition function
# 2020-03-07 23:44:44.437443: x and x_prime:
# [[ 0.21428571  0.64285714  0.94897959 -1.01020408]]
# 2020-03-07 23:44:44.438208: y_next:
# [[1]]
# 2020-03-07 23:44:53.922788: Starting evaluation 4
# 2020-03-07 23:45:00.245510: Computing acquisition function
# 2020-03-07 23:45:00.377202: x and x_prime:
# [[ 0.2755102  -0.03061224 -0.39795918 -1.07142857]]
# 2020-03-07 23:45:00.379333: y_next:
# [[1]]
# 2020-03-07 23:45:11.615029: Starting evaluation 5
# 2020-03-07 23:45:16.707887: Computing acquisition function
# 2020-03-07 23:45:16.782533: x and x_prime:
# [[-0.76530612  1.5        -1.5        -1.5       ]]
# 2020-03-07 23:45:16.783322: y_next:
# [[1]]
# 2020-03-07 23:45:27.768638: Starting evaluation 6
# 2020-03-07 23:45:33.261022: Computing acquisition function
# 2020-03-07 23:45:33.338338: x and x_prime:
# [[ 1.5        -0.45918367  0.09183673  0.52040816]]
# 2020-03-07 23:45:33.339521: y_next:
# [[0]]
# 2020-03-07 23:45:42.645452: Starting evaluation 7
# 2020-03-07 23:45:48.518821: Computing acquisition function
# 2020-03-07 23:45:48.604730: x and x_prime:
# [[-0.82653061  0.09183673 -1.5        -1.5       ]]
# 2020-03-07 23:45:48.605472: y_next:
# [[1]]
# 2020-03-07 23:46:01.400675: Starting evaluation 8
# 2020-03-07 23:46:08.408593: Computing acquisition function
# 2020-03-07 23:46:08.485863: x and x_prime:
# [[ 1.13265306 -0.58163265  0.58163265  0.09183673]]
# 2020-03-07 23:46:08.486742: y_next:
# [[0]]
# 2020-03-07 23:46:20.428067: Starting evaluation 9
# 2020-03-07 23:46:27.075303: Computing acquisition function
# 2020-03-07 23:46:27.245767: x and x_prime:
# [[ 1.07142857 -1.13265306  1.01020408 -0.03061224]]
# 2020-03-07 23:46:27.247900: y_next:
# [[1]]
# 2020-03-07 23:46:40.989702: Starting evaluation 10
# 2020-03-07 23:46:48.007433: Computing acquisition function
# 2020-03-07 23:46:48.152420: x and x_prime:
# [[ 1.43877551 -0.2755102  -0.03061224 -0.03061224]]
# 2020-03-07 23:46:48.154757: y_next:
# [[0]]
# 2020-03-07 23:47:03.541991: Starting evaluation 11
# 2020-03-07 23:47:09.479299: Computing acquisition function
# 2020-03-07 23:47:09.553915: x and x_prime:
# [[-1.37755102 -1.13265306  0.39795918 -0.94897959]]
# 2020-03-07 23:47:09.555425: y_next:
# [[0]]
# 2020-03-07 23:47:22.470179: Starting evaluation 12
# 2020-03-07 23:47:28.070558: Computing acquisition function
# 2020-03-07 23:47:28.153791: x and x_prime:
# [[ 0.70408163 -0.58163265 -0.39795918 -1.07142857]]
# 2020-03-07 23:47:28.154679: y_next:
# [[1]]
# 2020-03-07 23:47:41.684865: Starting evaluation 13
# 2020-03-07 23:47:46.988240: Computing acquisition function
# 2020-03-07 23:47:47.071405: x and x_prime:
# [[ 0.64285714 -0.15306122 -1.31632653 -0.8877551 ]]
# 2020-03-07 23:47:47.072345: y_next:
# [[0]]
# 2020-03-07 23:48:01.302505: Starting evaluation 14
# 2020-03-07 23:48:06.678200: Computing acquisition function
# 2020-03-07 23:48:06.761772: x and x_prime:
# [[ 0.70408163  0.58163265 -0.33673469 -1.01020408]]
# 2020-03-07 23:48:06.763307: y_next:
# [[0]]
# 2020-03-07 23:48:22.328677: Starting evaluation 15
# 2020-03-07 23:48:28.468022: Computing acquisition function
# 2020-03-07 23:48:28.552624: x and x_prime:
# [[-0.15306122 -0.45918367 -1.31632653 -1.01020408]]
# 2020-03-07 23:48:28.553523: y_next:
# [[1]]
# 2020-03-07 23:48:45.177858: Starting evaluation 16
# 2020-03-07 23:48:52.563086: Computing acquisition function
# 2020-03-07 23:48:52.642462: x and x_prime:
# [[ 1.07142857 -0.52040816  0.8877551  -0.52040816]]
# 2020-03-07 23:48:52.643297: y_next:
# [[0]]
# 2020-03-07 23:49:07.855708: Starting evaluation 17
# 2020-03-07 23:49:13.657955: Computing acquisition function
# 2020-03-07 23:49:13.941304: x and x_prime:
# [[-0.58163265 -1.07142857 -1.5        -1.5       ]]
# 2020-03-07 23:49:13.943760: y_next:
# [[1]]
# 2020-03-07 23:49:28.129086: Starting evaluation 18
# 2020-03-07 23:49:33.644800: Computing acquisition function
# 2020-03-07 23:49:33.731958: x and x_prime:
# [[ 1.19387755  1.25510204 -1.5        -1.5       ]]
# 2020-03-07 23:49:33.733720: y_next:
# [[1]]
# 2020-03-07 23:49:48.546056: Starting evaluation 19
# 2020-03-07 23:49:56.502897: Computing acquisition function
# 2020-03-07 23:49:56.588549: x and x_prime:
# [[-1.37755102  1.13265306 -1.5        -1.5       ]]
# 2020-03-07 23:49:56.590310: y_next:
# [[1]]
# 2020-03-07 23:50:13.904329: Starting evaluation 0
# 2020-03-07 23:50:20.462753: Computing acquisition function
# 2020-03-07 23:50:20.536612: x and x_prime:
# [[ 1.19387755  1.25510204 -1.5        -1.5       ]]
# 2020-03-07 23:50:20.537222: y_next:
# [[1]]
# 2020-03-07 23:50:27.431060: Starting evaluation 1
# 2020-03-07 23:50:34.461596: Computing acquisition function
# 2020-03-07 23:50:34.536215: x and x_prime:
# [[ 1.5         1.5        -1.13265306 -1.37755102]]
# 2020-03-07 23:50:34.536984: y_next:
# [[0]]
# 2020-03-07 23:50:40.228436: Starting evaluation 2
# 2020-03-07 23:50:47.002683: Computing acquisition function
# 2020-03-07 23:50:47.094890: x and x_prime:
# [[-0.58163265  1.25510204 -1.5        -1.5       ]]
# 2020-03-07 23:50:47.096322: y_next:
# [[1]]
# 2020-03-07 23:50:55.416441: Starting evaluation 3
# 2020-03-07 23:51:02.248289: Computing acquisition function
# 2020-03-07 23:51:02.332388: x and x_prime:
# [[-0.58163265  1.31632653 -1.01020408 -1.25510204]]
# 2020-03-07 23:51:02.333309: y_next:
# [[1]]
# 2020-03-07 23:51:10.372050: Starting evaluation 4
# 2020-03-07 23:51:16.497800: Computing acquisition function
# 2020-03-07 23:51:16.577383: x and x_prime:
# [[-0.64285714 -0.52040816 -0.45918367  0.15306122]]
# 2020-03-07 23:51:16.578596: y_next:
# [[1]]
# 2020-03-07 23:51:25.286334: Starting evaluation 5
# 2020-03-07 23:51:31.087291: Computing acquisition function
# 2020-03-07 23:51:31.160409: x and x_prime:
# [[ 0.64285714  0.15306122  1.31632653 -0.76530612]]
# 2020-03-07 23:51:31.161621: y_next:
# [[1]]
# 2020-03-07 23:51:39.886154: Starting evaluation 6
# 2020-03-07 23:51:45.449477: Computing acquisition function
# 2020-03-07 23:51:45.525910: x and x_prime:
# [[-1.31632653  0.21428571 -1.5        -1.5       ]]
# 2020-03-07 23:51:45.526500: y_next:
# [[1]]
# 2020-03-07 23:51:55.226627: Starting evaluation 7
# 2020-03-07 23:52:00.416180: Computing acquisition function
# 2020-03-07 23:52:00.497182: x and x_prime:
# [[ 0.15306122 -1.07142857 -1.5        -1.5       ]]
# 2020-03-07 23:52:00.498725: y_next:
# [[1]]
# 2020-03-07 23:52:10.542617: Starting evaluation 8
# 2020-03-07 23:52:15.735358: Computing acquisition function
# 2020-03-07 23:52:15.812802: x and x_prime:
# [[-0.33673469  0.70408163 -1.37755102 -1.5       ]]
# 2020-03-07 23:52:15.813582: y_next:
# [[1]]
# 2020-03-07 23:52:27.943415: Starting evaluation 9
# 2020-03-07 23:52:33.181099: Computing acquisition function
# 2020-03-07 23:52:33.266831: x and x_prime:
# [[ 1.5         1.07142857 -1.25510204 -1.07142857]]
# 2020-03-07 23:52:33.268324: y_next:
# [[1]]
# 2020-03-07 23:52:45.835435: Starting evaluation 10
# 2020-03-07 23:52:51.639978: Computing acquisition function
# 2020-03-07 23:52:51.723891: x and x_prime:
# [[ 1.07142857 -0.21428571  1.25510204 -1.13265306]]
# 2020-03-07 23:52:51.725542: y_next:
# [[1]]
# 2020-03-07 23:53:08.960748: Starting evaluation 11
# 2020-03-07 23:53:15.751612: Computing acquisition function
# 2020-03-07 23:53:15.911662: x and x_prime:
# [[ 1.13265306  1.31632653 -0.94897959 -0.76530612]]
# 2020-03-07 23:53:15.912770: y_next:
# [[0]]
# 2020-03-07 23:53:31.861774: Starting evaluation 12
# 2020-03-07 23:53:37.214819: Computing acquisition function
# 2020-03-07 23:53:37.300303: x and x_prime:
# [[-1.5         0.58163265 -0.8877551  -1.31632653]]
# 2020-03-07 23:53:37.301761: y_next:
# [[1]]
# 2020-03-07 23:53:52.700984: Starting evaluation 13
# 2020-03-07 23:54:00.324417: Computing acquisition function
# 2020-03-07 23:54:00.473925: x and x_prime:
# [[ 0.8877551   0.64285714 -1.31632653 -1.5       ]]
# 2020-03-07 23:54:00.475751: y_next:
# [[1]]
# 2020-03-07 23:54:20.369594: Starting evaluation 14
# 2020-03-07 23:54:26.854486: Computing acquisition function
# 2020-03-07 23:54:26.942149: x and x_prime:
# [[ 0.21428571  1.25510204 -1.19387755 -1.43877551]]
# 2020-03-07 23:54:26.943268: y_next:
# [[1]]
# 2020-03-07 23:54:48.695217: Starting evaluation 15
# 2020-03-07 23:54:56.368226: Computing acquisition function
# 2020-03-07 23:54:56.544211: x and x_prime:
# [[-0.82653061 -1.37755102 -1.19387755  0.09183673]]
# 2020-03-07 23:54:56.546497: y_next:
# [[0]]
# 2020-03-07 23:55:17.308624: Starting evaluation 16
# 2020-03-07 23:55:23.077602: Computing acquisition function
# 2020-03-07 23:55:23.166494: x and x_prime:
# [[ 0.45918367  0.21428571  1.37755102 -1.43877551]]
# 2020-03-07 23:55:23.167307: y_next:
# [[1]]
# 2020-03-07 23:55:42.505702: Starting evaluation 17
# 2020-03-07 23:55:47.887349: Computing acquisition function
# 2020-03-07 23:55:47.977119: x and x_prime:
# [[ 0.52040816 -1.25510204 -1.07142857 -1.5       ]]
# 2020-03-07 23:55:47.978824: y_next:
# [[1]]
# 2020-03-07 23:56:08.100355: Starting evaluation 18
# 2020-03-07 23:56:13.506851: Computing acquisition function
# 2020-03-07 23:56:13.589278: x and x_prime:
# [[ 1.37755102 -1.01020408 -0.33673469 -1.01020408]]
# 2020-03-07 23:56:13.590071: y_next:
# [[1]]
# 2020-03-07 23:56:35.735479: Starting evaluation 19
# 2020-03-07 23:56:44.070077: Computing acquisition function
# 2020-03-07 23:56:44.241186: x and x_prime:
# [[ 0.64285714  1.01020408 -1.07142857 -1.31632653]]
# 2020-03-07 23:56:44.244085: y_next:
# [[1]]
# 2020-03-07 23:57:13.307730: Starting evaluation 0
# 2020-03-07 23:57:19.131080: Computing acquisition function
# 2020-03-07 23:57:19.218112: x and x_prime:
# [[-0.03061224 -1.43877551 -1.07142857 -1.25510204]]
# 2020-03-07 23:57:19.218969: y_next:
# [[0]]
# 2020-03-07 23:57:23.677761: Starting evaluation 1
# 2020-03-07 23:57:30.386812: Computing acquisition function
# 2020-03-07 23:57:30.472375: x and x_prime:
# [[ 0.58163265 -1.01020408 -1.19387755 -0.58163265]]
# 2020-03-07 23:57:30.473757: y_next:
# [[1]]
# 2020-03-07 23:57:35.640568: Starting evaluation 2
# 2020-03-07 23:57:42.654304: Computing acquisition function
# 2020-03-07 23:57:42.789300: x and x_prime:
# [[ 1.13265306 -0.70408163 -1.01020408 -1.13265306]]
# 2020-03-07 23:57:42.791174: y_next:
# [[1]]
# 2020-03-07 23:57:50.261306: Starting evaluation 3
# 2020-03-07 23:57:57.698641: Computing acquisition function
# 2020-03-07 23:57:57.826856: x and x_prime:
# [[-0.52040816 -0.09183673 -1.5        -1.5       ]]
# 2020-03-07 23:57:57.828742: y_next:
# [[1]]
# 2020-03-07 23:58:05.061667: Starting evaluation 4
# 2020-03-07 23:58:10.752518: Computing acquisition function
# 2020-03-07 23:58:10.830517: x and x_prime:
# [[ 1.5         0.52040816 -1.5        -1.5       ]]
# 2020-03-07 23:58:10.831919: y_next:
# [[1]]
# 2020-03-07 23:58:20.257831: Starting evaluation 5
# 2020-03-07 23:58:27.465448: Computing acquisition function
# 2020-03-07 23:58:27.610980: x and x_prime:
# [[-1.37755102 -0.52040816  0.2755102  -0.58163265]]
# 2020-03-07 23:58:27.612935: y_next:
# [[0]]
# 2020-03-07 23:58:35.967414: Starting evaluation 6
# 2020-03-07 23:58:41.576663: Computing acquisition function
# 2020-03-07 23:58:41.647018: x and x_prime:
# [[-0.45918367  0.70408163 -1.43877551 -1.5       ]]
# 2020-03-07 23:58:41.647819: y_next:
# [[1]]
# 2020-03-07 23:58:52.238406: Starting evaluation 7
# 2020-03-07 23:58:59.195155: Computing acquisition function
# 2020-03-07 23:58:59.393278: x and x_prime:
# [[ 0.8877551   0.58163265 -1.37755102 -1.5       ]]
# 2020-03-07 23:58:59.395513: y_next:
# [[1]]
# 2020-03-07 23:59:10.074647: Starting evaluation 8
# 2020-03-07 23:59:15.547413: Computing acquisition function
# 2020-03-07 23:59:15.628185: x and x_prime:
# [[ 1.5  1.5 -1.5 -1.5]]
# 2020-03-07 23:59:15.628936: y_next:
# [[0]]
# 2020-03-07 23:59:25.329781: Starting evaluation 9
# 2020-03-07 23:59:30.935514: Computing acquisition function
# 2020-03-07 23:59:31.012547: x and x_prime:
# [[ 0.15306122 -0.70408163 -1.25510204 -1.37755102]]
# 2020-03-07 23:59:31.013273: y_next:
# [[1]]
# 2020-03-07 23:59:41.122415: Starting evaluation 10
# 2020-03-07 23:59:46.567914: Computing acquisition function
# 2020-03-07 23:59:46.650114: x and x_prime:
# [[ 0.64285714  1.31632653 -1.43877551 -1.5       ]]
# 2020-03-07 23:59:46.651356: y_next:
# [[1]]
# 2020-03-07 23:59:57.335644: Starting evaluation 11
# 2020-03-08 00:00:02.669651: Computing acquisition function
# 2020-03-08 00:00:02.760548: x and x_prime:
# [[ 0.76530612 -0.52040816 -1.19387755 -1.5       ]]
# 2020-03-08 00:00:02.763356: y_next:
# [[1]]
# 2020-03-08 00:00:13.912552: Starting evaluation 12
# 2020-03-08 00:00:19.439191: Computing acquisition function
# 2020-03-08 00:00:19.525893: x and x_prime:
# [[ 0.39795918  0.45918367 -1.19387755 -1.5       ]]
# 2020-03-08 00:00:19.527254: y_next:
# [[1]]
# 2020-03-08 00:00:32.700383: Starting evaluation 13
# ...
# [[-1.5         0.58163265 -1.5        -0.09183673]]
# 2020-03-08 00:44:34.859525: y_next:
# [[1]]
# 2020-03-08 00:44:46.798059: Starting evaluation 16
# 2020-03-08 00:44:52.794278: Computing acquisition function
# 2020-03-08 00:44:52.875485: x and x_prime:
# [[ 1.5         1.43877551  1.5        -0.33673469]]
# 2020-03-08 00:44:52.876405: y_next:
# [[0]]
# 2020-03-08 00:45:05.814616: Starting evaluation 17
# 2020-03-08 00:45:11.677712: Computing acquisition function
# 2020-03-08 00:45:11.755383: x and x_prime:
# [[-1.31632653  0.2755102   1.5        -0.45918367]]
# 2020-03-08 00:45:11.756713: y_next:
# [[0]]
# 2020-03-08 00:45:25.117871: Starting evaluation 18
# 2020-03-08 00:45:32.512408: Computing acquisition function
# 2020-03-08 00:45:32.589711: x and x_prime:
# [[ 1.5  1.5 -1.5  1.5]]
# 2020-03-08 00:45:32.590667: y_next:
# [[0]]
# 2020-03-08 00:45:48.605794: Starting evaluation 19
# 2020-03-08 00:45:55.862934: Computing acquisition function
# 2020-03-08 00:45:56.010690: x and x_prime:
# [[ 0.33673469 -0.15306122 -1.5         1.5       ]]
# 2020-03-08 00:45:56.013002: y_next:
# [[1]]
# 2020-03-08 00:46:11.503907: Starting evaluation 0
# 2020-03-08 00:46:16.986017: Computing acquisition function
# 2020-03-08 00:46:17.063976: x and x_prime:
# [[ 1.01020408 -0.03061224 -0.76530612 -0.03061224]]
# 2020-03-08 00:46:17.064689: y_next:
# [[0]]
# 2020-03-08 00:46:21.699606: Starting evaluation 1
# 2020-03-08 00:46:27.766672: Computing acquisition function
# 2020-03-08 00:46:27.841965: x and x_prime:
# [[ 1.19387755 -0.39795918 -0.8877551  -0.45918367]]
# 2020-03-08 00:46:27.842764: y_next:
# [[0]]
# 2020-03-08 00:46:35.096005: Starting evaluation 2
# 2020-03-08 00:46:42.387662: Computing acquisition function
# 2020-03-08 00:46:42.465442: x and x_prime:
# [[-0.09183673 -1.25510204 -1.5        -1.5       ]]
# 2020-03-08 00:46:42.466894: y_next:
# [[1]]
# 2020-03-08 00:46:49.179983: Starting evaluation 3
# 2020-03-08 00:46:54.857804: Computing acquisition function
# 2020-03-08 00:46:54.932659: x and x_prime:
# [[ 0.52040816  0.76530612 -1.5        -1.5       ]]
# 2020-03-08 00:46:54.934006: y_next:
# [[1]]
# 2020-03-08 00:47:04.543592: Starting evaluation 4
# 2020-03-08 00:47:10.938781: Computing acquisition function
# 2020-03-08 00:47:11.013423: x and x_prime:
# [[-1.13265306 -0.52040816  0.70408163 -0.39795918]]
# 2020-03-08 00:47:11.015235: y_next:
# [[1]]
# 2020-03-08 00:47:18.462458: Starting evaluation 5
# 2020-03-08 00:47:26.340855: Computing acquisition function
# 2020-03-08 00:47:26.443326: x and x_prime:
# [[ 0.94897959 -1.13265306 -1.13265306 -0.58163265]]
# 2020-03-08 00:47:26.444895: y_next:
# [[0]]
# 2020-03-08 00:47:36.286030: Starting evaluation 6
# 2020-03-08 00:47:43.107414: Computing acquisition function
# 2020-03-08 00:47:43.184309: x and x_prime:
# [[-0.09183673  0.39795918 -0.2755102   0.03061224]]
# 2020-03-08 00:47:43.185079: y_next:
# [[1]]
# 2020-03-08 00:47:52.130990: Starting evaluation 7
# 2020-03-08 00:47:57.768556: Computing acquisition function
# 2020-03-08 00:47:57.862554: x and x_prime:
# [[-0.33673469 -1.01020408 -0.8877551  -1.43877551]]
# 2020-03-08 00:47:57.864205: y_next:
# [[1]]
# 2020-03-08 00:48:07.368683: Starting evaluation 8
# 2020-03-08 00:48:12.750142: Computing acquisition function
# 2020-03-08 00:48:12.822591: x and x_prime:
# [[0.70408163 0.21428571 0.8877551  1.13265306]]
# 2020-03-08 00:48:12.823368: y_next:
# [[1]]
# 2020-03-08 00:48:22.229660: Starting evaluation 9
# 2020-03-08 00:48:27.388947: Computing acquisition function
# 2020-03-08 00:48:27.471125: x and x_prime:
# [[-0.39795918 -0.94897959 -0.33673469 -1.31632653]]
# 2020-03-08 00:48:27.472384: y_next:
# [[1]]
# 2020-03-08 00:48:38.041249: Starting evaluation 10
# 2020-03-08 00:48:43.315867: Computing acquisition function
# 2020-03-08 00:48:43.401905: x and x_prime:
# [[-1.5         0.52040816  0.21428571  0.21428571]]
# 2020-03-08 00:48:43.402722: y_next:
# [[1]]
# 2020-03-08 00:48:55.146921: Starting evaluation 11
# 2020-03-08 00:49:01.141936: Computing acquisition function
# 2020-03-08 00:49:01.218532: x and x_prime:
# [[-1.13265306  0.82653061  0.15306122 -0.2755102 ]]
# 2020-03-08 00:49:01.220210: y_next:
# [[0]]
# 2020-03-08 00:49:15.222000: Starting evaluation 12
# 2020-03-08 00:49:21.452404: Computing acquisition function
# 2020-03-08 00:49:21.619066: x and x_prime:
# [[ 0.70408163  0.58163265 -1.13265306 -1.19387755]]
# 2020-03-08 00:49:21.620796: y_next:
# [[1]]
# 2020-03-08 00:49:35.719719: Starting evaluation 13
# 2020-03-08 00:49:43.322041: Computing acquisition function
# 2020-03-08 00:49:43.402813: x and x_prime:
# [[ 0.09183673 -0.15306122  0.45918367  0.8877551 ]]
# 2020-03-08 00:49:43.403933: y_next:
# [[1]]
# 2020-03-08 00:49:56.494147: Starting evaluation 14
# 2020-03-08 00:50:02.576968: Computing acquisition function
# 2020-03-08 00:50:02.729244: x and x_prime:
# [[-1.43877551  0.82653061  0.15306122 -0.82653061]]
# 2020-03-08 00:50:02.730221: y_next:
# [[0]]
# 2020-03-08 00:50:19.161333: Starting evaluation 15
# 2020-03-08 00:50:26.401409: Computing acquisition function
# 2020-03-08 00:50:26.483490: x and x_prime:
# [[-0.33673469 -1.31632653  0.33673469 -1.07142857]]
# 2020-03-08 00:50:26.484304: y_next:
# [[0]]
# 2020-03-08 00:50:42.367569: Starting evaluation 16
# 2020-03-08 00:50:49.033651: Computing acquisition function
# 2020-03-08 00:50:49.114868: x and x_prime:
# [[-1.19387755 -1.5         0.03061224 -0.76530612]]
# 2020-03-08 00:50:49.116285: y_next:
# [[0]]
# 2020-03-08 00:51:06.312832: Starting evaluation 17
# 2020-03-08 00:51:13.120325: Computing acquisition function
# 2020-03-08 00:51:13.206868: x and x_prime:
# [[-0.52040816 -0.45918367 -1.07142857 -1.43877551]]
# 2020-03-08 00:51:13.208345: y_next:
# [[1]]
# 2020-03-08 00:51:32.057612: Starting evaluation 18
# 2020-03-08 00:51:38.123726: Computing acquisition function
# 2020-03-08 00:51:38.206925: x and x_prime:
# [[-0.94897959  1.43877551  0.15306122 -0.70408163]]
# 2020-03-08 00:51:38.208500: y_next:
# [[0]]
# 2020-03-08 00:51:54.497335: Starting evaluation 19
# 2020-03-08 00:51:59.918807: Computing acquisition function
# 2020-03-08 00:51:59.998931: x and x_prime:
# [[-0.45918367  0.8877551  -0.21428571  0.03061224]]
# 2020-03-08 00:52:00.000134: y_next:
# [[0]]
# 2020-03-08 00:52:17.048553: Starting evaluation 0
# 2020-03-08 00:52:22.356592: Computing acquisition function
# 2020-03-08 00:52:22.435440: x and x_prime:
# [[ 1.37755102 -0.15306122 -1.5        -1.5       ]]
# 2020-03-08 00:52:22.436173: y_next:
# [[1]]
# 2020-03-08 00:52:27.265370: Starting evaluation 1
# 2020-03-08 00:52:32.652043: Computing acquisition function
# 2020-03-08 00:52:32.734221: x and x_prime:
# [[-0.82653061  1.31632653  0.82653061 -1.07142857]]
# 2020-03-08 00:52:32.735446: y_next:
# [[0]]
# 2020-03-08 00:52:38.490801: Starting evaluation 2
# 2020-03-08 00:52:44.383156: Computing acquisition function
# 2020-03-08 00:52:44.463111: x and x_prime:
# [[ 1.13265306 -1.5        -1.01020408  1.07142857]]
# 2020-03-08 00:52:44.464240: y_next:
# [[0]]
# 2020-03-08 00:52:50.589367: Starting evaluation 3
# 2020-03-08 00:52:57.011472: Computing acquisition function
# 2020-03-08 00:52:57.088547: x and x_prime:
# [[ 1.37755102  0.21428571 -0.94897959 -1.25510204]]
# 2020-03-08 00:52:57.089329: y_next:
# [[1]]
# 2020-03-08 00:53:04.737753: Starting evaluation 4
# 2020-03-08 00:53:10.890003: Computing acquisition function
# 2020-03-08 00:53:10.981808: x and x_prime:
# [[ 0.39795918 -0.52040816 -0.21428571  0.39795918]]
# 2020-03-08 00:53:10.983306: y_next:
# [[1]]
# 2020-03-08 00:53:21.116887: Starting evaluation 5
# 2020-03-08 00:53:28.839645: Computing acquisition function
# 2020-03-08 00:53:28.919736: x and x_prime:
# [[ 0.45918367 -0.39795918  0.2755102   0.52040816]]
# 2020-03-08 00:53:28.921160: y_next:
# [[0]]
# 2020-03-08 00:53:39.154189: Starting evaluation 6
# 2020-03-08 00:53:46.096922: Computing acquisition function
# 2020-03-08 00:53:46.175773: x and x_prime:
# [[ 0.45918367  0.82653061 -0.15306122 -0.39795918]]
# 2020-03-08 00:53:46.176893: y_next:
# [[0]]
# 2020-03-08 00:53:55.947119: Starting evaluation 7
# 2020-03-08 00:54:01.584355: Computing acquisition function
# 2020-03-08 00:54:01.679247: x and x_prime:
# [[-1.25510204  0.33673469  0.8877551  -1.5       ]]
# 2020-03-08 00:54:01.681904: y_next:
# [[1]]
# 2020-03-08 00:54:12.148692: Starting evaluation 8
# 2020-03-08 00:54:20.379709: Computing acquisition function
# 2020-03-08 00:54:20.521635: x and x_prime:
# [[ 0.2755102  -0.03061224  0.52040816  0.21428571]]
# 2020-03-08 00:54:20.524297: y_next:
# [[1]]
# 2020-03-08 00:54:33.841674: Starting evaluation 9
# 2020-03-08 00:54:39.669068: Computing acquisition function
# 2020-03-08 00:54:39.749518: x and x_prime:
# [[ 0.8877551   0.33673469 -1.01020408 -1.43877551]]
# 2020-03-08 00:54:39.751246: y_next:
# [[1]]
# 2020-03-08 00:54:54.670854: Starting evaluation 10
# 2020-03-08 00:55:01.035820: Computing acquisition function
# 2020-03-08 00:55:01.119577: x and x_prime:
# [[-0.82653061  0.82653061  0.64285714 -1.5       ]]
# 2020-03-08 00:55:01.120618: y_next:
# [[1]]
# 2020-03-08 00:55:14.946505: Starting evaluation 11
# 2020-03-08 00:55:22.215346: Computing acquisition function
# 2020-03-08 00:55:22.296735: x and x_prime:
# [[ 1.43877551 -0.39795918 -1.19387755 -1.01020408]]
# 2020-03-08 00:55:22.298077: y_next:
# [[1]]
# 2020-03-08 00:55:37.644019: Starting evaluation 12
# 2020-03-08 00:55:43.297567: Computing acquisition function
# 2020-03-08 00:55:43.376092: x and x_prime:
# [[ 0.52040816 -1.01020408 -0.8877551   0.39795918]]
# 2020-03-08 00:55:43.377978: y_next:
# [[1]]
# 2020-03-08 00:55:57.343646: Starting evaluation 13
# 2020-03-08 00:56:02.565081: Computing acquisition function
# 2020-03-08 00:56:02.646487: x and x_prime:
# [[-0.39795918  1.5         0.39795918 -0.2755102 ]]
# 2020-03-08 00:56:02.647301: y_next:
# [[0]]
# 2020-03-08 00:56:17.305802: Starting evaluation 14
# 2020-03-08 00:56:23.538432: Computing acquisition function
# 2020-03-08 00:56:23.620508: x and x_prime:
# [[-1.07142857 -0.39795918  1.19387755 -0.45918367]]
# 2020-03-08 00:56:23.621391: y_next:
# [[1]]
# 2020-03-08 00:56:39.124921: Starting evaluation 15
# 2020-03-08 00:56:44.920231: Computing acquisition function
# 2020-03-08 00:56:45.005320: x and x_prime:
# [[ 0.03061224 -0.2755102   0.52040816 -0.15306122]]
# 2020-03-08 00:56:45.006851: y_next:
# [[1]]
# 2020-03-08 00:57:02.668736: Starting evaluation 16
# 2020-03-08 00:57:09.391216: Computing acquisition function
# 2020-03-08 00:57:09.547125: x and x_prime:
# [[ 0.09183673  0.09183673  0.09183673 -0.64285714]]
# 2020-03-08 00:57:09.548293: y_next:
# [[0]]
# 2020-03-08 00:57:27.213742: Starting evaluation 17
# 2020-03-08 00:57:32.754839: Computing acquisition function
# 2020-03-08 00:57:32.839269: x and x_prime:
# [[ 1.01020408  0.09183673 -1.19387755 -0.76530612]]
# 2020-03-08 00:57:32.840242: y_next:
# [[0]]
# 2020-03-08 00:57:50.257047: Starting evaluation 18
# 2020-03-08 00:57:57.135786: Computing acquisition function
# 2020-03-08 00:57:57.357451: x and x_prime:
# [[ 1.07142857 -0.09183673 -0.70408163 -1.07142857]]
# 2020-03-08 00:57:57.359959: y_next:
# [[0]]
# 2020-03-08 00:58:18.612604: Starting evaluation 19
# 2020-03-08 00:58:25.916731: Computing acquisition function
# 2020-03-08 00:58:26.030854: x and x_prime:
# [[ 0.82653061  0.94897959  0.2755102  -0.45918367]]
# 2020-03-08 00:58:26.033209: y_next:
# [[0]]
# 2020-03-08 00:58:49.957474: Starting evaluation 0
# 2020-03-08 00:58:56.352531: Computing acquisition function
# 2020-03-08 00:58:56.424898: x and x_prime:
# [[ 0.76530612 -1.01020408 -1.5        -1.5       ]]
# 2020-03-08 00:58:56.425708: y_next:
# [[1]]
# 2020-03-08 00:59:02.209678: Starting evaluation 1
# 2020-03-08 00:59:08.787445: Computing acquisition function
# 2020-03-08 00:59:08.895147: x and x_prime:
# [[ 0.8877551   1.25510204 -1.5        -1.5       ]]
# 2020-03-08 00:59:08.896669: y_next:
# [[1]]
# 2020-03-08 00:59:15.063158: Starting evaluation 2
# 2020-03-08 00:59:20.938626: Computing acquisition function
# 2020-03-08 00:59:21.024621: x and x_prime:
# [[ 0.70408163 -0.39795918 -1.5        -1.5       ]]
# 2020-03-08 00:59:21.025987: y_next:
# [[1]]
# 2020-03-08 00:59:26.407305: Starting evaluation 3
# 2020-03-08 00:59:32.445830: Computing acquisition function
# 2020-03-08 00:59:32.529520: x and x_prime:
# [[ 0.64285714  1.31632653 -1.5        -1.5       ]]
# 2020-03-08 00:59:32.530728: y_next:
# [[1]]
# 2020-03-08 00:59:38.632569: Starting evaluation 4
# 2020-03-08 00:59:44.099347: Computing acquisition function
# 2020-03-08 00:59:44.173593: x and x_prime:
# [[-1.5         0.94897959 -0.58163265  0.8877551 ]]
# 2020-03-08 00:59:44.174719: y_next:
# [[0]]
# 2020-03-08 00:59:50.532109: Starting evaluation 5
# 2020-03-08 00:59:55.963433: Computing acquisition function
# 2020-03-08 00:59:56.050627: x and x_prime:
# [[ 0.09183673 -1.19387755 -0.39795918  0.15306122]]
# 2020-03-08 00:59:56.051859: y_next:
# [[0]]
# 2020-03-08 01:00:02.604294: Starting evaluation 6
# 2020-03-08 01:00:07.884768: Computing acquisition function
# 2020-03-08 01:00:07.961336: x and x_prime:
# [[0.2755102  0.82653061 1.43877551 1.37755102]]
# 2020-03-08 01:00:07.962267: y_next:
# [[1]]
# 2020-03-08 01:00:14.872887: Starting evaluation 7
# 2020-03-08 01:00:20.251106: Computing acquisition function
# 2020-03-08 01:00:20.337182: x and x_prime:
# [[ 0.8877551   1.13265306  1.43877551 -1.19387755]]
# 2020-03-08 01:00:20.338348: y_next:
# [[1]]
# 2020-03-08 01:00:28.756944: Starting evaluation 8
# 2020-03-08 01:00:34.207304: Computing acquisition function
# 2020-03-08 01:00:34.282528: x and x_prime:
# [[-1.5        -0.70408163  0.45918367 -1.37755102]]
# 2020-03-08 01:00:34.283821: y_next:
# [[1]]
# 2020-03-08 01:00:42.438787: Starting evaluation 9
# 2020-03-08 01:00:48.463031: Computing acquisition function
# 2020-03-08 01:00:48.543909: x and x_prime:
# [[-1.19387755 -0.82653061 -0.2755102  -0.70408163]]
# 2020-03-08 01:00:48.545117: y_next:
# [[0]]
# 2020-03-08 01:00:57.483071: Starting evaluation 10
# 2020-03-08 01:01:05.214260: Computing acquisition function
# 2020-03-08 01:01:05.406301: x and x_prime:
# [[-0.76530612  1.01020408 -1.25510204 -0.21428571]]
# 2020-03-08 01:01:05.420984: y_next:
# [[0]]
# 2020-03-08 01:01:17.498454: Starting evaluation 11
# 2020-03-08 01:01:24.056374: Computing acquisition function
# 2020-03-08 01:01:24.203295: x and x_prime:
# [[-1.5        -0.45918367  1.37755102 -0.21428571]]
# 2020-03-08 01:01:24.204485: y_next:
# [[1]]
# 2020-03-08 01:01:36.229532: Starting evaluation 12
# 2020-03-08 01:01:42.153801: Computing acquisition function
# 2020-03-08 01:01:42.238436: x and x_prime:
# [[-0.52040816  0.39795918 -1.31632653  0.09183673]]
# 2020-03-08 01:01:42.239701: y_next:
# [[1]]
# 2020-03-08 01:01:52.376331: Starting evaluation 13
# 2020-03-08 01:01:58.215794: Computing acquisition function
# 2020-03-08 01:01:58.290199: x and x_prime:
# [[ 0.39795918 -0.03061224  1.19387755  1.37755102]]
# 2020-03-08 01:01:58.291012: y_next:
# [[1]]
# 2020-03-08 01:02:10.124789: Starting evaluation 14
# 2020-03-08 01:02:16.054170: Computing acquisition function
# 2020-03-08 01:02:16.148620: x and x_prime:
# [[ 1.5         0.03061224 -1.37755102  1.01020408]]
# 2020-03-08 01:02:16.150225: y_next:
# [[0]]
# 2020-03-08 01:02:29.218653: Starting evaluation 15
# 2020-03-08 01:02:34.939451: Computing acquisition function
# 2020-03-08 01:02:35.331909: x and x_prime:
# [[-1.13265306  0.70408163  1.25510204 -0.82653061]]
# 2020-03-08 01:02:35.335058: y_next:
# [[0]]
# 2020-03-08 01:02:51.422965: Starting evaluation 16
# 2020-03-08 01:02:57.473550: Computing acquisition function
# 2020-03-08 01:02:57.555137: x and x_prime:
# [[-0.64285714 -0.52040816 -1.37755102  0.03061224]]
# 2020-03-08 01:02:57.556817: y_next:
# [[1]]
# 2020-03-08 01:03:12.293561: Starting evaluation 17
# 2020-03-08 01:03:19.424064: Computing acquisition function
# 2020-03-08 01:03:19.496894: x and x_prime:
# [[ 0.15306122 -1.5        -1.43877551  0.76530612]]
# 2020-03-08 01:03:19.497724: y_next:
# [[0]]
# 2020-03-08 01:03:34.593101: Starting evaluation 18
# 2020-03-08 01:03:40.058778: Computing acquisition function
# 2020-03-08 01:03:40.135671: x and x_prime:
# [[ 0.64285714 -1.19387755  1.43877551 -1.5       ]]
# 2020-03-08 01:03:40.137552: y_next:
# [[1]]
# 2020-03-08 01:03:53.844725: Starting evaluation 19
# 2020-03-08 01:03:59.460697: Computing acquisition function
# 2020-03-08 01:03:59.537235: x and x_prime:
# [[-1.5         0.15306122  1.5         0.8877551 ]]
# 2020-03-08 01:03:59.538088: y_next:
# [[1]]

# %%
pickle.dump((X_results, y_results, best_guess_results), open(results_dir + "Xybestguess.p", "wb"))

# %%
def dist(x, y):
    """
    x and y have shape (..., input_dims)
    """
    return np.sqrt(np.sum((x - y) * (x - y), axis=-1))

# %%
xx = uniform_grid(input_dims, num_discrete_per_dim, low=objective_low, high=objective_high)
global_min = xx[np.argmin(objective(xx))][0]

for i in range(best_guess_results.shape[0]):
    diff_from_min = dist(best_guess_results[i], global_min)
    
    x_axis = list(range(num_combs+1, num_combs+1+num_evals))
    plt.figure(figsize=(12, 6))
    plt.plot(x_axis, diff_from_min, 'kx', mew=2)
    plt.xticks(x_axis)
    plt.xlabel('Evaluations', fontsize=18)
    plt.ylabel('Best guess distance', fontsize=16)
    plt.title("Run %s" % i)
    plt.show()
