# %% [markdown]
# # Preferential Bayesian Optimization: RANDOM
# This notebook demonstrates the use of random querying on ordinal (preference) data.
#
# Formulation by Nguyen Quoc Phong.

# %%
import numpy as np
import gpflow
import tensorflow as tf
import matplotlib.pyplot as plt
import sys
import os
import pickle

from gpflow.utilities import set_trainable, print_summary
gpflow.config.set_default_summary_fmt("notebook")

sys.path.append(os.path.split(os.path.split(os.path.split(os.getcwd())[0])[0])[0]) # Move 3 levels up directory to import PBO
import PBO

# %%
objective = PBO.objectives.hartmann3d
objective_low = 0
objective_high = 1.
objective_name = "Hart3"
acquisition_name = "RANDOM"
experiment_name = "PBO" + "_" + acquisition_name + "_" + objective_name

# %%
num_runs = 20
num_evals = 20
num_samples = 1000
num_choices = 2
input_dims = 3
num_maximizers = 20
num_init_points = 3
num_inducing_init = 3
num_discrete_per_dim = 100 # Discretization of continuous input space

# %%
results_dir = os.getcwd() + '/results/' + experiment_name + '/'

try:
    # Create target Directory
    os.makedirs(results_dir)
    print("Directory " , results_dir ,  " created ") 
except FileExistsError:
    print("Directory " , results_dir ,  " already exists")
# Out:
# Directory  /home/sebtsh/PBO/notebooks/RANDOM/results/PBO_RANDOM_Hart3/  created

# %%
def get_noisy_observation(X, objective):
    f = PBO.objectives.objective_get_f_neg(X, objective)
    return PBO.observation_model.gen_observation_from_f(X, f, 1)

# %%
def train_and_visualize(X, y, num_inducing, title):
    
    # Train model with data
    q_mu, q_sqrt, u, inputs, k, indifference_threshold = PBO.models.learning_stochastic.train_model_fullcov(X, y, 
                                                                         num_inducing=num_inducing,
                                                                         obj_low=objective_low,
                                                                         obj_high=objective_high,
                                                                         num_steps=3000)
    likelihood = gpflow.likelihoods.Gaussian()
    model = PBO.models.learning.init_SVGP_fullcov(q_mu, q_sqrt, u, k, likelihood)
    u_mean = q_mu.numpy()
    inducing_vars = u.numpy()
    
    return model, inputs, u_mean, inducing_vars

# %%
def uniform_grid(input_dims, num_discrete_per_dim, low=0., high=1.):
    """
    Returns an array with all possible permutations of discrete values in input_dims number of dimensions.
    :param input_dims: int
    :param num_discrete_per_dim: int
    :param low: int
    :param high: int
    :return: tensor of shape (num_discrete_per_dim ** input_dims, input_dims)
    """
    num_points = num_discrete_per_dim ** input_dims
    out = np.zeros([num_points, input_dims])
    discrete_points = np.linspace(low, high, num_discrete_per_dim)
    for i in range(num_points):
        for dim in range(input_dims):
            val = num_discrete_per_dim ** (dim)
            out[i, dim] = discrete_points[int((i // val) % num_discrete_per_dim)]
    return out

# %% [markdown]
# This function is our main metric for the performance of the acquisition function: The closer the model's best guess to the global minimum, the better.

# %%
def best_guess(model):
    """
    Returns a GP model's best guess of the global maximum of f.
    """
    xx = uniform_grid(input_dims, num_discrete_per_dim, low=objective_low, high=objective_high)
    res = model.predict_f(xx)[0].numpy()
    return xx[np.argmax(res)]

# %% [markdown]
# Store the results in these arrays:

# %%
num_data_at_end = int((num_init_points-1) * num_init_points / 2 + num_evals)
X_results = np.zeros([num_runs, num_data_at_end, num_choices, input_dims])
y_results = np.zeros([num_runs, num_data_at_end, 1, input_dims])
best_guess_results = np.zeros([num_runs, num_evals, input_dims])

# %%
y_results = np.zeros([num_runs, num_data_at_end, 1, input_dims])  # REMOVE LATER

# %%
X_results[0] = X
y_results[0] = y

# %% [markdown]
# Create the initial values for each run:

# %%
np.random.seed(0)
init_points = np.random.uniform(low=objective_low, high=objective_high, size=[num_runs, num_init_points, input_dims])
num_combs = int((num_init_points-1) * num_init_points / 2)
init_vals = np.zeros([num_runs, num_combs, num_choices, input_dims])
for run in range(num_runs):
    cur_idx = 0
    for init_point in range(num_init_points-1):
        for next_point in range(init_point+1, num_init_points):
            init_vals[run, cur_idx, 0] = init_points[run, init_point]
            init_vals[run, cur_idx, 1] = init_points[run, next_point]
            cur_idx += 1

# %% [markdown]
# The following loops carry out the Bayesian optimization algorithm over a number of runs, with a fixed number of evaluations per run.

# %%
for run in range(1, num_runs):
    print("Beginning run %s" % (run))
    
    X = init_vals[run]
    y = get_noisy_observation(X, objective)
    
    model, inputs, u_mean, inducing_vars = train_and_visualize(X, y, num_inducing_init, "Run_{}:_Initial_model".format(run))

    for evaluation in range(num_evals):
        print("Beginning evaluation %s" % (evaluation)) 
        
        existing_idx = np.random.randint(0, inputs.shape[0])
        existing_input = inputs[existing_idx]
        random_input = np.random.uniform(low=objective_low, 
                                         high=objective_high, 
                                         size=(1, input_dims))
        
        next_query = np.zeros((num_choices, input_dims))
        next_query[0, :] = existing_input
        next_query[1, :] = random_input
        print("Evaluation %s: Next query is %s" % (evaluation, next_query))

        X = np.concatenate([X, [next_query]])
        # Evaluate objective function
        y = np.concatenate([y, get_noisy_observation(np.expand_dims(next_query, axis=0), objective)], axis=0)
        
        print("Evaluation %s: Training model" % (evaluation))
        model, inputs, u_mean, inducing_vars = train_and_visualize(X, y, 
                                                                   num_inducing_init + evaluation + 1, 
                                                                   "Run_{}_Evaluation_{}".format(run, evaluation))

        best_guess_results[run, evaluation, :] = best_guess(model)

    X_results[run] = X
    y_results[run] = y
# Out:
# Beginning run 1
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 4.779772578379597 in 0.1606s
# Negative ELBO at step 500: 2.0156255224296142 in 50.9795s
# Negative ELBO at step 1000: 1.9257136299962938 in 51.4875s
# Negative ELBO at step 1500: 1.8556707630674003 in 50.7842s
# Negative ELBO at step 2000: 1.8467978810640415 in 51.2707s
# Negative ELBO at step 2500: 1.8371685569263123 in 50.9255s
# Beginning evaluation 0
# Evaluation 0: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.45841243 0.48503053 0.89551293]]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 18.10444828740892 in 0.2020s
# Negative ELBO at step 500: 3.138039001477157 in 61.7645s
# Negative ELBO at step 1000: 2.917865595200535 in 64.5104s
# Negative ELBO at step 1500: 2.836159043271749 in 62.6303s
# Negative ELBO at step 2000: 2.7945133416450836 in 61.2656s
# Negative ELBO at step 2500: 2.732047502994801 in 63.2500s
# Beginning evaluation 1
# Evaluation 1: Next query is [[0.0871293  0.0202184  0.83261985]
#  [0.997994   0.98788917 0.60332299]]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 15.760793016724792 in 0.1871s
# Negative ELBO at step 500: 3.6359799849050436 in 73.1754s
# Negative ELBO at step 1000: 3.297978299876842 in 73.4318s
# Negative ELBO at step 1500: 3.1847072680756803 in 74.2232s
# Negative ELBO at step 2000: 3.0966078335977096 in 74.6793s
# Negative ELBO at step 2500: 3.1567649831901643 in 72.6295s
# Beginning evaluation 2
# Evaluation 2: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.16628957 0.2404904  0.2205283 ]]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 97.30338150724624 in 0.2682s
# Negative ELBO at step 500: 7.599099072991162 in 83.0129s
# Negative ELBO at step 1000: 5.474490702703966 in 84.1475s
# Negative ELBO at step 1500: 4.596460415541921 in 82.7260s
# Negative ELBO at step 2000: 4.260073807539197 in 86.2054s
# Negative ELBO at step 2500: 4.1195890742248515 in 83.5142s
# Beginning evaluation 3
# Evaluation 3: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.36322396 0.2467724  0.4935906 ]]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1854.821339994635 in 0.2912s
# Negative ELBO at step 500: 48.23557781048612 in 92.9027s
# Negative ELBO at step 1000: 19.692981692465096 in 95.1384s
# Negative ELBO at step 1500: 10.358891926551081 in 94.6965s
# Negative ELBO at step 2000: 8.453379912395514 in 95.2835s
# Negative ELBO at step 2500: 7.002260490277573 in 96.9159s
# Beginning evaluation 4
# Evaluation 4: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.3798939  0.56045059 0.66821823]]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 192.78729398257963 in 0.3572s
# Negative ELBO at step 500: 10.396688616562784 in 105.8894s
# Negative ELBO at step 1000: 7.470770629401686 in 105.4385s
# Negative ELBO at step 1500: 6.480722290384682 in 104.7546s
# Negative ELBO at step 2000: 6.123024688245877 in 106.1013s
# Negative ELBO at step 2500: 5.856784779764764 in 104.4177s
# Beginning evaluation 5
# Evaluation 5: Next query is [[0.997994   0.98788917 0.60332299]
#  [0.52336468 0.38059538 0.98535984]]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 287.84124873590997 in 0.3085s
# Negative ELBO at step 500: 18.74369260161376 in 116.3364s
# Negative ELBO at step 1000: 7.703762933130366 in 116.6125s
# Negative ELBO at step 1500: 7.1376860918987575 in 116.0647s
# Negative ELBO at step 2000: 6.625453217736597 in 117.9299s
# Negative ELBO at step 2500: 6.638940491495026 in 116.7544s
# Beginning evaluation 6
# Evaluation 6: Next query is [[0.3798939  0.56045059 0.66821823]
#  [0.59831597 0.11891694 0.4175392 ]]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1404.8461895344733 in 0.3736s
# Negative ELBO at step 500: 47.79753225171825 in 129.5756s
# Negative ELBO at step 1000: 17.747968174268593 in 126.5492s
# Negative ELBO at step 1500: 11.599708076034023 in 127.9775s
# Negative ELBO at step 2000: 10.366525093123618 in 127.4976s
# Negative ELBO at step 2500: 9.43863563378994 in 127.2395s
# Beginning evaluation 7
# Evaluation 7: Next query is [[0.52336468 0.38059538 0.98535984]
#  [0.33126888 0.32032629 0.94680717]]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1912.0379368582003 in 0.3832s
# Negative ELBO at step 500: 38.98102633802317 in 143.7865s
# Negative ELBO at step 1000: 18.622911779210483 in 140.7358s
# Negative ELBO at step 1500: 12.300600991690866 in 142.0208s
# Negative ELBO at step 2000: 9.284991698619905 in 139.7061s
# Negative ELBO at step 2500: 9.212812396225203 in 141.4167s
# Beginning evaluation 8
# Evaluation 8: Next query is [[0.3798939  0.56045059 0.66821823]
#  [0.65251435 0.55264587 0.25120012]]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 12323.368791619196 in 0.4275s
# Negative ELBO at step 500: 162.7984441550275 in 153.4235s
# Negative ELBO at step 1000: 75.09189094565761 in 149.3060s
# Negative ELBO at step 1500: 37.93095656791388 in 148.0216s
# Negative ELBO at step 2000: 25.972328235677566 in 149.8873s
# Negative ELBO at step 2500: 25.3191878694791 in 149.6757s
# Beginning evaluation 9
# Evaluation 9: Next query is [[0.56804456 0.92559664 0.07103606]
#  [0.27798994 0.79328167 0.65997055]]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 32635.584678463834 in 0.4633s
# Negative ELBO at step 500: 274.252738538597 in 165.1514s
# Negative ELBO at step 1000: 127.16134588835062 in 165.8454s
# Negative ELBO at step 1500: 90.09668829076476 in 163.0449s
# Negative ELBO at step 2000: 45.237005871207096 in 163.6549s
# Negative ELBO at step 2500: 29.36578944750415 in 163.7834s
# Beginning evaluation 10
# Evaluation 10: Next query is [[0.3798939  0.56045059 0.66821823]
#  [0.96391299 0.30342126 0.26668018]]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 11076.280055572908 in 0.6124s
# Negative ELBO at step 500: 202.9085669698367 in 172.4547s
# Negative ELBO at step 1000: 85.30117092672184 in 173.9727s
# Negative ELBO at step 1500: 39.32521691137002 in 171.2334s
# Negative ELBO at step 2000: 24.016152492080145 in 170.6404s
# Negative ELBO at step 2500: 22.712589446279182 in 171.6577s
# Beginning evaluation 11
# Evaluation 11: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.53794578 0.93766309 0.3051887 ]]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 9808.147607845609 in 0.5167s
# Negative ELBO at step 500: 204.29686160012105 in 181.2337s
# Negative ELBO at step 1000: 66.36822513924105 in 188.6022s
# Negative ELBO at step 1500: 43.656690469733704 in 183.3714s
# Negative ELBO at step 2000: 27.281612522065934 in 184.9099s
# Negative ELBO at step 2500: 21.4288087402795 in 184.8519s
# Beginning evaluation 12
# Evaluation 12: Next query is [[0.27798994 0.79328167 0.65997055]
#  [0.79611711 0.81999571 0.48579488]]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 26756.353010685114 in 0.5315s
# Negative ELBO at step 500: 386.7340361715933 in 193.0235s
# Negative ELBO at step 1000: 145.34420540814344 in 192.6376s
# Negative ELBO at step 1500: 83.09056126575122 in 195.2676s
# Negative ELBO at step 2000: 47.908509812045224 in 191.3736s
# Negative ELBO at step 2500: 32.68594722094815 in 192.6642s
# Beginning evaluation 13
# Evaluation 13: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.96076647 0.64056459 0.68864832]]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 55806.515195134234 in 0.5014s
# Negative ELBO at step 500: 830.5137605377938 in 201.6628s
# Negative ELBO at step 1000: 397.94298485824766 in 207.0191s
# Negative ELBO at step 1500: 166.21218224238723 in 207.2542s
# Negative ELBO at step 2000: 102.55912980530815 in 202.9762s
# Negative ELBO at step 2500: 86.26886897105345 in 204.1898s
# Beginning evaluation 14
# Evaluation 14: Next query is [[0.0871293  0.0202184  0.83261985]
#  [0.38575967 0.06829277 0.79030471]]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 147449.87547922932 in 0.7484s
# Negative ELBO at step 500: 1230.1617191024911 in 216.4630s
# Negative ELBO at step 1000: 530.6063666394657 in 215.1507s
# Negative ELBO at step 1500: 343.5894307816746 in 217.7420s
# Negative ELBO at step 2000: 237.85726811765895 in 214.5110s
# Negative ELBO at step 2500: 184.55130948860315 in 212.3838s
# Beginning evaluation 15
# Evaluation 15: Next query is [[0.36322396 0.2467724  0.4935906 ]
#  [0.98738334 0.78745161 0.49138007]]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 91880.3426559101 in 0.7468s
# Negative ELBO at step 500: 1608.055362915929 in 224.5526s
# Negative ELBO at step 1000: 449.5522871478969 in 225.8814s
# Negative ELBO at step 1500: 253.88022917892002 in 228.5586s
# Negative ELBO at step 2000: 158.43576088290246 in 229.7877s
# Negative ELBO at step 2500: 109.7559888100703 in 224.8064s
# Beginning evaluation 16
# Evaluation 16: Next query is [[0.0871293  0.0202184  0.83261985]
#  [0.52522331 0.04001707 0.59096908]]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 60146.22273254748 in 0.6345s
# Negative ELBO at step 500: 1106.6322426094305 in 235.4575s
# Negative ELBO at step 1000: 398.33051837679704 in 238.7849s
# Negative ELBO at step 1500: 230.26968520213202 in 237.6111s
# Negative ELBO at step 2000: 144.96327832412786 in 239.6133s
# Negative ELBO at step 2500: 91.99441784770649 in 235.0259s
# Beginning evaluation 17
# Evaluation 17: Next query is [[0.997994   0.98788917 0.60332299]
#  [0.54695006 0.29361682 0.96820439]]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 75625.7063841925 in 0.6585s
# Negative ELBO at step 500: 1473.4318347038704 in 244.5596s
# Negative ELBO at step 1000: 586.4931022049705 in 246.0165s
# Negative ELBO at step 1500: 335.7493174621792 in 248.5732s
# Negative ELBO at step 2000: 208.57691005211285 in 248.5681s
# Negative ELBO at step 2500: 146.98855133279915 in 248.0879s
# Beginning evaluation 18
# Evaluation 18: Next query is [[0.52522331 0.04001707 0.59096908]
#  [0.79142094 0.68630091 0.58753846]]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 136634.50854917426 in 0.7119s
# Negative ELBO at step 500: 1884.6840395994557 in 260.5869s
# Negative ELBO at step 1000: 788.8631188436502 in 258.6769s
# Negative ELBO at step 1500: 433.72512038403306 in 262.4176s
# Negative ELBO at step 2000: 256.8765023887668 in 260.8859s
# Negative ELBO at step 2500: 202.67420386417922 in 258.9458s
# Beginning evaluation 19
# Evaluation 19: Next query is [[0.59831597 0.11891694 0.4175392 ]
#  [0.18808101 0.8952924  0.64677545]]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 124937.44320750823 in 0.9009s
# Negative ELBO at step 500: 2396.8798407101026 in 269.0901s
# Negative ELBO at step 1000: 1032.7455815586934 in 271.1303s
# Negative ELBO at step 1500: 478.69771668529705 in 272.4677s
# Negative ELBO at step 2000: 323.30924003375407 in 268.0666s
# Negative ELBO at step 2500: 232.369841917079 in 270.4752s
# Beginning run 2
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 4.7542976697433 in 0.1401s
# Negative ELBO at step 500: 2.341025928010625 in 52.3928s
# Negative ELBO at step 1000: 2.1857968964336894 in 51.7372s
# Negative ELBO at step 1500: 2.0460539789254018 in 50.2849s
# Negative ELBO at step 2000: 1.9768979288333965 in 50.8160s
# Negative ELBO at step 2500: 1.917067707551162 in 51.9322s
# Beginning evaluation 0
# Evaluation 0: Next query is [[0.77815675 0.87001215 0.97861834]
#  [0.69597422 0.33277685 0.09545662]]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 29.225925567544103 in 0.1754s
# Negative ELBO at step 500: 3.225785184315673 in 63.6719s
# Negative ELBO at step 1000: 2.6550585924484205 in 63.7428s
# Negative ELBO at step 1500: 2.698974407966956 in 61.8927s
# Negative ELBO at step 2000: 2.6159756023994065 in 62.2337s
# Negative ELBO at step 2500: 2.5809319525524357 in 61.9835s
# Beginning evaluation 1
# Evaluation 1: Next query is [[0.69597422 0.33277685 0.09545662]
#  [0.063369   0.40985745 0.72250009]]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 34.8801731012726 in 0.1893s
# Negative ELBO at step 500: 4.540490654618808 in 74.0879s
# Negative ELBO at step 1000: 3.597713383143556 in 72.5348s
# Negative ELBO at step 1500: 3.3472535942441617 in 73.8803s
# Negative ELBO at step 2000: 3.2472627031655676 in 71.5410s
# Negative ELBO at step 2500: 3.2297376659355748 in 73.3768s
# Beginning evaluation 2
# Evaluation 2: Next query is [[0.11827443 0.63992102 0.14335329]
#  [0.15949655 0.19131256 0.54934832]]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 119.7347973397602 in 0.2715s
# Negative ELBO at step 500: 7.044052352509401 in 86.6145s
# Negative ELBO at step 1000: 4.808403786541249 in 83.3326s
# Negative ELBO at step 1500: 4.389132306638057 in 85.0168s
# Negative ELBO at step 2000: 4.444291198745496 in 83.7036s
# Negative ELBO at step 2500: 4.373639434867201 in 86.0162s
# Beginning evaluation 3
# Evaluation 3: Next query is [[0.15949655 0.19131256 0.54934832]
#  [0.57499033 0.73993748 0.70466465]]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 940.6829844307905 in 0.2661s
# Negative ELBO at step 500: 19.285392296098784 in 94.6695s
# Negative ELBO at step 1000: 9.644805512170276 in 95.6579s
# Negative ELBO at step 1500: 6.449609062556156 in 94.5183s
# Negative ELBO at step 2000: 5.574185504507555 in 96.2899s
# Negative ELBO at step 2500: 5.29689924691452 in 96.7878s
# Beginning evaluation 4
# Evaluation 4: Next query is [[0.77815675 0.87001215 0.97861834]
#  [0.14297878 0.35455447 0.66780345]]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 266.1537067932505 in 0.2849s
# Negative ELBO at step 500: 12.528505771869446 in 106.2793s
# Negative ELBO at step 1000: 7.457575729560625 in 105.3119s
# Negative ELBO at step 1500: 6.498499517997738 in 107.9904s
# Negative ELBO at step 2000: 6.218327563377472 in 107.7555s
# Negative ELBO at step 2500: 6.057340539254353 in 105.0036s
# Beginning evaluation 5
# Evaluation 5: Next query is [[0.11827443 0.63992102 0.14335329]
#  [0.20339584 0.17610384 0.31980734]]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 647.1660473918982 in 0.3472s
# Negative ELBO at step 500: 21.24507862681895 in 117.8806s
# Negative ELBO at step 1000: 11.480781790976838 in 119.5156s
# Negative ELBO at step 1500: 9.388908342632558 in 118.1346s
# Negative ELBO at step 2000: 8.175096904904152 in 117.5649s
# Negative ELBO at step 2500: 7.376673753532836 in 118.1033s
# Beginning evaluation 6
# Evaluation 6: Next query is [[0.15949655 0.19131256 0.54934832]
#  [0.14091704 0.61223801 0.1295314 ]]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 897.5840308760123 in 0.4206s
# Negative ELBO at step 500: 33.34496769156709 in 128.6019s
# Negative ELBO at step 1000: 17.27939976194271 in 128.2993s
# Negative ELBO at step 1500: 10.409131257591978 in 130.5688s
# Negative ELBO at step 2000: 8.901327431723137 in 126.4850s
# Negative ELBO at step 2500: 7.855761785378201 in 126.7033s
# Beginning evaluation 7
# Evaluation 7: Next query is [[0.11827443 0.63992102 0.14335329]
#  [0.55899164 0.49769535 0.95750981]]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 13523.760432534515 in 0.4097s
# Negative ELBO at step 500: 241.56206499312765 in 140.2484s
# Negative ELBO at step 1000: 82.00074674347823 in 140.9934s
# Negative ELBO at step 1500: 58.974196485091156 in 141.1929s
# Negative ELBO at step 2000: 37.96945944278657 in 140.5815s
# Negative ELBO at step 2500: 26.46052684258934 in 142.0058s
# Beginning evaluation 8
# Evaluation 8: Next query is [[0.77815675 0.87001215 0.97861834]
#  [0.07247392 0.00549482 0.27624767]]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2448.9617479949916 in 0.4111s
# Negative ELBO at step 500: 87.80237256018272 in 150.2662s
# Negative ELBO at step 1000: 37.53174434351242 in 150.1436s
# Negative ELBO at step 1500: 22.68252010742014 in 149.5756s
# Negative ELBO at step 2000: 15.711164722289581 in 149.0528s
# Negative ELBO at step 2500: 13.09658080376236 in 150.6195s
# Beginning evaluation 9
# Evaluation 9: Next query is [[0.55899164 0.49769535 0.95750981]
#  [0.18870537 0.87368075 0.72288922]]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2833.37943590122 in 0.4011s
# Negative ELBO at step 500: 68.31827816708048 in 162.2782s
# Negative ELBO at step 1000: 32.13313876350563 in 165.0028s
# Negative ELBO at step 1500: 20.01146066620774 in 163.6623s
# Negative ELBO at step 2000: 16.13313933788129 in 161.2956s
# Negative ELBO at step 2500: 12.182129954937384 in 164.9241s
# Beginning evaluation 10
# Evaluation 10: Next query is [[0.69597422 0.33277685 0.09545662]
#  [0.28646463 0.50159147 0.87941746]]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 43799.55631785604 in 0.5079s
# Negative ELBO at step 500: 483.51863519048896 in 170.0344s
# Negative ELBO at step 1000: 186.17201131584508 in 174.0138s
# Negative ELBO at step 1500: 96.89366343673052 in 170.3564s
# Negative ELBO at step 2500: 48.867678671989424 in 171.6758s
# Beginning evaluation 11
# Evaluation 11: Next query is [[0.11827443 0.63992102 0.14335329]
#  [0.47130219 0.29379874 0.98181609]]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 20370.267793516083 in 0.5692s
# Negative ELBO at step 500: 352.89335785637496 in 181.5136s
# Negative ELBO at step 1000: 132.7337369293832 in 184.5100s
# Negative ELBO at step 1500: 69.91690291319485 in 181.7741s
# Negative ELBO at step 2000: 47.010552328453926 in 182.9430s
# Negative ELBO at step 2500: 36.9557910850819 in 184.9437s
# Beginning evaluation 12
# Evaluation 12: Next query is [[0.15949655 0.19131256 0.54934832]
#  [0.35240712 0.89417252 0.18104167]]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 5611.513584873685 in 0.5484s
# Negative ELBO at step 500: 152.3220424434733 in 192.7649s
# Negative ELBO at step 1000: 59.68906177468634 in 195.0766s
# Negative ELBO at step 1500: 38.4738484589221 in 192.7302s
# Negative ELBO at step 2000: 27.25712072579488 in 193.1492s
# Negative ELBO at step 2500: 20.25397853865248 in 193.8527s
# Beginning evaluation 13
# Evaluation 13: Next query is [[0.79915856 0.46147936 0.78052918]
#  [0.02795538 0.02934627 0.577622  ]]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 18096.728012717995 in 0.5565s
# Negative ELBO at step 500: 354.3882791007552 in 201.1819s
# Negative ELBO at step 1000: 110.16865914729165 in 205.8635s
# Negative ELBO at step 1500: 64.62880472949956 in 202.3040s
# Negative ELBO at step 2000: 47.84344437876533 in 203.7986s
# Negative ELBO at step 2500: 31.8259400359232 in 205.1385s
# Beginning evaluation 14
# Evaluation 14: Next query is [[0.18870537 0.87368075 0.72288922]
#  [0.60402693 0.66218365 0.58099582]]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 44659.3082859692 in 0.5961s
# Negative ELBO at step 500: 822.2111106419641 in 216.0835s
# Negative ELBO at step 1000: 277.1951262554942 in 217.2717s
# Negative ELBO at step 1500: 164.65160818548952 in 215.4938s
# Negative ELBO at step 2000: 86.52591750694522 in 214.5667s
# Negative ELBO at step 2500: 69.12882496442603 in 215.3008s
# Beginning evaluation 15
# Evaluation 15: Next query is [[0.14091704 0.61223801 0.1295314 ]
#  [0.68646976 0.24433258 0.15337445]]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 16937.74517820375 in 0.5984s
# Negative ELBO at step 500: 389.6661393265707 in 225.4367s
# Negative ELBO at step 1000: 147.12499082824422 in 226.8457s
# Negative ELBO at step 1500: 91.77349424338587 in 224.0541s
# Negative ELBO at step 2000: 55.61923124314532 in 225.1249s
# Negative ELBO at step 2500: 39.19591691524016 in 227.2512s
# Beginning evaluation 16
# Evaluation 16: Next query is [[0.02795538 0.02934627 0.577622  ]
#  [0.06877785 0.01077776 0.99704634]]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 267727.5990904511 in 0.6621s
# Negative ELBO at step 500: 3559.1500314805558 in 238.9973s
# Negative ELBO at step 1000: 1469.9108976934192 in 235.1110s
# Negative ELBO at step 1500: 889.0699915667487 in 237.8023s
# Negative ELBO at step 2000: 462.2576709441107 in 238.8015s
# Negative ELBO at step 2500: 313.1208546566247 in 239.8985s
# Beginning evaluation 17
# Evaluation 17: Next query is [[0.69597422 0.33277685 0.09545662]
#  [0.82072514 0.50359775 0.52082427]]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 487689.88128801953 in 0.7683s
# Negative ELBO at step 500: 4029.3241826300186 in 246.7211s
# Negative ELBO at step 1000: 1819.1947556219843 in 246.6171s
# Negative ELBO at step 1500: 1054.2707267665962 in 247.2445s
# Negative ELBO at step 2000: 694.3110929977074 in 248.8876s
# Negative ELBO at step 2500: 460.4684916489027 in 248.6809s
# Beginning evaluation 18
# Evaluation 18: Next query is [[0.06877785 0.01077776 0.99704634]
#  [0.63250897 0.51462554 0.13772485]]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 104340.8385286349 in 0.7778s
# Negative ELBO at step 500: 1883.4408964442798 in 259.8223s
# Negative ELBO at step 1000: 804.6528907632536 in 261.1343s
# Negative ELBO at step 1500: 443.05860232403336 in 261.4038s
# Negative ELBO at step 2000: 235.85931012982257 in 260.8283s
# Negative ELBO at step 2500: 159.0376315354595 in 260.3095s
# Beginning evaluation 19
# Evaluation 19: Next query is [[0.063369   0.40985745 0.72250009]
#  [0.84055719 0.08757178 0.97551218]]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 135903.27162432703 in 0.7351s
# Negative ELBO at step 500: 2688.3224006060696 in 269.5005s
# Negative ELBO at step 1000: 797.6440281820159 in 269.0787s
# Negative ELBO at step 1500: 451.9858367665461 in 294.5971s
# Negative ELBO at step 2000: 283.7496256063789 in 336.7262s
# Negative ELBO at step 2500: 195.5171153476433 in 330.7787s
# Beginning run 3
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7.263563061440066 in 0.1443s
# Negative ELBO at step 500: 2.3071779974336826 in 67.9187s
# Negative ELBO at step 1000: 2.114784001198845 in 65.0884s
# Negative ELBO at step 1500: 1.9823129876274002 in 64.8249s
# Negative ELBO at step 2000: 2.061112458231119 in 62.4485s
# Negative ELBO at step 2500: 1.980050053097325 in 68.5572s
# Beginning evaluation 0
# Evaluation 0: Next query is [[0.26455561 0.77423369 0.45615033]
#  [0.20487769 0.81000386 0.56782065]]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 53.829705493062136 in 0.1991s
# Negative ELBO at step 500: 3.9322000792477647 in 80.0194s
# Negative ELBO at step 1000: 2.962290228596734 in 80.1988s
# Negative ELBO at step 1500: 2.892368193056432 in 68.0268s
# Negative ELBO at step 2000: 2.8294614290522566 in 82.9074s
# Negative ELBO at step 2500: 2.7442683708748787 in 77.5830s
# Beginning evaluation 1
# Evaluation 1: Next query is [[0.94466892 0.52184832 0.41466194]
#  [0.28934192 0.39857764 0.97084726]]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 38.76079312873472 in 0.1903s
# Negative ELBO at step 500: 4.346278639000351 in 94.7694s
# Negative ELBO at step 1000: 3.504828726937069 in 88.2659s
# Negative ELBO at step 1500: 3.447306018128751 in 98.6312s
# Negative ELBO at step 2000: 3.5267504443327384 in 90.7426s
# Negative ELBO at step 2500: 3.4959762317135996 in 99.8103s
# Beginning evaluation 2
# Evaluation 2: Next query is [[0.20487769 0.81000386 0.56782065]
#  [0.47147972 0.8175088  0.45251495]]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1439.7989523258636 in 0.2254s
# Negative ELBO at step 500: 32.492032099986545 in 112.3668s
# Negative ELBO at step 1000: 11.770059962931972 in 100.8887s
# Negative ELBO at step 1500: 9.09412787967236 in 111.8497s
# Negative ELBO at step 2000: 9.216814591598542 in 100.1862s
# Negative ELBO at step 2500: 6.741034173900092 in 111.5710s
# Beginning evaluation 3
# Evaluation 3: Next query is [[0.56843395 0.0187898  0.6176355 ]
#  [0.69740038 0.4139625  0.6296183 ]]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 89.38726198922605 in 0.2503s
# Negative ELBO at step 500: 7.088391606887107 in 126.8476s
# Negative ELBO at step 1000: 5.236924555712864 in 110.7002s
# Negative ELBO at step 1500: 4.790246628615833 in 110.7368s
# Negative ELBO at step 2000: 4.85970468501439 in 113.7009s
# Negative ELBO at step 2500: 4.72076799455319 in 114.6326s
# Beginning evaluation 4
# Evaluation 4: Next query is [[0.94466892 0.52184832 0.41466194]
#  [0.01032792 0.67777514 0.17808517]]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 699.1266493639813 in 0.7335s
# Negative ELBO at step 500: 21.271094289119073 in 128.8915s
# Negative ELBO at step 1000: 10.875690584204808 in 129.4869s
# Negative ELBO at step 1500: 9.09320787372588 in 131.5051s
# Negative ELBO at step 2000: 6.503829298926016 in 126.0047s
# Negative ELBO at step 2500: 6.031148115022983 in 124.2356s
# Beginning evaluation 5
# Evaluation 5: Next query is [[0.94466892 0.52184832 0.41466194]
#  [0.93686283 0.77386297 0.40563389]]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 971.2928992396178 in 0.3364s
# Negative ELBO at step 500: 28.941981444187796 in 142.3920s
# Negative ELBO at step 1000: 13.464488354997819 in 145.9520s
# Negative ELBO at step 1500: 8.430052417461024 in 138.6821s
# Negative ELBO at step 2000: 7.320269733220769 in 142.4950s
# Negative ELBO at step 2500: 6.782913436952695 in 143.3902s
# Beginning evaluation 6
# Evaluation 6: Next query is [[0.26455561 0.77423369 0.45615033]
#  [0.49222678 0.36133145 0.57935088]]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7325.600919988852 in 0.3360s
# Negative ELBO at step 500: 155.57006318096478 in 154.0713s
# Negative ELBO at step 1000: 62.06366750265009 in 159.4180s
# Negative ELBO at step 1500: 32.48603715491414 in 164.3556s
# Negative ELBO at step 2000: 22.83588386586059 in 162.3686s
# Negative ELBO at step 2500: 17.00808107402579 in 171.4784s
# Beginning evaluation 7
# Evaluation 7: Next query is [[0.47147972 0.8175088  0.45251495]
#  [0.27379311 0.91753949 0.75773427]]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 8913.829389263268 in 0.3538s
# Negative ELBO at step 500: 145.75568262367858 in 177.2708s
# Negative ELBO at step 1000: 58.27492780069157 in 178.9331s
# Negative ELBO at step 1500: 32.3244772413577 in 172.2383s
# Negative ELBO at step 2000: 18.804823253365257 in 167.3274s
# Negative ELBO at step 2500: 15.403637549357178 in 174.3530s
# Beginning evaluation 8
# Evaluation 8: Next query is [[0.47147972 0.8175088  0.45251495]
#  [0.76935769 0.83984988 0.31260788]]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 11011.906118331435 in 0.3892s
# Negative ELBO at step 500: 266.5334559351811 in 189.1941s
# Negative ELBO at step 1000: 113.27947638792062 in 181.1508s
# Negative ELBO at step 1500: 52.331993833083025 in 187.3763s
# Negative ELBO at step 2000: 31.678956913819125 in 192.4513s
# Negative ELBO at step 2500: 24.136635419027975 in 187.3354s
# Beginning evaluation 9
# Evaluation 9: Next query is [[0.93686283 0.77386297 0.40563389]
#  [0.28833118 0.42694236 0.74447356]]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 10650.034853686855 in 1.0729s
# Negative ELBO at step 500: 218.2843674712189 in 202.8935s
# Negative ELBO at step 1000: 75.95180558540075 in 205.6771s
# Negative ELBO at step 1500: 54.29316485884197 in 205.3827s
# Negative ELBO at step 2000: 31.742565843390917 in 196.1772s
# Negative ELBO at step 2500: 27.757911175144315 in 194.8960s
# Beginning evaluation 10
# Evaluation 10: Next query is [[0.47147972 0.8175088  0.45251495]
#  [0.82857069 0.74738178 0.15570077]]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 42522.15010416234 in 0.4542s
# Negative ELBO at step 500: 425.1698633474577 in 212.2487s
# Negative ELBO at step 1000: 179.92115055111142 in 203.2255s
# Negative ELBO at step 1500: 87.18817601933615 in 203.6571s
# Negative ELBO at step 2000: 59.1710376833845 in 205.1689s
# Negative ELBO at step 2500: 31.48939233426476 in 197.8581s
# Beginning evaluation 11
# Evaluation 11: Next query is [[0.93686283 0.77386297 0.40563389]
#  [0.39420789 0.89973486 0.58986812]]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 6034.728010679549 in 0.5266s
# Negative ELBO at step 500: 142.82946285686572 in 219.8020s
# Negative ELBO at step 1000: 62.90754210289731 in 223.3481s
# Negative ELBO at step 1500: 34.59704462426545 in 224.5614s
# Negative ELBO at step 2000: 20.07318653539894 in 219.3672s
# Negative ELBO at step 2500: 17.38973334972678 in 215.2399s
# Beginning evaluation 12
# Evaluation 12: Next query is [[0.28833118 0.42694236 0.74447356]
#  [0.09538035 0.96668199 0.38958478]]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 17412.693906500856 in 0.5869s
# Negative ELBO at step 500: 368.4757485932612 in 248.5082s
# Negative ELBO at step 1000: 139.96031983329763 in 252.4099s
# Negative ELBO at step 1500: 74.38051780480419 in 247.0638s
# Negative ELBO at step 2000: 47.174188506135216 in 241.7960s
# Negative ELBO at step 2500: 31.249387109549907 in 241.6446s
# Beginning evaluation 13
# Evaluation 13: Next query is [[0.93686283 0.77386297 0.40563389]
#  [0.45849116 0.08161389 0.66102798]]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 87766.93304394899 in 0.6522s
# Negative ELBO at step 500: 959.4151865754216 in 254.4928s
# Negative ELBO at step 1000: 437.06776350844046 in 257.3472s
# Negative ELBO at step 1500: 190.80534443984314 in 249.7345s
# Negative ELBO at step 2000: 104.31483739248206 in 246.2423s
# Negative ELBO at step 2500: 66.82854451288244 in 245.5197s
# Beginning evaluation 14
# Evaluation 14: Next query is [[0.26455561 0.77423369 0.45615033]
#  [0.12925762 0.50268559 0.18631862]]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 81614.19144994124 in 0.7442s
# Negative ELBO at step 500: 1553.1989112909612 in 261.8048s
# Negative ELBO at step 1000: 539.4240696008491 in 282.5288s
# Negative ELBO at step 1500: 257.8108387016409 in 271.2417s
# Negative ELBO at step 2000: 143.6219265427547 in 273.8613s
# Negative ELBO at step 2500: 95.90582676841711 in 283.9799s
# Beginning evaluation 15
# Evaluation 15: Next query is [[0.28934192 0.39857764 0.97084726]
#  [0.21370719 0.76223281 0.48637379]]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 133617.22641738554 in 0.6943s
# Negative ELBO at step 500: 1515.47438909804 in 271.3186s
# Negative ELBO at step 1000: 622.7064440748585 in 280.2894s
# Negative ELBO at step 1500: 350.2242217665538 in 280.9363s
# Negative ELBO at step 2000: 193.77383146295304 in 276.8620s
# Negative ELBO at step 2500: 130.8600314649061 in 275.3434s
# Beginning evaluation 16
# Evaluation 16: Next query is [[0.93686283 0.77386297 0.40563389]
#  [0.72404239 0.78435259 0.33035861]]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 29402.399655558056 in 1.1264s
# Negative ELBO at step 500: 662.9321237007277 in 305.3586s
# Negative ELBO at step 1000: 258.2855160155862 in 301.3285s
# Negative ELBO at step 1500: 143.97746356099324 in 301.7361s
# Negative ELBO at step 2000: 92.25968856718912 in 297.7075s
# Negative ELBO at step 2500: 64.82267712119514 in 308.2363s
# Negative ELBO at step 500: 7903.770713942254 in 307.3089s
# Negative ELBO at step 1000: 3293.238491151637 in 304.1487s
# Negative ELBO at step 1500: 1502.9639250460611 in 304.1656s
# Negative ELBO at step 2000: 999.6194022763318 in 311.0959s
# Negative ELBO at step 2500: 704.8176438740093 in 303.0069s
# Beginning evaluation 18
# Evaluation 18: Next query is [[0.26455561 0.77423369 0.45615033]
#  [0.33495454 0.80859617 0.68811388]]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 155744.21941991118 in 0.6968s
# Negative ELBO at step 500: 2552.151588075596 in 327.9509s
# Negative ELBO at step 1000: 1068.3665381677008 in 269.9536s
# Negative ELBO at step 1500: 651.3405488760901 in 261.5497s
# Negative ELBO at step 2000: 377.1912842144941 in 258.7431s
# Negative ELBO at step 2500: 213.94516741634303 in 261.0950s
# Beginning evaluation 19
# Evaluation 19: Next query is [[0.76935769 0.83984988 0.31260788]
#  [0.67954193 0.82536885 0.21166892]]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 356913.7872141588 in 0.9475s
# Negative ELBO at step 500: 4368.258640796421 in 270.4691s
# Negative ELBO at step 1000: 2098.703499444171 in 270.3396s
# Negative ELBO at step 1500: 935.3913009060619 in 271.9633s
# Negative ELBO at step 2000: 579.7192269254251 in 271.3851s
# Negative ELBO at step 2500: 395.4660821472497 in 268.7728s
# Beginning run 4
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 186.08960630251428 in 0.1376s
# Negative ELBO at step 500: 4.398323705091533 in 52.1526s
# Negative ELBO at step 1000: 3.3818472764326115 in 51.3150s
# Negative ELBO at step 1500: 2.990324374509067 in 52.0631s
# Negative ELBO at step 2000: 2.3944261570928074 in 50.5624s
# Negative ELBO at step 2500: 2.2759111816437767 in 52.2584s
# Beginning evaluation 0
# Evaluation 0: Next query is [[0.61209572 0.616934   0.94374808]
#  [0.4155887  0.9074198  0.49630736]]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 11.778647096891607 in 0.2024s
# Negative ELBO at step 500: 2.9908197056273975 in 61.4279s
# Negative ELBO at step 1000: 2.7878005678129014 in 63.2873s
# Negative ELBO at step 1500: 2.701261064135168 in 61.0339s
# Negative ELBO at step 2000: 2.7584032198781734 in 63.3727s
# Negative ELBO at step 2500: 2.7569325513054848 in 62.9817s
# Beginning evaluation 1
# Evaluation 1: Next query is [[0.6818203  0.3595079  0.43703195]
#  [0.46532407 0.66939017 0.81028094]]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 87.05541398999723 in 0.2184s
# Negative ELBO at step 500: 6.448108981151753 in 74.5071s
# Negative ELBO at step 1000: 3.790968436715265 in 73.0133s
# Negative ELBO at step 1500: 3.633331663540398 in 73.7628s
# Negative ELBO at step 2000: 3.359787611002466 in 73.5193s
# Negative ELBO at step 2500: 3.346971742764046 in 72.7978s
# Beginning evaluation 2
# Evaluation 2: Next query is [[0.6976312  0.06022547 0.66676672]
#  [0.6755326  0.18800797 0.26195315]]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 173.8547236379529 in 0.2215s
# Negative ELBO at step 500: 7.496384072575783 in 83.5143s
# Negative ELBO at step 1000: 5.162951786780927 in 83.7494s
# Negative ELBO at step 1500: 4.302131320067904 in 83.1601s
# Negative ELBO at step 2000: 4.085941224231954 in 87.5062s
# Negative ELBO at step 2500: 4.252715789952463 in 83.2232s
# Beginning evaluation 3
# Evaluation 3: Next query is [[0.61209572 0.616934   0.94374808]
#  [0.81566656 0.85898652 0.65709623]]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 121.7958198114799 in 0.2338s
# Negative ELBO at step 500: 7.01914785590988 in 95.0763s
# Negative ELBO at step 1000: 5.021554011830769 in 94.9566s
# Negative ELBO at step 1500: 4.922734653723097 in 95.6981s
# Negative ELBO at step 2000: 4.784654681693754 in 94.5179s
# Negative ELBO at step 2500: 4.68177540485974 in 95.2351s
# Beginning evaluation 4
# Evaluation 4: Next query is [[0.6976312  0.06022547 0.66676672]
#  [0.23645571 0.37596243 0.43116513]]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 355.3367629560619 in 0.3187s
# Negative ELBO at step 500: 17.787015216724505 in 105.9269s
# Negative ELBO at step 1000: 7.43811241780397 in 107.5917s
# Negative ELBO at step 1500: 6.46100890344735 in 106.5852s
# Negative ELBO at step 2000: 5.828447927183246 in 106.3973s
# Negative ELBO at step 2500: 5.36043694095293 in 106.1527s
# Beginning evaluation 5
# Evaluation 5: Next query is [[0.6976312  0.06022547 0.66676672]
#  [0.5308068  0.54559505 0.9446899 ]]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 446.2601703109879 in 0.3375s
# Negative ELBO at step 500: 17.560589693792274 in 115.3943s
# Negative ELBO at step 1000: 10.070588887940502 in 117.8901s
# Negative ELBO at step 1500: 7.321848263292241 in 117.4187s
# Negative ELBO at step 2000: 6.2683251931528154 in 115.5554s
# Negative ELBO at step 2500: 6.2201381862320995 in 119.2892s
# Beginning evaluation 6
# Evaluation 6: Next query is [[0.6755326  0.18800797 0.26195315]
#  [0.1058747  0.88811617 0.50349775]]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1669.8984571629558 in 0.3656s
# Negative ELBO at step 500: 29.975920271060346 in 127.6197s
# Negative ELBO at step 1000: 14.775407529936118 in 128.6870s
# Negative ELBO at step 1500: 12.3491314157131 in 129.0995s
# Negative ELBO at step 2000: 9.056215082304394 in 129.3869s
# Negative ELBO at step 2500: 8.011309537258011 in 127.2755s
# Beginning evaluation 7
# Evaluation 7: Next query is [[0.23645571 0.37596243 0.43116513]
#  [0.23484841 0.05512453 0.01890107]]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 858.0810008516574 in 0.3631s
# Negative ELBO at step 500: 29.528960816821375 in 140.3808s
# Negative ELBO at step 1000: 15.108772076593958 in 140.4564s
# Negative ELBO at step 1500: 10.534758698403508 in 140.9733s
# Negative ELBO at step 2000: 8.679769643425143 in 141.0269s
# Negative ELBO at step 2500: 8.374788570032871 in 141.1903s
# Beginning evaluation 8
# Evaluation 8: Next query is [[0.23484841 0.05512453 0.01890107]
#  [0.74147265 0.23937852 0.03745515]]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 3243.7925128686115 in 0.4405s
# Negative ELBO at step 500: 97.22145319332564 in 150.6181s
# Negative ELBO at step 1000: 45.26161494026886 in 150.6407s
# Negative ELBO at step 1500: 23.437993527316035 in 149.3958s
# Negative ELBO at step 2000: 16.002972766446494 in 151.6809s
# Negative ELBO at step 2500: 14.459068091531439 in 150.2577s
# Beginning evaluation 9
# Evaluation 9: Next query is [[0.4155887  0.9074198  0.49630736]
#  [0.53942578 0.4884055  0.55625735]]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 17383.98918290344 in 0.4770s
# Negative ELBO at step 500: 373.8159978802608 in 162.6630s
# Negative ELBO at step 1000: 138.4614662478879 in 164.4020s
# Negative ELBO at step 1500: 83.36881056801377 in 161.6502s
# Negative ELBO at step 2000: 50.48203530990999 in 161.3630s
# Negative ELBO at step 2500: 30.00709349483322 in 162.2221s
# Beginning evaluation 10
# Evaluation 10: Next query is [[0.53942578 0.4884055  0.55625735]
#  [0.49962121 0.33207435 0.51043818]]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 22789.0867969428 in 0.5398s
# Negative ELBO at step 500: 386.7379453146343 in 174.1790s
# Negative ELBO at step 1000: 140.89826353654794 in 172.1422s
# Negative ELBO at step 1500: 66.3573126516307 in 172.8210s
# Negative ELBO at step 2000: 46.89479337103009 in 173.8979s
# Negative ELBO at step 2500: 32.45232992299276 in 173.1460s
# Beginning evaluation 11
# Evaluation 11: Next query is [[0.23484841 0.05512453 0.01890107]
#  [0.02797926 0.2923274  0.97300258]]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 4198.105047225054 in 0.4949s
# Negative ELBO at step 500: 145.43064446592905 in 181.8806s
# Negative ELBO at step 1000: 64.97966580867117 in 183.1821s
# Negative ELBO at step 1500: 43.139661896030965 in 186.3878s
# Negative ELBO at step 2000: 25.792749205288104 in 185.2212s
# Negative ELBO at step 2500: 17.734445791900676 in 183.6847s
# Beginning evaluation 12
# Evaluation 12: Next query is [[0.53942578 0.4884055  0.55625735]
#  [0.45222121 0.66693986 0.80794342]]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 22810.078149306304 in 0.5452s
# Negative ELBO at step 500: 381.9010848515863 in 192.9508s
# Negative ELBO at step 1000: 155.71328488307586 in 192.6735s
# Negative ELBO at step 1500: 80.10087060513794 in 196.0390s
# Negative ELBO at step 2000: 44.41928974086654 in 193.1466s
# Negative ELBO at step 2500: 34.287825668567734 in 193.3134s
# Beginning evaluation 13
# Evaluation 13: Next query is [[0.46532407 0.66939017 0.81028094]
#  [0.22210949 0.73017758 0.6828881 ]]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 34884.8744767542 in 0.5869s
# Negative ELBO at step 500: 665.5791431178909 in 203.4465s
# Negative ELBO at step 1000: 250.30993769981495 in 209.3875s
# Negative ELBO at step 1500: 150.10404162243896 in 205.3915s
# Negative ELBO at step 2000: 83.26834020542938 in 206.8959s
# Negative ELBO at step 2500: 59.044524047746734 in 204.0126s
# Beginning evaluation 14
# Evaluation 14: Next query is [[0.1058747  0.88811617 0.50349775]
#  [0.90677455 0.29565155 0.64990036]]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 166280.43658862618 in 0.5747s
# Negative ELBO at step 500: 2227.0167541702203 in 220.3471s
# Negative ELBO at step 1000: 781.8022480480076 in 213.6443s
# Negative ELBO at step 1500: 306.327854215858 in 217.0813s
# Negative ELBO at step 2000: 318.92262262378244 in 214.6636s
# Negative ELBO at step 2500: 168.89857567748123 in 215.8775s
# Beginning evaluation 15
# Evaluation 15: Next query is [[0.6976312  0.06022547 0.66676672]
#  [0.67428712 0.04974564 0.71965364]]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 66949.25796476145 in 0.6170s
# Negative ELBO at step 500: 1027.6511544768146 in 225.6830s
# Negative ELBO at step 1000: 525.2739779790202 in 224.9574s
# Negative ELBO at step 1500: 263.9262310143053 in 226.1927s
# Negative ELBO at step 2000: 149.2258052484934 in 223.0809s
# Negative ELBO at step 2500: 102.59003273614088 in 225.6011s
# Beginning evaluation 16
# Evaluation 16: Next query is [[0.1058747  0.88811617 0.50349775]
#  [0.62548881 0.61767002 0.73643582]]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 340160.0567736759 in 0.6260s
# Negative ELBO at step 500: 4130.06089039908 in 238.5486s
# Negative ELBO at step 1000: 1635.6062844146786 in 235.9982s
# Negative ELBO at step 1500: 828.7415005619604 in 239.7785s
# Negative ELBO at step 2000: 563.6872680345261 in 242.9607s
# Negative ELBO at step 2500: 424.05875403084553 in 241.3477s
# Beginning evaluation 17
# Evaluation 17: Next query is [[0.5308068  0.54559505 0.9446899 ]
#  [0.28163004 0.84942031 0.51979923]]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 215899.2082461278 in 0.8343s
# Negative ELBO at step 500: 2982.296235536787 in 245.2331s
# Negative ELBO at step 1000: 1044.0888750096276 in 247.4305s
# Negative ELBO at step 1500: 614.4174296917414 in 245.8141s
# Negative ELBO at step 2000: 374.787756153993 in 249.8600s
# Negative ELBO at step 2500: 230.14913181571117 in 251.5478s
# Beginning evaluation 18
# Evaluation 18: Next query is [[0.67428712 0.04974564 0.71965364]
#  [0.87842025 0.89862595 0.52733238]]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 132721.60869750864 in 0.7529s
# Negative ELBO at step 500: 2267.7644667865125 in 261.3642s
# Negative ELBO at step 1000: 782.6645784575213 in 259.3480s
# Negative ELBO at step 1500: 398.55701242466034 in 260.7904s
# Negative ELBO at step 2000: 263.5057985161042 in 262.1301s
# Negative ELBO at step 2500: 166.48838555379157 in 260.1859s
# Beginning evaluation 19
# Evaluation 19: Next query is [[0.46532407 0.66939017 0.81028094]
#  [0.91952199 0.30859523 0.94250059]]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 138199.85905412765 in 0.7383s
# Negative ELBO at step 500: 2361.4524558161575 in 269.4882s
# Negative ELBO at step 1000: 944.6198294294849 in 267.6507s
# Negative ELBO at step 1500: 612.5367545904104 in 270.4895s
# Negative ELBO at step 2000: 365.70227953458016 in 271.5726s
# Negative ELBO at step 2500: 239.9369260455097 in 268.0305s
# Beginning run 5
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 19.111862362219775 in 0.1678s
# Negative ELBO at step 500: 2.479078966648254 in 53.6928s
# Negative ELBO at step 1000: 2.2659084052380374 in 52.3149s
# Negative ELBO at step 1500: 2.1002373792246214 in 51.1694s
# Negative ELBO at step 2000: 2.0181706365581498 in 52.4167s
# Negative ELBO at step 2500: 1.9924538712515467 in 53.9847s
# Beginning evaluation 0
# Evaluation 0: Next query is [[0.67063787 0.21038256 0.1289263 ]
#  [0.6892962  0.07453008 0.29865743]]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 422.7279999080435 in 0.1595s
# Negative ELBO at step 500: 10.476049065320057 in 63.3372s
# Negative ELBO at step 1000: 6.7011375412809215 in 64.2236s
# Negative ELBO at step 1500: 3.8408452971739218 in 64.5998s
# Negative ELBO at step 2000: 3.739874391805875 in 65.1636s
# Negative ELBO at step 2500: 3.3015131259133983 in 63.0742s
# Beginning evaluation 1
# Evaluation 1: Next query is [[0.6892962  0.07453008 0.29865743]
#  [0.30730966 0.50981511 0.43438855]]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 113.88963088663759 in 0.1894s
# Negative ELBO at step 500: 5.331666110335401 in 74.1558s
# Negative ELBO at step 1000: 3.8628376583590285 in 73.4321s
# Negative ELBO at step 1500: 3.763441394800371 in 75.2853s
# Negative ELBO at step 2000: 3.649658843808574 in 74.3533s
# Negative ELBO at step 2500: 3.6016996429338217 in 74.4348s
# Beginning evaluation 2
# Evaluation 2: Next query is [[0.31542835 0.36371077 0.57019677]
#  [0.87256336 0.06255667 0.49346694]]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 222.08010907048123 in 0.2665s
# Negative ELBO at step 500: 8.792509611873125 in 84.7032s
# Negative ELBO at step 1000: 5.77469850668369 in 84.1964s
# Negative ELBO at step 1500: 4.821704025096211 in 85.6368s
# Negative ELBO at step 2000: 4.548050713766875 in 83.2311s
# Negative ELBO at step 2500: 4.588847186411435 in 86.2287s
# Beginning evaluation 3
# Evaluation 3: Next query is [[0.43860151 0.98837384 0.10204481]
#  [0.78716384 0.09100696 0.95367824]]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 3553.344792442287 in 0.2895s
# Negative ELBO at step 500: 56.77863193671648 in 96.1935s
# Negative ELBO at step 1000: 24.295243999667505 in 94.1670s
# Negative ELBO at step 1500: 14.760317762505574 in 94.3112s
# Negative ELBO at step 2000: 10.198007988538041 in 97.1725s
# Negative ELBO at step 2500: 7.875247509547275 in 97.0772s
# Beginning evaluation 4
# Evaluation 4: Next query is [[0.78716384 0.09100696 0.95367824]
#  [0.52952903 0.64004555 0.66627283]]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1536.0769084525712 in 0.2833s
# Negative ELBO at step 500: 35.89316105184326 in 105.1284s
# Negative ELBO at step 1000: 14.880719108876352 in 106.4889s
# Negative ELBO at step 1500: 8.728401285325846 in 109.3498s
# Negative ELBO at step 2000: 7.852648463258392 in 105.2850s
# Negative ELBO at step 2500: 6.8774050608878365 in 102.9402s
# Beginning evaluation 5
# Evaluation 5: Next query is [[0.43860151 0.98837384 0.10204481]
#  [0.55767262 0.41250902 0.77872567]]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 457.429165575169 in 0.3619s
# Negative ELBO at step 500: 19.159383175429646 in 115.4767s
# Negative ELBO at step 1000: 11.524179194846711 in 115.3227s
# Negative ELBO at step 1500: 7.611755988923548 in 117.9550s
# Negative ELBO at step 2000: 7.599741653176501 in 116.2994s
# Negative ELBO at step 2500: 7.050659347400365 in 116.3971s
# Beginning evaluation 6
# Evaluation 6: Next query is [[0.67063787 0.21038256 0.1289263 ]
#  [0.98776285 0.04164528 0.9458517 ]]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1449.8439108450748 in 0.3269s
# Negative ELBO at step 500: 41.50155350461361 in 129.3461s
# Negative ELBO at step 1000: 21.35011579879015 in 130.2039s
# Negative ELBO at step 1500: 11.372411777818805 in 126.6718s
# Negative ELBO at step 2000: 10.337675977287951 in 127.2461s
# Negative ELBO at step 2500: 9.14426246578632 in 127.9397s
# Beginning evaluation 7
# Evaluation 7: Next query is [[0.6892962  0.07453008 0.29865743]
#  [0.34765174 0.16888337 0.16242146]]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 4982.229052454081 in 0.3424s
# Negative ELBO at step 500: 88.01994127095271 in 139.9341s
# Negative ELBO at step 1000: 36.90207011661083 in 140.6368s
# Negative ELBO at step 1500: 23.033144808432457 in 139.8644s
# Negative ELBO at step 2000: 15.469238227594687 in 139.2834s
# Negative ELBO at step 2500: 13.627076689349655 in 141.8477s
# Beginning evaluation 8
# Evaluation 8: Next query is [[0.98776285 0.04164528 0.9458517 ]
#  [0.89068713 0.04479231 0.2200711 ]]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1511.9685555462063 in 0.3587s
# Negative ELBO at step 500: 40.14852620599396 in 150.5049s
# Negative ELBO at step 1000: 19.55244004265611 in 152.4193s
# Negative ELBO at step 1500: 13.806800107014926 in 148.2280s
# Negative ELBO at step 2000: 10.865960703568964 in 149.3646s
# Negative ELBO at step 2500: 10.095381419808902 in 148.6182s
# Beginning evaluation 9
# Evaluation 9: Next query is [[0.34765174 0.16888337 0.16242146]
#  [0.69624826 0.61328558 0.4861621 ]]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 4054.799265648625 in 0.4154s
# Negative ELBO at step 500: 113.77472241129777 in 160.6445s
# Negative ELBO at step 1000: 53.57979955382428 in 160.3073s
# Negative ELBO at step 1500: 27.335887483870664 in 160.8895s
# Negative ELBO at step 2000: 18.85403680747641 in 165.2240s
# Negative ELBO at step 2500: 15.805386153067184 in 161.4523s
# Beginning evaluation 10
# Evaluation 10: Next query is [[0.30730966 0.50981511 0.43438855]
#  [0.40902322 0.88282548 0.41968604]]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 18103.485141907127 in 0.5383s
# Negative ELBO at step 500: 365.40077178466817 in 172.4766s
# Negative ELBO at step 1000: 146.58004185685138 in 176.5612s
# Negative ELBO at step 1500: 80.96019942152499 in 173.1961s
# Negative ELBO at step 2000: 50.38852487382688 in 173.4893s
# Negative ELBO at step 2500: 31.43514679943491 in 174.5074s
# Beginning evaluation 11
# Evaluation 11: Next query is [[0.55767262 0.41250902 0.77872567]
#  [0.22579991 0.70364761 0.22017853]]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 5814.550541671931 in 0.4767s
# Negative ELBO at step 500: 161.45856151589948 in 183.2209s
# Negative ELBO at step 1000: 66.6579120640156 in 182.3798s
# Negative ELBO at step 1500: 38.12647775198888 in 184.4052s
# Negative ELBO at step 2000: 22.80956851399349 in 183.6495s
# Negative ELBO at step 2500: 17.558698305834856 in 185.3086s
# Beginning evaluation 12
# Evaluation 12: Next query is [[0.43860151 0.98837384 0.10204481]
#  [0.73777386 0.02633856 0.92715044]]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 54844.25300675063 in 0.5412s
# Negative ELBO at step 500: 923.4741915348109 in 193.8657s
# Negative ELBO at step 1000: 311.2173184546691 in 192.2060s
# Negative ELBO at step 1500: 187.14366613355895 in 190.7183s
# Negative ELBO at step 2000: 105.21973565479509 in 194.9031s
# Negative ELBO at step 2500: 71.06775027533888 in 195.4264s
# Beginning evaluation 13
# Evaluation 13: Next query is [[0.52952903 0.64004555 0.66627283]
#  [0.98788958 0.29243083 0.89444372]]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 67511.07300340619 in 0.6247s
# Negative ELBO at step 500: 929.5673411524298 in 208.8525s
# Negative ELBO at step 1000: 359.774760113331 in 209.4797s
# Negative ELBO at step 1500: 191.26716461654735 in 206.4236s
# Negative ELBO at step 2000: 117.22238275247345 in 205.4811s
# Negative ELBO at step 2500: 74.9971528762571 in 202.7933s
# Beginning evaluation 14
# Evaluation 14: Next query is [[0.67063787 0.21038256 0.1289263 ]
#  [0.84335482 0.32626442 0.85206646]]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 24268.306586542505 in 0.5454s
# Negative ELBO at step 500: 422.5657059347567 in 216.8571s
# Negative ELBO at step 1000: 175.49358558000395 in 214.1335s
# Negative ELBO at step 1500: 97.11986832967777 in 213.6256s
# Negative ELBO at step 2000: 53.01368825740016 in 214.6630s

# %%
print_summary(model)

# %%
pickle.dump((X_results, y_results, best_guess_results), open(results_dir + "Xybestguess.p", "wb"))

# %%
def dist(x, y):
    """
    x and y have shape (..., input_dims)
    """
    return np.sqrt(np.sum((x - y) * (x - y), axis=-1))

xx = uniform_grid(input_dims, num_discrete_per_dim, low=objective_low, high=objective_high)
global_min = xx[np.argmin(objective(xx))][0]

for i in range(best_guess_results.shape[0]):
    diff_from_min = dist(best_guess_results[i], global_min)
    
    x_axis = list(range(num_combs+1, num_combs+1+num_evals))
    plt.figure(figsize=(12, 6))
    plt.plot(x_axis, diff_from_min, 'kx', mew=2)
    plt.xticks(x_axis)
    plt.xlabel('Evaluations', fontsize=18)
    plt.ylabel('Best guess distance', fontsize=16)
    plt.title("Run %s" % i)
    plt.show()
