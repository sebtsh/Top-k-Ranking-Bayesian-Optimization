# %% [markdown]
# # Preferential Bayesian Optimization: RANDOM
# This notebook demonstrates the use of random querying on ordinal (preference) data.
#
# Formulation by Nguyen Quoc Phong.

# %%
import numpy as np
import gpflow
import tensorflow as tf
import matplotlib.pyplot as plt
import sys
import os
import pickle

from gpflow.utilities import set_trainable, print_summary
gpflow.config.set_default_summary_fmt("notebook")

sys.path.append(os.path.split(os.path.split(os.path.split(os.getcwd())[0])[0])[0]) # Move 3 levels up directory to import PBO
import PBO

# %%
objective = PBO.objectives.hartmann3d
objective_low = 0
objective_high = 1.
objective_name = "Hart3"
acquisition_name = "RANDOM"
experiment_name = "PBO" + "_" + acquisition_name + "_" + objective_name

# %%
num_runs = 20
num_evals = 20
num_samples = 1000
num_choices = 2
input_dims = 3
num_maximizers = 20
num_init_points = 3
num_inducing_init = 3
num_discrete_per_dim = 100 # Discretization of continuous input space

# %%
results_dir = os.getcwd() + '/results/' + experiment_name + '/'

try:
    # Create target Directory
    os.makedirs(results_dir)
    print("Directory " , results_dir ,  " created ") 
except FileExistsError:
    print("Directory " , results_dir ,  " already exists")
# Out:
# Directory  /home/sebtsh/PBO/notebooks/RANDOM/results/PBO_RANDOM_Hart3/  already exists

# %%
def get_noisy_observation(X, objective):
    f = PBO.objectives.objective_get_f_neg(X, objective)
    return PBO.observation_model.gen_observation_from_f(X, f, 1)

# %%
def train_and_visualize(X, y, num_inducing, title):
    
    # Train model with data
    q_mu, q_sqrt, u, inputs, k, indifference_threshold = PBO.models.learning_stochastic.train_model_fullcov(X, y, 
                                                                         num_inducing=num_inducing,
                                                                         obj_low=objective_low,
                                                                         obj_high=objective_high,
                                                                         num_steps=3000)
    likelihood = gpflow.likelihoods.Gaussian()
    model = PBO.models.learning.init_SVGP_fullcov(q_mu, q_sqrt, u, k, likelihood)
    u_mean = q_mu.numpy()
    inducing_vars = u.numpy()
    
    return model, inputs, u_mean, inducing_vars

# %%
def uniform_grid(input_dims, num_discrete_per_dim, low=0., high=1.):
    """
    Returns an array with all possible permutations of discrete values in input_dims number of dimensions.
    :param input_dims: int
    :param num_discrete_per_dim: int
    :param low: int
    :param high: int
    :return: tensor of shape (num_discrete_per_dim ** input_dims, input_dims)
    """
    num_points = num_discrete_per_dim ** input_dims
    out = np.zeros([num_points, input_dims])
    discrete_points = np.linspace(low, high, num_discrete_per_dim)
    for i in range(num_points):
        for dim in range(input_dims):
            val = num_discrete_per_dim ** (dim)
            out[i, dim] = discrete_points[int((i // val) % num_discrete_per_dim)]
    return out

# %% [markdown]
# This function is our main metric for the performance of the acquisition function: The closer the model's best guess to the global minimum, the better.

# %%
def best_guess(model):
    """
    Returns a GP model's best guess of the global maximum of f.
    """
    xx = uniform_grid(input_dims, num_discrete_per_dim, low=objective_low, high=objective_high)
    res = model.predict_f(xx)[0].numpy()
    return xx[np.argmax(res)]

# %% [markdown]
# Store the results in these arrays:

# %%
num_data_at_end = int((num_init_points-1) * num_init_points / 2 + num_evals)
X_results = np.zeros([num_runs, num_data_at_end, num_choices, input_dims])
y_results = np.zeros([num_runs, num_data_at_end, 1, input_dims])
best_guess_results = np.zeros([num_runs, num_evals, input_dims])

# %% [markdown]
# Create the initial values for each run:

# %%
np.random.seed(0)
init_points = np.random.uniform(low=objective_low, high=objective_high, size=[num_runs, num_init_points, input_dims])
num_combs = int((num_init_points-1) * num_init_points / 2)
init_vals = np.zeros([num_runs, num_combs, num_choices, input_dims])
for run in range(num_runs):
    cur_idx = 0
    for init_point in range(num_init_points-1):
        for next_point in range(init_point+1, num_init_points):
            init_vals[run, cur_idx, 0] = init_points[run, init_point]
            init_vals[run, cur_idx, 1] = init_points[run, next_point]
            cur_idx += 1

# %% [markdown]
# The following loops carry out the Bayesian optimization algorithm over a number of runs, with a fixed number of evaluations per run.

# %%
for run in range(num_runs):
    print("Beginning run %s" % (run))
    
    X = init_vals[run]
    y = get_noisy_observation(X, objective)
    
    model, inputs, u_mean, inducing_vars = train_and_visualize(X, y, num_inducing_init, "Run_{}:_Initial_model".format(run))

    for evaluation in range(num_evals):
        print("Beginning evaluation %s" % (evaluation)) 
        
        existing_idx = np.random.randint(0, inputs.shape[0])
        existing_input = inputs[existing_idx]
        random_input = np.random.uniform(low=objective_low, 
                                         high=objective_high, 
                                         size=(1, input_dims))
        
        next_query = np.zeros((num_choices, input_dims))
        next_query[0, :] = existing_input
        next_query[1, :] = random_input
        print("Evaluation %s: Next query is %s" % (evaluation, next_query))

        X = np.concatenate([X, [next_query]])
        # Evaluate objective function
        y = np.concatenate([y, get_noisy_observation(np.expand_dims(next_query, axis=0), objective)], axis=0)
        
        print("Evaluation %s: Training model" % (evaluation))
        model, inputs, u_mean, inducing_vars = train_and_visualize(X, y, 
                                                                   num_inducing_init + evaluation + 1, 
                                                                   "Run_{}_Evaluation_{}".format(run, evaluation))

        best_guess_results[run, evaluation, :] = best_guess(model)

    X_results[run] = X
    y_results[run] = y
# Out:
# Beginning run 0
# Indifference_threshold is trainable.
# WARNING:tensorflow:From /home/sebtsh/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/ops/array_grad.py:563: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity instead.
# Negative ELBO at step 0: 6.746526885444059 in 0.1875s
# Negative ELBO at step 500: 2.196172119500443 in 52.9890s
# Negative ELBO at step 1000: 2.1388190091271486 in 52.0348s
# Negative ELBO at step 1500: 2.163648947696851 in 53.2397s
# Negative ELBO at step 2000: 2.082518778753918 in 64.2289s
# Negative ELBO at step 2500: 2.1330662592808673 in 58.1043s
# Beginning evaluation 0
# Evaluation 0: Next query is [[0.43758721 0.891773   0.96366276]
#  [0.21874937 0.56957353 0.45210904]]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 59.14407296532674 in 0.2114s
# Negative ELBO at step 500: 4.225254189337748 in 81.3669s
# Negative ELBO at step 1000: 3.5865268706736684 in 72.6612s
# Negative ELBO at step 1500: 3.0044144775964785 in 78.5960s
# Negative ELBO at step 2000: 2.8350340428187324 in 76.1045s
# Negative ELBO at step 2500: 2.7719897183891384 in 81.0353s
# Beginning evaluation 1
# Evaluation 1: Next query is [[0.5488135  0.71518937 0.60276338]
#  [0.89667129 0.99033895 0.21689698]]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 27.534762800400234 in 0.2384s
# Negative ELBO at step 500: 3.9256910234712232 in 87.4324s
# Negative ELBO at step 1000: 3.6752573518315463 in 92.0672s
# Negative ELBO at step 1500: 3.5958946795959466 in 89.2996s
# Negative ELBO at step 2000: 3.5901256643962904 in 96.2044s
# Negative ELBO at step 2500: 3.4741393217264065 in 87.4479s
# Beginning evaluation 2
# Evaluation 2: Next query is [[0.5488135  0.71518937 0.60276338]
#  [0.22944183 0.8802976  0.31369239]]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 89.3454018099252 in 0.2527s
# Negative ELBO at step 500: 6.4563736955216475 in 103.7686s
# Negative ELBO at step 1000: 5.077701588553353 in 104.6311s
# Negative ELBO at step 1500: 4.576287691819147 in 111.3005s
# Negative ELBO at step 2000: 4.538400489502709 in 90.8800s
# Negative ELBO at step 2500: 4.388462194164163 in 111.4819s
# Beginning evaluation 3
# Evaluation 3: Next query is [[0.54488318 0.4236548  0.64589411]
#  [0.03045296 0.74699424 0.09259617]]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 237.26919689811683 in 0.3020s
# Negative ELBO at step 500: 11.030012630288974 in 123.9795s
# Negative ELBO at step 1000: 6.560100895780099 in 106.9243s
# Negative ELBO at step 1500: 5.917302617371067 in 120.3377s
# Negative ELBO at step 2000: 5.328718458136087 in 109.6286s
# Negative ELBO at step 2500: 5.35292136049806 in 114.2475s
# Beginning evaluation 4
# Evaluation 4: Next query is [[0.54488318 0.4236548  0.64589411]
#  [0.79920259 0.63044794 0.87428797]]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 732.3900562643821 in 0.3249s
# Negative ELBO at step 500: 16.654127324055963 in 122.1069s
# Negative ELBO at step 1000: 9.928047907867576 in 133.0213s
# Negative ELBO at step 1500: 7.354272015768453 in 121.8453s
# Negative ELBO at step 2000: 6.647682774748949 in 131.6596s
# Negative ELBO at step 2500: 6.5267184844436485 in 131.4652s
# Beginning evaluation 5
# Evaluation 5: Next query is [[0.43758721 0.891773   0.96366276]
#  [0.92621293 0.32531031 0.95287067]]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1824.335658857744 in 0.3222s
# Negative ELBO at step 500: 46.62361874447952 in 134.0522s
# Negative ELBO at step 1000: 19.762084915656338 in 148.4711s
# Negative ELBO at step 1500: 11.68406484395589 in 130.8566s
# Negative ELBO at step 2000: 9.621281930554982 in 152.6762s
# Negative ELBO at step 2500: 7.852714501757612 in 122.3630s
# Beginning evaluation 6
# Evaluation 6: Next query is [[0.43758721 0.891773   0.96366276]
#  [0.58759964 0.2728219  0.3708528 ]]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1749.7132763583895 in 0.3378s
# Negative ELBO at step 500: 54.97108130707787 in 157.1319s
# Negative ELBO at step 1000: 20.237389483272125 in 158.2297s
# Negative ELBO at step 1500: 14.286847823770149 in 155.6858s
# Negative ELBO at step 2000: 9.747147454185782 in 153.7981s
# Negative ELBO at step 2500: 9.977907252237934 in 155.7433s
# Beginning evaluation 7
# Evaluation 7: Next query is [[0.89667129 0.99033895 0.21689698]
#  [0.02706898 0.73139734 0.76696351]]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2061.7295810469236 in 1.1211s
# Negative ELBO at step 500: 50.96839748566402 in 181.8682s
# Negative ELBO at step 1000: 21.336947986227862 in 171.9577s
# Negative ELBO at step 1500: 14.794400858072226 in 173.7277s
# Negative ELBO at step 2000: 12.332384455603979 in 171.6951s
# Negative ELBO at step 2500: 10.049536898645297 in 173.9232s
# Beginning evaluation 8
# Evaluation 8: Next query is [[0.21874937 0.56957353 0.45210904]
#  [0.01560606 0.42879572 0.06807407]]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2536.3657268086345 in 0.4589s
# Negative ELBO at step 500: 70.52683203145386 in 188.2173s
# Negative ELBO at step 1000: 30.953503191232404 in 187.9250s
# Negative ELBO at step 1500: 18.141212365958292 in 192.1369s
# Negative ELBO at step 2000: 13.11483227833824 in 181.3528s
# Negative ELBO at step 2500: 11.145912353925 in 185.4208s
# Beginning evaluation 9
# Evaluation 9: Next query is [[0.79920259 0.63044794 0.87428797]
#  [0.12105988 0.24154569 0.22826361]]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 9871.914271452812 in 0.3982s
# Negative ELBO at step 500: 181.82088924109846 in 206.3803s
# Negative ELBO at step 1000: 72.45145206464707 in 190.2826s
# Negative ELBO at step 1500: 49.75579852834185 in 199.7405s
# Negative ELBO at step 2000: 29.005692417351902 in 194.6689s
# Negative ELBO at step 2500: 23.302906855399698 in 201.8058s
# Beginning evaluation 10
# Evaluation 10: Next query is [[0.02706898 0.73139734 0.76696351]
#  [0.55207828 0.27165277 0.45544415]]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 22307.09839853702 in 0.6750s
# Negative ELBO at step 500: 438.4868664925494 in 207.6902s
# Negative ELBO at step 1000: 176.42166084100015 in 210.6844s
# Negative ELBO at step 1500: 85.35984647938143 in 211.5797s
# Negative ELBO at step 2000: 56.266827770893514 in 211.4241s
# Negative ELBO at step 2500: 38.886729090471476 in 218.1373s
# Beginning evaluation 11
# Evaluation 11: Next query is [[0.92621293 0.32531031 0.95287067]
#  [0.22708397 0.45485988 0.97208251]]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 21876.23651637665 in 0.5676s
# Negative ELBO at step 500: 295.59121529269703 in 224.3196s
# Negative ELBO at step 1000: 118.14293995338019 in 227.3443s
# Negative ELBO at step 1500: 61.38762558535696 in 227.1215s
# Negative ELBO at step 2000: 41.97555426930939 in 232.1816s
# Negative ELBO at step 2500: 33.20943729549347 in 224.5999s
# Beginning evaluation 12
# Evaluation 12: Next query is [[0.12105988 0.24154569 0.22826361]
#  [0.73988392 0.89806236 0.67258231]]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 13246.644832876527 in 0.7920s
# Negative ELBO at step 500: 308.3565131539386 in 236.9291s
# Negative ELBO at step 1000: 114.52201519294951 in 232.0470s
# Negative ELBO at step 1500: 67.9089120867273 in 233.4951s
# Negative ELBO at step 2000: 38.273728079901744 in 227.9191s
# Negative ELBO at step 2500: 34.00197145965518 in 229.5867s
# Beginning evaluation 13
# Evaluation 13: Next query is [[0.55207828 0.27165277 0.45544415]
#  [0.89180097 0.78093113 0.2115339 ]]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 18429.07239308441 in 0.7272s
# Negative ELBO at step 500: 385.84959143803513 in 239.5439s
# Negative ELBO at step 1000: 139.84698569414746 in 244.7023s
# Negative ELBO at step 1500: 70.33803519005433 in 239.6602s
# Negative ELBO at step 2000: 44.15026264765183 in 244.7424s
# Negative ELBO at step 2500: 31.393298894166385 in 234.0947s
# Beginning evaluation 14
# Evaluation 14: Next query is [[0.89667129 0.99033895 0.21689698]
#  [0.7706745  0.72052752 0.63341482]]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 23743.303871385357 in 0.5944s
# Negative ELBO at step 500: 436.49998369216564 in 256.9824s
# Negative ELBO at step 1000: 191.83191515987096 in 255.7546s
# Negative ELBO at step 1500: 107.85991989387145 in 251.8258s
# Negative ELBO at step 2000: 58.328871764510396 in 246.4187s
# Negative ELBO at step 2500: 41.368681481522955 in 247.7443s
# Beginning evaluation 15
# Evaluation 15: Next query is [[0.79920259 0.63044794 0.87428797]
#  [0.24768502 0.31823351 0.85877747]]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 32387.840946418954 in 0.6192s
# Negative ELBO at step 500: 507.0541459036616 in 280.6521s
# Negative ELBO at step 1000: 199.06559773317832 in 279.2624s
# Negative ELBO at step 1500: 104.80046742996018 in 273.6114s
# Negative ELBO at step 2000: 66.52711273829831 in 288.5754s
# Negative ELBO at step 2500: 40.4782686953942 in 282.6537s
# Beginning evaluation 16
# Evaluation 16: Next query is [[0.21874937 0.56957353 0.45210904]
#  [0.67805941 0.14469114 0.16804252]]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 75556.87741976966 in 0.8959s
# Negative ELBO at step 500: 1413.7407731626554 in 298.7288s
# Negative ELBO at step 1000: 549.7053239794424 in 288.1187s
# Negative ELBO at step 1500: 325.6303519421864 in 301.6764s
# Negative ELBO at step 2000: 141.06693147230712 in 299.2718s
# Negative ELBO at step 2500: 117.10447937466273 in 294.8257s
# Beginning evaluation 17
# Evaluation 17: Next query is [[0.43758721 0.891773   0.96366276]
#  [0.79559037 0.34453046 0.77087276]]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 116466.29619273343 in 0.7428s
# Negative ELBO at step 500: 1743.7354545970911 in 301.8333s
# Negative ELBO at step 1000: 654.6365826527725 in 298.0389s
# Negative ELBO at step 1500: 346.93871560127985 in 308.5514s
# Negative ELBO at step 2000: 275.1523460754279 in 308.0912s
# Negative ELBO at step 2500: 160.6286641328104 in 308.5487s
# Beginning evaluation 18
# Evaluation 18: Next query is [[0.43758721 0.891773   0.96366276]
#  [0.16235795 0.29084091 0.17979529]]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 594663.437525757 in 0.7234s
# Negative ELBO at step 500: 7394.730881059166 in 322.3560s
# Negative ELBO at step 1500: 1046.1958897530037 in 328.2076s
# Negative ELBO at step 2000: 629.6672600903636 in 313.6088s
# Negative ELBO at step 2500: 396.1089216387689 in 316.8181s
# Beginning evaluation 19
# Evaluation 19: Next query is [[0.02706898 0.73139734 0.76696351]
#  [0.9485403  0.77827617 0.84834527]]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 180243.18841881407 in 0.7249s
# Negative ELBO at step 500: 2002.4453565955473 in 325.2514s
# Negative ELBO at step 1000: 766.657736383982 in 325.3610s
# Negative ELBO at step 1500: 457.426237944007 in 333.4299s
# Negative ELBO at step 2000: 238.58406629244914 in 339.7624s
# Negative ELBO at step 2500: 183.25027382691925 in 326.1641s
# Beginning run 1
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 3.228701914258373 in 0.2360s
# Negative ELBO at step 500: 2.085319877843708 in 64.1953s
# Negative ELBO at step 1000: 1.9066087298787544 in 71.5642s
# Negative ELBO at step 1500: 1.8361213323407277 in 57.4202s
# Negative ELBO at step 2000: 1.8972429038149365 in 69.0853s
# Negative ELBO at step 2500: 1.844315992826078 in 71.3842s
# Beginning evaluation 0
# Evaluation 0: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.45841243 0.48503053 0.89551293]]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 18.45188771159578 in 0.2229s
# Negative ELBO at step 500: 3.125786931028548 in 78.3582s
# Negative ELBO at step 1000: 2.8364953992124025 in 89.3483s
# Negative ELBO at step 1500: 2.8152981341685868 in 66.3202s
# Negative ELBO at step 2000: 2.752887404656049 in 80.2999s
# Negative ELBO at step 2500: 2.722233705786163 in 87.7192s
# Beginning evaluation 1
# Evaluation 1: Next query is [[0.0871293  0.0202184  0.83261985]
#  [0.997994   0.98788917 0.60332299]]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 15.395652750165524 in 0.2260s
# Negative ELBO at step 500: 3.733271124670057 in 90.8492s
# Negative ELBO at step 1000: 3.2915627462840726 in 88.6291s
# Negative ELBO at step 1500: 3.144638669211737 in 91.3359s
# Negative ELBO at step 2000: 3.2498962040391146 in 83.6078s
# Negative ELBO at step 2500: 3.13070268923223 in 94.6770s
# Beginning evaluation 2
# Evaluation 2: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.16628957 0.2404904  0.2205283 ]]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 109.26468307099728 in 0.5618s
# Negative ELBO at step 500: 8.705726577963091 in 107.3727s
# Negative ELBO at step 1000: 5.252153245958308 in 98.7082s
# Negative ELBO at step 1500: 4.45213136249979 in 110.4021s
# Negative ELBO at step 2000: 4.592440403302152 in 98.6175s
# Negative ELBO at step 2500: 4.356013152841902 in 103.3198s
# Beginning evaluation 3
# Evaluation 3: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.36322396 0.2467724  0.4935906 ]]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1742.8046554015398 in 0.3097s
# Negative ELBO at step 500: 56.384339049910565 in 115.2267s
# Negative ELBO at step 1000: 20.283007947581808 in 115.3172s
# Negative ELBO at step 1500: 12.323457180764214 in 119.8107s
# Negative ELBO at step 2000: 8.828146687064399 in 120.1185s
# Negative ELBO at step 2500: 7.203824841127811 in 114.9479s
# Beginning evaluation 4
# Evaluation 4: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.3798939  0.56045059 0.66821823]]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 162.59490339764162 in 0.3145s
# Negative ELBO at step 500: 11.308076636167684 in 133.8244s
# Negative ELBO at step 1000: 7.503494822513269 in 127.9138s
# Negative ELBO at step 1500: 6.235296383734777 in 132.1115s
# Negative ELBO at step 2000: 6.27512333542853 in 131.1766s
# Negative ELBO at step 2500: 6.079935842856967 in 131.9143s
# Beginning evaluation 5
# Evaluation 5: Next query is [[0.997994   0.98788917 0.60332299]
#  [0.52336468 0.38059538 0.98535984]]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 232.39178321052106 in 0.3319s
# Negative ELBO at step 500: 15.451091218003132 in 141.5098s
# Negative ELBO at step 1000: 8.48705377548633 in 146.0679s
# Negative ELBO at step 1500: 7.083952205110667 in 149.9931s
# Negative ELBO at step 2000: 6.579445731364414 in 149.5175s
# Negative ELBO at step 2500: 6.418486792140201 in 145.8340s
# Beginning evaluation 6
# Evaluation 6: Next query is [[0.3798939  0.56045059 0.66821823]
#  [0.59831597 0.11891694 0.4175392 ]]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1569.0407444497557 in 0.3463s
# Negative ELBO at step 500: 39.93784865208595 in 156.4338s
# Negative ELBO at step 1000: 18.236176919451005 in 151.0126s
# Negative ELBO at step 1500: 14.000613566836751 in 159.1975s
# Negative ELBO at step 2000: 11.506494275873843 in 163.2638s
# Negative ELBO at step 2500: 8.437449431675086 in 157.7255s
# Beginning evaluation 7
# Evaluation 7: Next query is [[0.52336468 0.38059538 0.98535984]
#  [0.33126888 0.32032629 0.94680717]]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 1272.2474821853664 in 0.3699s
# Negative ELBO at step 500: 44.7216968709426 in 171.3989s
# Negative ELBO at step 1000: 17.32729194841105 in 172.3357s
# Negative ELBO at step 1500: 13.049669268070586 in 171.5883s
# Negative ELBO at step 2000: 10.527303502184736 in 174.6730s
# Negative ELBO at step 2500: 9.001510719551451 in 174.7725s
# Beginning evaluation 8
# Evaluation 8: Next query is [[0.3798939  0.56045059 0.66821823]
#  [0.65251435 0.55264587 0.25120012]]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 19251.655205164705 in 1.1910s
# Negative ELBO at step 500: 191.44619292614797 in 186.4441s
# Negative ELBO at step 1000: 82.2429870000664 in 189.0284s
# Negative ELBO at step 1500: 42.86405620828353 in 190.7339s
# Negative ELBO at step 2000: 28.623549101576472 in 191.1196s
# Negative ELBO at step 2500: 25.366771340139845 in 187.8005s
# Beginning evaluation 9
# Evaluation 9: Next query is [[0.56804456 0.92559664 0.07103606]
#  [0.27798994 0.79328167 0.65997055]]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 25805.285067691908 in 0.4268s
# Negative ELBO at step 500: 283.11078482505 in 199.5357s
# Negative ELBO at step 1000: 111.29369961253582 in 194.3232s
# Negative ELBO at step 1500: 64.17705963161323 in 199.0939s
# Negative ELBO at step 2000: 40.40461973235741 in 197.6195s
# Negative ELBO at step 2500: 29.60403876987674 in 196.5172s
# Beginning evaluation 10
# Evaluation 10: Next query is [[0.3798939  0.56045059 0.66821823]
#  [0.96391299 0.30342126 0.26668018]]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 11329.99925088735 in 0.4622s
# Negative ELBO at step 500: 182.60858066566823 in 210.2177s
# Negative ELBO at step 1000: 75.74816191365427 in 208.1272s
# Negative ELBO at step 1500: 46.80426526605545 in 217.6785s
# Negative ELBO at step 2000: 28.952000877385533 in 211.7696s
# Negative ELBO at step 2500: 17.96790204759492 in 210.4332s
# Beginning evaluation 11
# Evaluation 11: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.53794578 0.93766309 0.3051887 ]]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 9743.190742508697 in 0.5026s
# Negative ELBO at step 500: 190.84919937319702 in 230.4872s
# Negative ELBO at step 1000: 78.43813469953265 in 233.7186s
# Negative ELBO at step 1500: 47.38506981491264 in 228.0305s
# Negative ELBO at step 2000: 32.59497795027477 in 226.6922s
# Negative ELBO at step 2500: 22.83503122438527 in 219.8405s
# Beginning evaluation 12
# Evaluation 12: Next query is [[0.27798994 0.79328167 0.65997055]
#  [0.79611711 0.81999571 0.48579488]]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 27233.818076993197 in 0.5746s
# Negative ELBO at step 500: 383.5500086537128 in 232.6307s
# Negative ELBO at step 1000: 144.60388169422208 in 243.0983s
# Negative ELBO at step 1500: 79.35183709284176 in 230.0240s
# Negative ELBO at step 2000: 43.73048091808823 in 237.1536s
# Negative ELBO at step 2500: 31.539137513387164 in 233.3489s
# Beginning evaluation 13
# Evaluation 13: Next query is [[0.38344152 0.79172504 0.52889492]
#  [0.96076647 0.64056459 0.68864832]]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 74881.4858200006 in 0.5986s
# Negative ELBO at step 500: 805.0589791365401 in 248.2712s
# Negative ELBO at step 1000: 372.50984313551214 in 249.6767s
# Negative ELBO at step 1500: 185.55809541061726 in 245.8412s
# Negative ELBO at step 2000: 107.79802798817258 in 245.4569s
# Negative ELBO at step 2500: 68.61758092297438 in 246.0337s
# Beginning evaluation 14
# Evaluation 14: Next query is [[0.0871293  0.0202184  0.83261985]
#  [0.38575967 0.06829277 0.79030471]]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 138561.20157563794 in 0.6588s
# Negative ELBO at step 500: 1446.8201252232775 in 261.7314s
# Negative ELBO at step 1000: 579.9002652276454 in 258.2485s
# Negative ELBO at step 1500: 286.24505500167163 in 256.3400s
# Negative ELBO at step 2000: 260.1081154442821 in 265.8490s
# Negative ELBO at step 2500: 113.73088908800533 in 261.4654s
# Beginning evaluation 15
# Evaluation 15: Next query is [[0.36322396 0.2467724  0.4935906 ]
#  [0.98738334 0.78745161 0.49138007]]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 82581.42691704638 in 0.6793s
# Negative ELBO at step 500: 1522.3468069467576 in 280.4423s
# Negative ELBO at step 1000: 489.1502137226119 in 278.3938s
# Negative ELBO at step 1500: 315.0434127840108 in 281.5359s
# Negative ELBO at step 2000: 169.78870410766402 in 268.9345s
# Negative ELBO at step 2500: 92.92158658061726 in 282.6411s
# Beginning evaluation 16
# Evaluation 16: Next query is [[0.0871293  0.0202184  0.83261985]
#  [0.52522331 0.04001707 0.59096908]]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 61700.085047416906 in 0.8020s
# Negative ELBO at step 500: 1019.7913484847091 in 298.6422s
# Negative ELBO at step 1000: 388.6171633210089 in 294.3617s
# Negative ELBO at step 1500: 255.84628045244912 in 289.0339s
# Negative ELBO at step 2000: 163.3571302528921 in 286.2223s
# Negative ELBO at step 2500: 97.96599332031248 in 290.1792s
# Beginning evaluation 17
# Evaluation 17: Next query is [[0.997994   0.98788917 0.60332299]
#  [0.54695006 0.29361682 0.96820439]]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 84182.78846527496 in 0.7556s
# Negative ELBO at step 500: 1478.2956926257395 in 307.9327s
# Negative ELBO at step 1000: 529.5518635310898 in 310.0750s
# Negative ELBO at step 1500: 362.0407181466744 in 306.7356s
# Negative ELBO at step 2000: 227.72663638354774 in 309.6895s
# Negative ELBO at step 2500: 108.36431563611355 in 302.5574s
# Beginning evaluation 18
# Evaluation 18: Next query is [[0.52522331 0.04001707 0.59096908]
#  [0.79142094 0.68630091 0.58753846]]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 116148.75887045692 in 0.7426s
# Negative ELBO at step 500: 1861.888161667433 in 322.9864s
# Negative ELBO at step 1000: 782.8770763770406 in 316.4837s
# Negative ELBO at step 1500: 454.068590889001 in 317.1309s
# Negative ELBO at step 2000: 256.114691418508 in 309.6457s
# Negative ELBO at step 2500: 182.65273657414528 in 327.8280s
# Beginning evaluation 19
# Evaluation 19: Next query is [[0.59831597 0.11891694 0.4175392 ]
#  [0.18808101 0.8952924  0.64677545]]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 143242.90375495207 in 2.4807s
# Negative ELBO at step 500: 2615.633527304424 in 327.0093s
# Negative ELBO at step 1000: 1135.9011792550245 in 336.8084s
# Negative ELBO at step 2000: 320.5385820910333 in 332.9495s
# Negative ELBO at step 2500: 205.26460985498804 in 317.0467s
# Beginning run 2
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 6.236137566523601 in 0.4383s
# Negative ELBO at step 500: 2.253203018010549 in 74.0820s
# Negative ELBO at step 1000: 2.0831152110078985 in 56.4020s
# Negative ELBO at step 1500: 2.008020016272622 in 53.2766s
# Negative ELBO at step 2000: 2.037717851536107 in 56.9137s
# Negative ELBO at step 2500: 1.936605716500461 in 66.8011s
# Beginning evaluation 0
# Evaluation 0: Next query is [[0.77815675 0.87001215 0.97861834]
#  [0.69597422 0.33277685 0.09545662]]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 36.34715501292972 in 0.4845s
# Negative ELBO at step 500: 3.4011785050129406 in 77.9270s
# Negative ELBO at step 1000: 2.8084024284008615 in 80.8000s
# Negative ELBO at step 1500: 2.6816940150480097 in 76.3003s
# Negative ELBO at step 2000: 2.48906523691647 in 78.5016s
# Negative ELBO at step 2500: 2.550848732271171 in 79.4667s
# Beginning evaluation 1
# Evaluation 1: Next query is [[0.69597422 0.33277685 0.09545662]
#  [0.063369   0.40985745 0.72250009]]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 26.133708493752245 in 0.2118s
# Negative ELBO at step 500: 4.551378115923864 in 95.1084s
# Negative ELBO at step 1000: 3.37944313852354 in 93.7310s
# Negative ELBO at step 1500: 3.4531260791778977 in 88.8220s
# Negative ELBO at step 2000: 3.294778538758557 in 88.8781s
# Negative ELBO at step 2500: 3.0609915677363424 in 88.4778s
# Beginning evaluation 2
# Evaluation 2: Next query is [[0.11827443 0.63992102 0.14335329]
#  [0.15949655 0.19131256 0.54934832]]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 101.71471888514726 in 0.2611s
# Negative ELBO at step 500: 7.494192914152863 in 106.8845s
# Negative ELBO at step 1000: 4.793827653846112 in 103.5761s
# Negative ELBO at step 1500: 4.696696126014864 in 103.9689s
# Negative ELBO at step 2000: 4.394471153674807 in 96.9583s
# Negative ELBO at step 2500: 4.265508706575822 in 109.8436s
# Beginning evaluation 3
# Evaluation 3: Next query is [[0.15949655 0.19131256 0.54934832]
#  [0.57499033 0.73993748 0.70466465]]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 729.1742622527129 in 0.7739s
# Negative ELBO at step 500: 20.999628748067213 in 122.2817s
# Negative ELBO at step 1000: 8.506943564453001 in 119.1726s
# Negative ELBO at step 1500: 6.495390972528267 in 116.0783s
# Negative ELBO at step 2000: 5.5751000745533945 in 126.1923s
# Negative ELBO at step 2500: 5.127143082345237 in 118.6762s
# Beginning evaluation 4
# Evaluation 4: Next query is [[0.77815675 0.87001215 0.97861834]
#  [0.14297878 0.35455447 0.66780345]]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 251.79355952336925 in 0.3168s
# Negative ELBO at step 500: 13.9884909675068 in 129.0723s
# Negative ELBO at step 1000: 7.673384449011448 in 133.8298s
# Negative ELBO at step 1500: 6.394011964903868 in 138.5595s
# Negative ELBO at step 2000: 6.176066558655403 in 126.0625s
# Negative ELBO at step 2500: 6.049224455774089 in 134.6873s
# Beginning evaluation 5
# Evaluation 5: Next query is [[0.11827443 0.63992102 0.14335329]
#  [0.20339584 0.17610384 0.31980734]]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 988.8241872118061 in 0.6861s
# Negative ELBO at step 500: 22.75836464693623 in 134.7335s
# Negative ELBO at step 1000: 13.339073978950488 in 146.4188s
# Negative ELBO at step 1500: 9.212620184998052 in 138.7093s
# Negative ELBO at step 2000: 7.786409203327976 in 142.8359s
# Negative ELBO at step 2500: 7.325064977890259 in 141.2354s
# Beginning evaluation 6
# Evaluation 6: Next query is [[0.15949655 0.19131256 0.54934832]
#  [0.14091704 0.61223801 0.1295314 ]]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 704.0842516409817 in 0.4526s
# Negative ELBO at step 500: 34.02561103144003 in 154.8832s
# Negative ELBO at step 1000: 13.692057779117606 in 157.0787s
# Negative ELBO at step 1500: 9.019272484888322 in 157.2280s
# Negative ELBO at step 2000: 8.616294953029962 in 157.9905s
# Negative ELBO at step 2500: 7.81779734013737 in 161.3632s
# Beginning evaluation 7
# Evaluation 7: Next query is [[0.11827443 0.63992102 0.14335329]
#  [0.55899164 0.49769535 0.95750981]]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 15256.642145202199 in 0.3885s
# Negative ELBO at step 500: 195.622822252719 in 175.8360s
# Negative ELBO at step 1000: 89.18274046183124 in 171.6371s
# Negative ELBO at step 1500: 52.268091435681185 in 176.8534s
# Negative ELBO at step 2000: 31.675245473350756 in 167.6996s
# Negative ELBO at step 2500: 28.092751826357997 in 175.5648s
# Beginning evaluation 8
# Evaluation 8: Next query is [[0.77815675 0.87001215 0.97861834]
#  [0.07247392 0.00549482 0.27624767]]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 3298.5880795322337 in 0.4211s
# Negative ELBO at step 500: 78.0798413281376 in 191.9442s
# Negative ELBO at step 1000: 35.84791431627824 in 195.4701s
# Negative ELBO at step 1500: 19.495829802775354 in 179.7569s
# Negative ELBO at step 2000: 18.418754357579267 in 175.2902s
# Negative ELBO at step 2500: 11.488963993502876 in 182.6633s
# Beginning evaluation 9
# Evaluation 9: Next query is [[0.55899164 0.49769535 0.95750981]
#  [0.18870537 0.87368075 0.72288922]]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2240.375996312608 in 0.4463s
# Negative ELBO at step 500: 62.47151722302554 in 196.6200s
# Negative ELBO at step 1000: 27.76577299992826 in 200.1211s
# Negative ELBO at step 1500: 17.384007268757983 in 197.1485s
# Negative ELBO at step 2000: 13.749945915479657 in 199.8700s
# Negative ELBO at step 2500: 11.351443700720372 in 196.5432s
# Beginning evaluation 10
# Evaluation 10: Next query is [[0.69597422 0.33277685 0.09545662]
#  [0.28646463 0.50159147 0.87941746]]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 33617.20488355747 in 0.4665s
# Negative ELBO at step 500: 543.4137593152219 in 210.6858s
# Negative ELBO at step 1000: 210.13987743801556 in 215.3240s
# Negative ELBO at step 1500: 109.46519704214137 in 205.1847s
# Negative ELBO at step 2000: 72.45301281811703 in 216.5959s
# Negative ELBO at step 2500: 53.76737727817287 in 216.7895s
# Beginning evaluation 11
# Evaluation 11: Next query is [[0.11827443 0.63992102 0.14335329]
#  [0.47130219 0.29379874 0.98181609]]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 22891.47233258109 in 0.4918s
# Negative ELBO at step 500: 326.8395247820228 in 227.4488s
# Negative ELBO at step 1000: 148.10384074609522 in 234.2473s
# Negative ELBO at step 1500: 68.5614015628002 in 218.4382s
# Negative ELBO at step 2000: 36.152764630034746 in 215.2176s
# Negative ELBO at step 2500: 33.574812385574646 in 228.4914s
# Beginning evaluation 12
# Evaluation 12: Next query is [[0.15949655 0.19131256 0.54934832]
#  [0.35240712 0.89417252 0.18104167]]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 5228.552350800892 in 0.6870s
# Negative ELBO at step 500: 170.68341349539952 in 235.6988s
# Negative ELBO at step 1000: 69.60146412640307 in 239.3705s
# Negative ELBO at step 1500: 40.89633409041642 in 238.9973s
# Negative ELBO at step 2000: 24.503552600212103 in 241.4806s
# Negative ELBO at step 2500: 19.47221332293315 in 240.8617s
# Beginning evaluation 13
# Evaluation 13: Next query is [[0.79915856 0.46147936 0.78052918]
#  [0.02795538 0.02934627 0.577622  ]]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 15419.012390868018 in 0.5533s
# Negative ELBO at step 500: 328.4700182823083 in 250.3204s
# Negative ELBO at step 1000: 113.28124487337028 in 259.2797s
# Negative ELBO at step 1500: 75.00833078690361 in 257.2379s
# Negative ELBO at step 2000: 37.38862410608991 in 246.5349s
# Negative ELBO at step 2500: 28.158594599306788 in 251.9729s
# Beginning evaluation 14
# Evaluation 14: Next query is [[0.18870537 0.87368075 0.72288922]
#  [0.60402693 0.66218365 0.58099582]]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 45897.48390569443 in 0.6757s
# Negative ELBO at step 500: 613.2758013225557 in 263.4576s
# Negative ELBO at step 1000: 244.38822522975238 in 258.9963s
# Negative ELBO at step 1500: 149.73827190230702 in 270.8209s
# Negative ELBO at step 2000: 77.78716888186388 in 267.1484s
# Negative ELBO at step 2500: 60.16545078327299 in 266.0717s
# Beginning evaluation 15
# Evaluation 15: Next query is [[0.14091704 0.61223801 0.1295314 ]
#  [0.68646976 0.24433258 0.15337445]]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 15262.127412318787 in 1.3623s
# Negative ELBO at step 500: 399.81055679425793 in 278.0796s
# Negative ELBO at step 1000: 160.70822549834062 in 275.0701s
# Negative ELBO at step 1500: 89.52138289586472 in 281.5864s
# Negative ELBO at step 2000: 56.07311643404011 in 281.6909s
# Negative ELBO at step 2500: 37.17843439680291 in 282.0645s
# Beginning evaluation 16
# Evaluation 16: Next query is [[0.02795538 0.02934627 0.577622  ]
#  [0.06877785 0.01077776 0.99704634]]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 285908.9659531843 in 0.7354s
# Negative ELBO at step 500: 2708.9142001600826 in 288.8388s
# Negative ELBO at step 1000: 1372.8166157289945 in 290.0120s
# Negative ELBO at step 1500: 662.3914008077147 in 288.2075s
# Negative ELBO at step 2000: 397.9247985781328 in 289.4242s
# Negative ELBO at step 2500: 278.1142996607915 in 294.3652s
# Beginning evaluation 17
# Evaluation 17: Next query is [[0.69597422 0.33277685 0.09545662]
#  [0.82072514 0.50359775 0.52082427]]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 548028.5106657022 in 0.6864s
# Negative ELBO at step 500: 4515.354844812279 in 308.1613s
# Negative ELBO at step 1000: 2207.5150543632044 in 302.6109s
# Negative ELBO at step 1500: 1433.0169588566448 in 312.4330s
# Negative ELBO at step 2000: 667.5632842568199 in 298.6581s
# Negative ELBO at step 2500: 417.1516570677584 in 297.7705s
# Beginning evaluation 18
# Evaluation 18: Next query is [[0.06877785 0.01077776 0.99704634]
#  [0.63250897 0.51462554 0.13772485]]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 124791.21240970556 in 0.7704s
# Negative ELBO at step 500: 2192.8061096775427 in 262.8392s
# Negative ELBO at step 1000: 761.4761145404964 in 266.6468s
# Negative ELBO at step 1500: 451.1108664198015 in 266.8553s
# Negative ELBO at step 2000: 257.26119372490155 in 262.6250s
# Negative ELBO at step 2500: 169.28073188323015 in 264.5327s
# Beginning evaluation 19
# Evaluation 19: Next query is [[0.063369   0.40985745 0.72250009]
#  [0.84055719 0.08757178 0.97551218]]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 137786.8883608765 in 0.7290s
# Negative ELBO at step 500: 2125.6009469709134 in 272.1197s
# Negative ELBO at step 1000: 930.1423476984058 in 271.7647s
# Negative ELBO at step 1500: 452.4792072343408 in 273.7551s
# Negative ELBO at step 2000: 296.0542166585242 in 273.4893s
# Negative ELBO at step 2500: 177.09967030589067 in 272.6000s
# Beginning run 3
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7.0263334067224585 in 0.1435s
# Negative ELBO at step 500: 2.1074017266513434 in 53.2188s
# Negative ELBO at step 1000: 2.19624375746359 in 51.0414s
# Negative ELBO at step 1500: 1.9593506437592516 in 53.3676s
# Negative ELBO at step 2000: 1.9664502658930747 in 52.7324s
# Negative ELBO at step 2500: 1.9554367302413342 in 51.2992s
# Beginning evaluation 0
# Evaluation 0: Next query is [[0.26455561 0.77423369 0.45615033]
#  [0.20487769 0.81000386 0.56782065]]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 52.45560988181143 in 0.1959s
# Negative ELBO at step 500: 3.8500787224859057 in 65.0518s
# Negative ELBO at step 1000: 3.0163652416934945 in 64.0504s
# Negative ELBO at step 1500: 2.9558904176252487 in 65.5362s
# Negative ELBO at step 2000: 2.6732762944431614 in 63.9224s
# Negative ELBO at step 2500: 2.8454387823324376 in 63.4528s
# Beginning evaluation 1
# Evaluation 1: Next query is [[0.94466892 0.52184832 0.41466194]
#  [0.28934192 0.39857764 0.97084726]]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 41.9548693651293 in 0.2323s
# Negative ELBO at step 500: 5.125250690399252 in 73.3644s
# Negative ELBO at step 1000: 3.7723901216840736 in 75.8010s
# Negative ELBO at step 1500: 3.6508012946575485 in 73.8064s
# Negative ELBO at step 2000: 3.444221539909312 in 76.4913s
# Negative ELBO at step 2500: 3.501396945092953 in 75.1950s
# Beginning evaluation 2
# Evaluation 2: Next query is [[0.20487769 0.81000386 0.56782065]
#  [0.47147972 0.8175088  0.45251495]]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 2525.1632334008777 in 0.2262s
# Negative ELBO at step 500: 29.394485820608853 in 84.8628s
# Negative ELBO at step 1000: 12.865263181386348 in 87.8477s
# Negative ELBO at step 1500: 8.480781693403372 in 84.2816s
# Negative ELBO at step 2000: 7.592011943046735 in 86.0647s
# Negative ELBO at step 2500: 6.613037844467846 in 84.6429s
# Beginning evaluation 3
# Evaluation 3: Next query is [[0.56843395 0.0187898  0.6176355 ]
#  [0.69740038 0.4139625  0.6296183 ]]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 80.4102175498664 in 0.2974s
# Negative ELBO at step 500: 7.623889946873117 in 96.5329s
# Negative ELBO at step 1000: 5.515260631639297 in 95.6300s
# Negative ELBO at step 1500: 4.824092972043965 in 98.9917s
# Negative ELBO at step 2000: 4.784720601519413 in 98.2874s
# Negative ELBO at step 2500: 4.48511030734444 in 99.3777s
# Beginning evaluation 4
# Evaluation 4: Next query is [[0.94466892 0.52184832 0.41466194]
#  [0.01032792 0.67777514 0.17808517]]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 662.0058040164791 in 0.2825s
# Negative ELBO at step 500: 23.87704469199591 in 108.8058s
# Negative ELBO at step 1000: 10.006972949085732 in 110.3612s
# Negative ELBO at step 1500: 7.885991638657175 in 106.6993s
# Negative ELBO at step 2000: 6.962332124546643 in 108.8773s
# Negative ELBO at step 2500: 6.030619339844664 in 110.0357s
# Beginning evaluation 5
# Evaluation 5: Next query is [[0.94466892 0.52184832 0.41466194]
#  [0.93686283 0.77386297 0.40563389]]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 846.1456604018792 in 0.3003s
# Negative ELBO at step 500: 27.422988270257175 in 118.0892s
# Negative ELBO at step 1000: 12.725706835645694 in 119.0480s
# Negative ELBO at step 1500: 8.934946795312808 in 122.3308s
# Negative ELBO at step 2000: 7.580196193980447 in 119.2219s
# Negative ELBO at step 2500: 6.586768810212646 in 118.0502s
# Beginning evaluation 6
# Evaluation 6: Next query is [[0.26455561 0.77423369 0.45615033]
#  [0.49222678 0.36133145 0.57935088]]
# Evaluation 6: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 12234.554998134541 in 0.3499s
# Negative ELBO at step 500: 150.37659166932414 in 131.3984s
# Negative ELBO at step 1000: 56.06986370138936 in 130.9742s
# Negative ELBO at step 1500: 30.050203886057936 in 129.0160s
# Negative ELBO at step 2000: 24.2969195163836 in 130.1202s
# Negative ELBO at step 2500: 17.22038710588854 in 130.7997s
# Beginning evaluation 7
# Evaluation 7: Next query is [[0.47147972 0.8175088  0.45251495]
#  [0.27379311 0.91753949 0.75773427]]
# Evaluation 7: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 8980.789131809093 in 0.4367s
# Negative ELBO at step 500: 196.12436157762104 in 143.7844s
# Negative ELBO at step 1000: 66.8622625584936 in 144.4162s
# Negative ELBO at step 1500: 30.41345333641393 in 140.5500s
# Negative ELBO at step 2000: 25.27058753874984 in 143.7715s
# Negative ELBO at step 2500: 16.595406033266666 in 145.5119s
# Beginning evaluation 8
# Evaluation 8: Next query is [[0.47147972 0.8175088  0.45251495]
#  [0.76935769 0.83984988 0.31260788]]
# Evaluation 8: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 10060.51946928483 in 0.4033s
# Negative ELBO at step 500: 222.95877710184027 in 152.5780s
# Negative ELBO at step 1000: 87.56521500045562 in 154.0874s
# Negative ELBO at step 1500: 57.93585068844961 in 153.6235s
# Negative ELBO at step 2000: 33.68856086752538 in 152.3299s
# Negative ELBO at step 2500: 22.89507299319632 in 152.6079s
# Beginning evaluation 9
# Evaluation 9: Next query is [[0.93686283 0.77386297 0.40563389]
#  [0.28833118 0.42694236 0.74447356]]
# Evaluation 9: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 12224.247965689392 in 0.4605s
# Negative ELBO at step 500: 237.47568163543457 in 163.4021s
# Negative ELBO at step 1000: 95.13096866659349 in 164.5119s
# Negative ELBO at step 1500: 59.28532619430625 in 163.9045s
# Negative ELBO at step 2000: 34.194679004279024 in 167.9253s
# Negative ELBO at step 2500: 25.333319635539333 in 161.8828s
# Beginning evaluation 10
# Evaluation 10: Next query is [[0.47147972 0.8175088  0.45251495]
#  [0.82857069 0.74738178 0.15570077]]
# Evaluation 10: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 42420.83296588142 in 0.5113s
# Negative ELBO at step 500: 451.2549037911609 in 171.8731s
# Negative ELBO at step 1000: 195.07339611112744 in 177.4053s
# Negative ELBO at step 1500: 113.3167464287003 in 176.7365s
# Negative ELBO at step 2000: 78.56459550712931 in 175.3213s
# Negative ELBO at step 2500: 54.8656677593206 in 172.2901s
# Beginning evaluation 11
# Evaluation 11: Next query is [[0.93686283 0.77386297 0.40563389]
#  [0.39420789 0.89973486 0.58986812]]
# Evaluation 11: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 7987.083410248544 in 0.5258s
# Negative ELBO at step 500: 182.7244098210749 in 189.8893s
# Negative ELBO at step 1000: 71.1370230556361 in 188.2538s
# Negative ELBO at step 1500: 40.75312090956375 in 188.8265s
# Negative ELBO at step 2000: 25.915196090192918 in 187.0495s
# Negative ELBO at step 2500: 17.880756387544707 in 189.5538s
# Beginning evaluation 12
# Evaluation 12: Next query is [[0.28833118 0.42694236 0.74447356]
#  [0.09538035 0.96668199 0.38958478]]
# Evaluation 12: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 14640.585210739557 in 0.5915s
# Negative ELBO at step 500: 391.13028249054196 in 198.3204s
# Negative ELBO at step 1000: 152.4369499410877 in 197.7194s
# Negative ELBO at step 1500: 72.00162639007732 in 198.9657s
# Negative ELBO at step 2000: 48.59268014268493 in 196.3906s
# Negative ELBO at step 2500: 35.85661674611275 in 199.9837s
# Beginning evaluation 13
# Evaluation 13: Next query is [[0.93686283 0.77386297 0.40563389]
#  [0.45849116 0.08161389 0.66102798]]
# Evaluation 13: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 82278.99473080291 in 0.7554s
# Negative ELBO at step 500: 1183.5324040861071 in 209.7982s
# Negative ELBO at step 1000: 391.3808206288098 in 210.2964s
# Negative ELBO at step 1500: 175.06082403795043 in 211.2483s
# Negative ELBO at step 2000: 137.44505482585555 in 213.5085s
# Negative ELBO at step 2500: 68.88664529301332 in 207.9849s
# Beginning evaluation 14
# Evaluation 14: Next query is [[0.26455561 0.77423369 0.45615033]
#  [0.12925762 0.50268559 0.18631862]]
# Evaluation 14: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 81923.92647814724 in 0.5975s
# Negative ELBO at step 500: 1294.8476120127943 in 222.0861s
# Negative ELBO at step 1000: 539.0251071345306 in 216.9956s
# Negative ELBO at step 1500: 237.3059061909111 in 222.0983s
# Negative ELBO at step 2000: 169.17271291351037 in 219.8162s
# Negative ELBO at step 2500: 98.28539292790936 in 219.2914s
# Beginning evaluation 15
# Evaluation 15: Next query is [[0.28934192 0.39857764 0.97084726]
#  [0.21370719 0.76223281 0.48637379]]
# Evaluation 15: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 108370.0516879906 in 0.6742s
# Negative ELBO at step 500: 1683.1537278602596 in 232.9707s
# Negative ELBO at step 1000: 651.0254387225843 in 234.9285s
# Negative ELBO at step 1500: 367.9067532763741 in 234.1083s
# Negative ELBO at step 2000: 221.13254734677074 in 232.3231s
# Negative ELBO at step 2500: 157.37542666757798 in 234.7993s
# Beginning evaluation 16
# Evaluation 16: Next query is [[0.93686283 0.77386297 0.40563389]
#  [0.72404239 0.78435259 0.33035861]]
# Evaluation 16: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 44298.59312374945 in 0.6361s
# Negative ELBO at step 500: 785.1456798325456 in 244.0304s
# Negative ELBO at step 1000: 293.5874029331277 in 238.8419s
# Negative ELBO at step 1500: 147.39182171243576 in 242.1813s
# Negative ELBO at step 2000: 87.82570160397748 in 243.2670s
# Negative ELBO at step 2500: 66.3343804104143 in 241.6692s
# Beginning evaluation 17
# Evaluation 17: Next query is [[0.56843395 0.0187898  0.6176355 ]
#  [0.8543426  0.73341455 0.67597539]]
# Evaluation 17: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 470762.50248961296 in 0.7417s
# Negative ELBO at step 500: 9073.878446906783 in 256.6930s
# Negative ELBO at step 1000: 2990.634701297476 in 255.4034s
# Negative ELBO at step 1500: 1620.8169340740117 in 256.9206s
# Negative ELBO at step 2000: 1039.0614687200953 in 255.2230s
# Negative ELBO at step 2500: 665.911043214438 in 254.6258s
# Beginning evaluation 18
# Evaluation 18: Next query is [[0.26455561 0.77423369 0.45615033]
#  [0.33495454 0.80859617 0.68811388]]
# Evaluation 18: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 153556.58977405415 in 0.7497s
# Negative ELBO at step 500: 2890.0896028239094 in 266.1136s
# Negative ELBO at step 1000: 1073.463622584818 in 267.6267s
# Negative ELBO at step 1500: 645.228326649659 in 270.0219s
# Negative ELBO at step 2000: 397.45998712923364 in 266.2528s
# Negative ELBO at step 2500: 264.83284249591924 in 268.6431s
# Beginning evaluation 19
# Evaluation 19: Next query is [[0.76935769 0.83984988 0.31260788]
#  [0.67954193 0.82536885 0.21166892]]
# Evaluation 19: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 366710.76128305227 in 0.7303s
# Negative ELBO at step 500: 4437.627992455781 in 275.7604s
# Negative ELBO at step 1000: 1737.0702298612757 in 275.3354s
# Negative ELBO at step 1500: 1130.5028439211342 in 276.5703s
# Negative ELBO at step 2000: 715.6611374177608 in 278.2250s
# Negative ELBO at step 2500: 396.1758834679789 in 277.1164s
# Beginning run 4
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 237.07422852584557 in 0.1663s
# Negative ELBO at step 500: 5.7007171696296295 in 52.3904s
# Negative ELBO at step 1000: 3.1620621461168685 in 52.4079s
# Negative ELBO at step 1500: 2.358444352373274 in 50.6362s
# Negative ELBO at step 2000: 2.561468936467496 in 53.6378s
# Negative ELBO at step 2500: 2.3337623639771445 in 54.5722s
# Beginning evaluation 0
# Evaluation 0: Next query is [[0.61209572 0.616934   0.94374808]
#  [0.4155887  0.9074198  0.49630736]]
# Evaluation 0: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 12.63069590241934 in 0.1659s
# Negative ELBO at step 500: 3.108685703331222 in 64.4922s
# Negative ELBO at step 1000: 2.83302061407683 in 63.5331s
# Negative ELBO at step 1500: 2.7407399518322118 in 63.8700s
# Negative ELBO at step 2000: 2.718717963218313 in 64.3533s
# Negative ELBO at step 2500: 2.606699058501612 in 63.5935s
# Beginning evaluation 1
# Evaluation 1: Next query is [[0.6818203  0.3595079  0.43703195]
#  [0.46532407 0.66939017 0.81028094]]
# Evaluation 1: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 132.40020887059316 in 0.2314s
# Negative ELBO at step 500: 5.662952750010277 in 74.7205s
# Negative ELBO at step 1000: 4.099751264032344 in 75.8113s
# Negative ELBO at step 1500: 3.427070951825286 in 76.0698s
# Negative ELBO at step 2000: 3.3469287118900484 in 76.5518s
# Negative ELBO at step 2500: 3.3723166237130817 in 76.1562s
# Beginning evaluation 2
# Evaluation 2: Next query is [[0.6976312  0.06022547 0.66676672]
#  [0.6755326  0.18800797 0.26195315]]
# Evaluation 2: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 141.26745411955633 in 0.2631s
# Negative ELBO at step 500: 7.561865413307104 in 84.1091s
# Negative ELBO at step 1000: 4.968405993297956 in 86.7832s
# Negative ELBO at step 1500: 4.54560483533535 in 84.9394s
# Negative ELBO at step 2000: 4.3564998536370005 in 87.1099s
# Negative ELBO at step 2500: 4.157962203946605 in 85.1696s
# Beginning evaluation 3
# Evaluation 3: Next query is [[0.61209572 0.616934   0.94374808]
#  [0.81566656 0.85898652 0.65709623]]
# Evaluation 3: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 105.50807172757492 in 0.2879s
# Negative ELBO at step 500: 8.051648042787141 in 97.4465s
# Negative ELBO at step 1000: 5.015736481957271 in 96.2353s
# Negative ELBO at step 1500: 4.8332798633052185 in 98.0393s
# Negative ELBO at step 2000: 4.708103486809432 in 98.0805s
# Negative ELBO at step 2500: 4.602933607472419 in 98.5062s
# Beginning evaluation 4
# Evaluation 4: Next query is [[0.6976312  0.06022547 0.66676672]
#  [0.23645571 0.37596243 0.43116513]]
# Evaluation 4: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 317.03125481355755 in 0.3310s
# Negative ELBO at step 500: 15.553857830114557 in 108.8093s
# Negative ELBO at step 1000: 8.973666865036378 in 109.0994s
# Negative ELBO at step 1500: 6.020536286983425 in 109.5385s
# Negative ELBO at step 2000: 5.947056006654818 in 106.6970s
# Negative ELBO at step 2500: 5.508715776844056 in 109.5141s
# Beginning evaluation 5
# Evaluation 5: Next query is [[0.6976312  0.06022547 0.66676672]
#  [0.5308068  0.54559505 0.9446899 ]]
# Evaluation 5: Training model
# Indifference_threshold is trainable.
# Negative ELBO at step 0: 395.3918097112227 in 0.3640s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e99f480768e4> in <module>
#      28         model, inputs, u_mean, inducing_vars = train_and_visualize(X, y,
#      29                                                                    num_inducing_init + evaluation + 1,
# ---> 30                                                                    "Run_{}_Evaluation_{}".format(run, evaluation))
#      31
#      32         best_guess_results[run, evaluation, :] = best_guess(model)
#
# <ipython-input-6-4e02aba53f99> in train_and_visualize(X, y, num_inducing, title)
#       6                                                                          obj_low=objective_low,
#       7                                                                          obj_high=objective_high,
# ----> 8                                                                          num_steps=3000)
#       9     likelihood = gpflow.likelihoods.Gaussian()
#      10     model = PBO.models.learning.init_SVGP_fullcov(q_mu, q_sqrt, u, k, likelihood)
#
# ~/PBO/models/learning_stochastic.py in train_model_fullcov(X, y, num_inducing, obj_low, obj_high, lengthscale, num_steps, indifference_threshold)
#     371     try:
#     372         for i in range(num_steps):
# --> 373             optimizer.minimize(neg_elbo, var_list=trainable_vars)
#     374
#     375             if i % 500 == 0:
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/keras/optimizer_v2/optimizer_v2.py in minimize(self, loss, var_list, grad_loss, name)
#     314     """
#     315     grads_and_vars = self._compute_gradients(
# --> 316         loss, var_list=var_list, grad_loss=grad_loss)
#     317
#     318     return self.apply_gradients(grads_and_vars, name=name)
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/keras/optimizer_v2/optimizer_v2.py in _compute_gradients(self, loss, var_list, grad_loss)
#     353     var_list = nest.flatten(var_list)
#     354     with backend.name_scope(self._name + "/gradients"):
# --> 355       grads = tape.gradient(loss_value, var_list, grad_loss)
#     356
#     357       if hasattr(self, "clipnorm"):
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1027         output_gradients=output_gradients,
#    1028         sources_raw=flat_sources_raw,
# -> 1029         unconnected_gradients=unconnected_gradients)
#    1030
#    1031     if not self._persistent:
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      75       output_gradients,
#      76       sources_raw,
# ---> 77       compat.as_str(unconnected_gradients.value))
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices)
#     139     return [None] * num_inputs
#     140
# --> 141   return grad_fn(mock_op, *out_grads)
#     142
#     143
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/ops/array_grad.py in _GatherV2Grad(op, grad)
#     583
#     584     outer_batches_indices = math_ops.range(batch_dims)
# --> 585     batch_axis_indices = math_ops.range(batch_dims, axis_dims)
#     586     inner_axes_indices = math_ops.range(axis_dims + 1, values_dims)
#     587
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/ops/math_ops.py in range(start, limit, delta, dtype, name)
#    1426     start, limit = 0, start
#    1427
# -> 1428   with ops.name_scope(name, "Range", [start, limit, delta]) as name:
#    1429     start = ops.convert_to_tensor(start, dtype=dtype, name="start")
#    1430     limit = ops.convert_to_tensor(limit, dtype=dtype, name="limit")
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py in name_scope(name, default_name, values)
#    6184     if graph_value is not None:
#    6185       return graph_value.graph.name_scope(name)
# -> 6186   return name_scope_v2(name or "")
#    6187
#    6188
#
# ~/anaconda3/envs/gpflow/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py in __init__(self, name)
#    6367       raise ValueError("name for name_scope must be a string.")
#    6368     self._name = name
# -> 6369     self._exit_fns = []
#    6370
#    6371   @property
#
# KeyboardInterrupt:

# %%
print_summary(model)

# %%
pickle.dump((X_results, y_results, best_guess_results), open(results_dir + "Xybestguess.p", "wb"))

# %%
def dist(x, y):
    """
    x and y have shape (..., input_dims)
    """
    return np.sqrt(np.sum((x - y) * (x - y), axis=-1))

xx = uniform_grid(input_dims, num_discrete_per_dim, low=objective_low, high=objective_high)
global_min = xx[np.argmin(objective(xx))][0]

for i in range(best_guess_results.shape[0]):
    diff_from_min = dist(best_guess_results[i], global_min)
    
    x_axis = list(range(num_combs+1, num_combs+1+num_evals))
    plt.figure(figsize=(12, 6))
    plt.plot(x_axis, diff_from_min, 'kx', mew=2)
    plt.xticks(x_axis)
    plt.xlabel('Evaluations', fontsize=18)
    plt.ylabel('Best guess distance', fontsize=16)
    plt.title("Run %s" % i)
    plt.show()
